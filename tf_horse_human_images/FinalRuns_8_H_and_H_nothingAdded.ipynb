# %% [markdown]
# ###Start###

# %% [markdown]
# This version is the most normal version of all versions. In this version there is no unitary weights, no BatchNormalizations, and no Regularizations.

# %%
import tensorflow as tf
import numpy as np
import os, random
import matplotlib.pyplot as plt
from keras import layers
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras import regularizers
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras.models import load_model
from tensorflow.keras.optimizers.schedules import ExponentialDecay
from tensorflow.keras.optimizers import Adam
from imblearn.over_sampling import RandomOverSampler
from sklearn.metrics import classification_report
import time
import psutil

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
path = '/content/drive/MyDrive/tf_HH/NP_data/'
trainImages = np.load(path + 'trainImages.npy')
trainLabels = np.load(path + 'trainLabels.npy')
testImages  = np.load(path + 'testImages.npy')
testLabels  = np.load(path + 'testLabels.npy')

# %%
augmented = ImageDataGenerator(rotation_range=12,
                               width_shift_range = 0.1,
                               height_shift_range= 0.1,
                               zoom_range=0.1,
                               horizontal_flip= True)
augmented.fit(trainImages)
augmented.fit(testImages)

# %% [markdown]
# ###Data Check

# %%
#Data Loading Check
plt.imshow(trainImages[254])
print(trainImages.shape, " ", trainImages.dtype)
print(trainLabels.shape)
print(testImages.shape)
print(testLabels.shape)
# Out:
# (1000, 256, 256, 3)   float32
# (1000, 2)
# (256, 256, 256, 3)
# (256, 2)

# %%
classes = ['AD', 'CN']

figure, axes = plt.subplots(4, 5, figsize= (12,12))
for i in range(len(trainImages)):
  if trainLabels[i][0] == 1 :
    titleIndex = 0
  else :
    titleIndex = 1
  ax_row = i // 5
  ax_col = i % 5
  if ax_row ==4 or ax_col==5:
    break
  ax = axes[ax_row][ax_col]
  ax.imshow(trainImages[i])
  ax.set_title(classes[titleIndex])
  ax.axis('off')

plt.tight_layout()
plt.show()
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %% [markdown]
# ###Unitary Regularizer###

# %%
# used version 1.2
import tensorflow.keras.backend as K
class UnitaryRegularizer(tf.keras.regularizers.Regularizer):
    def __init__(self, lambd):
        self.lambd = lambd

    def __call__(self, weights):
        # Get the number of output neurons
        num_output_neurons = weights.shape[-1]

        # Reshape the weight matrix to be a 2D matrix (flatten filters)
        flattened_weights = tf.reshape(weights, (-1, num_output_neurons))

        # Calculate the matrix product and the identity matrix
        product = tf.matmul(flattened_weights, tf.transpose(flattened_weights))
        identity_matrix = tf.eye(product.shape[0])

        # Calculate the Frobenius norm for each filter separately
        filter_norms = tf.norm(product - identity_matrix, axis=[-2, -1])
        #print(filter_norms)

        # Calculate the regularization term as the sum of squared Frobenius norms
        regularization = 0.5 * self.lambd * tf.reduce_sum(tf.square(filter_norms))
        #tf.print(regularization)
        return regularization

    def get_config(self):
        return {'lambd': self.lambd}

# %% [markdown]
# ###MODEL

# %%
my_resnet = tf.keras.applications.ResNet50(input_shape=(256, 256, 3), include_top=False)
my_resnet.trainable = False
custom_lambd = 0.01
model = tf.keras.Sequential([
    tf.keras.layers.Input((256, 256, 3)),
    #tf.keras.layers.BatchNormalization(),
    my_resnet,
    #tf.keras.layers.BatchNormalization(),
    tf.keras.layers.Conv2D(filters = 256, kernel_size = (3, 3),
                             activation = tf.nn.
                           relu , name='conv1', padding='same'),
    #tf.keras.layers.BatchNormalization(),
    tf.keras.layers.MaxPool2D(pool_size=(2, 2), name='pool1'),
    tf.keras.layers.Conv2D(filters = 128, kernel_size = (3, 3),
                             activation = tf.nn.relu, padding='same',
                            name='conv2'),
                           #kernel_regularizer= UnitaryRegularizer(lambd=custom_lambd) ),
    #tf.keras.layers.MaxPool2D(pool_size=(2, 2), name='pool2'),
    tf.keras.layers.Conv2D(filters = 64, kernel_size = (3, 3),
                             activation = tf.nn.relu, name='conv3',
                            padding='same'),
    tf.keras.layers.MaxPool2D(pool_size=(2, 2), name='pool3'),
    #tf.keras.layers.BatchNormalization(),
    tf.keras.layers.Conv2D(filters = 32, kernel_size = (3, 3),
                           activation= tf.nn.relu, padding='same',
                           name='conv4'),
                           #kernel_regularizer= UnitaryRegularizer(lambd=custom_lambd) ),
    tf.keras.layers.Conv2D(filters = 32, kernel_size = (3, 3),
                           activation= tf.nn.relu, padding='same',
                           name='conv5'),
                           #kernel_regularizer= UnitaryRegularizer(lambd=custom_lambd) ),
    #tf.keras.layers.BatchNormalization(),
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(128, activation = tf.nn.relu),
    tf.keras.layers.Dense(64, activation = tf.nn.relu),
                          #,kernel_regularizer=regularizers.l2(0.01)),
    tf.keras.layers.Dense(2, activation = 'sigmoid')
])

# %% [markdown]
# ###Unitary Initialization###

# %%
# this function below is utilizing CPU because of using NUMPY
def unitarizer(weightArr):
  unitaryMatrices = np.empty_like(weightArr)
  print("1")
  weightArr_tr = np.transpose(weightArr, (3, 2, 0, 1))
  print("2 tr: ", weightArr_tr.shape)
  U, SIGMA, V_trans = np.linalg.svd(weightArr_tr)
  print("3 ", V_trans.shape)
  W = V_trans.T
  print("4 ", W.shape)
  W = np.reshape(W, weightArr.shape)
  print("5")
  #unitaryMatrices[:,:,i,j] = unitarySingleKernel
  return W

# %%
trainableWeights = model.trainable_weights
print("the shape of trainable weights in first conv", trainableWeights[4].shape)
# Out:
# the shape of trainable weights in first conv (3, 3, 2048, 256)

# %%
indecies = [8, 14, 16]

for idx in indecies:
  print("***********************  Convolution is unitarizing ", idx, " ************************")
  convWeights  = trainableWeights[idx]
  print(convWeights.shape)
  U_convWeights = unitarizer(convWeights)
  print(U_convWeights[0][0][16][16])
  print("*************************  Convolution unitarized ", idx, "  *************************")
  model.trainable_weights[idx].assign(U_convWeights)
  convtester = model.trainable_weights[idx]
  print("************************* Convolution unitaryCheck ", idx, " *************************")
  print(convtester[0][0][16][16])
# Out:
# ***********************  Convolution is unitarizing  8  ************************
# (3, 3, 256, 128)
# 1
# 2 tr:  (128, 256, 3, 3)
# 3  (128, 256, 3, 3)
# 4  (3, 3, 256, 128)
# 5
# -0.38356513
# *************************  Convolution unitarized  8   *************************
# ************************* Convolution unitaryCheck  8  *************************
# tf.Tensor(-0.38356513, shape=(), dtype=float32)
# ***********************  Convolution is unitarizing  14  ************************
# (3, 3, 64, 32)
# 1
# 2 tr:  (32, 64, 3, 3)
# 3  (32, 64, 3, 3)
# 4  (3, 3, 64, 32)
# 5
# 0.61836576
# *************************  Convolution unitarized  14   *************************
# ************************* Convolution unitaryCheck  14  *************************
# tf.Tensor(0.61836576, shape=(), dtype=float32)
# ***********************  Convolution is unitarizing  16  ************************
# (3, 3, 32, 32)
# 1
# 2 tr:  (32, 32, 3, 3)
# 3  (32, 32, 3, 3)
# 4  (3, 3, 32, 32)
# 5
# -0.8618421
# *************************  Convolution unitarized  16   *************************
# ************************* Convolution unitaryCheck  16  *************************
# tf.Tensor(-0.8618421, shape=(), dtype=float32)

# %%
#not needed when we regularize it.
# model.layers[6].trainable=False
# model.layers[10].trainable=False
# model.layers[11].trainable=False

# %% [markdown]
# ###Model compile###

# %%
model.compile(optimizer='sgd', loss='binary_crossentropy', metrics=['accuracy'])

# %%
checkpointPath = "/content/drive/MyDrive/Kag-adni-unBalance/finalCheckPoints/FinalRuns1/"

checkPointCallBack = ModelCheckpoint(filepath = checkpointPath,
                                     monitor = 'val_accuracy',
                                     mode='max', save_best_only = True)

# %% [markdown]
# ###Model Check

# %%
tf.keras.utils.plot_model(model, show_shapes = True,
                          show_layer_activations=True, show_trainable= True)

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  resnet50 (Functional)       (None, 8, 8, 2048)        23587712
#
#  conv1 (Conv2D)              (None, 8, 8, 256)         4718848
#
#  pool1 (MaxPooling2D)        (None, 4, 4, 256)         0
#
#  conv2 (Conv2D)              (None, 4, 4, 128)         295040
#
#  conv3 (Conv2D)              (None, 4, 4, 64)          73792
#
#  pool3 (MaxPooling2D)        (None, 2, 2, 64)          0
#
#  conv4 (Conv2D)              (None, 2, 2, 32)          18464
#
#  conv5 (Conv2D)              (None, 2, 2, 32)          9248
#
#  flatten_1 (Flatten)         (None, 128)               0
#
#  dense_3 (Dense)             (None, 128)               16512
#
#  dense_4 (Dense)             (None, 64)                8256
#
#  dense_5 (Dense)             (None, 2)                 130
#
# =================================================================
# Total params: 28,728,002
# Trainable params: 5,140,290
# Non-trainable params: 23,587,712
# _________________________________________________________________

# %%
#early_stopping = EarlyStopping(patience=5, restore_best_weights=True)

# %% [markdown]
# ###RUN###

# %%
training_times = []
memory_usage = []
testAccuracy = []
num_epochs = 120
for epoch in range(num_epochs):
  startTime = time.time()
  history = model.fit(augmented.flow(trainImages, trainLabels, batch_size = 64),
                    epochs = 1)
          #validation_data=(testImages, testLabels))
                    #callbacks=[checkPointCallBack])#with version 1.2
  endTime = time.time()
  epochTime = endTime - startTime
  training_times.append(epochTime)
  memory_usage.append(psutil.virtual_memory().used/1024**2)
  testLoss , testAcc = model.evaluate(testImages, testLabels, verbose = 0)
  testAccuracy.append(testAcc)
  print(f"Epoch {epoch + 1}/{num_epochs} - Time: {epochTime:.2f}s - Memory Usage: {memory_usage[-1]:.2f}MB - val_loss: {testLoss} - val_accuracy: {testAcc}")
  print("*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*")
# Out:
# 16/16 [==============================] - 21s 992ms/step - loss: 0.6896 - accuracy: 0.5340
# Epoch 1/120 - Time: 24.80s - Memory Usage: 6027.51MB - val_loss: 0.6755114197731018 - val_accuracy: 0.76953125
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 16/16 [==============================] - 17s 1s/step - loss: 0.6821 - accuracy: 0.6140
# Epoch 2/120 - Time: 17.91s - Memory Usage: 6213.61MB - val_loss: 0.6714248061180115 - val_accuracy: 0.51171875
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 16/16 [==============================] - 16s 984ms/step - loss: 0.6789 - accuracy: 0.5920
# Epoch 3/120 - Time: 21.99s - Memory Usage: 6482.77MB - val_loss: 0.6615923047065735 - val_accuracy: 0.5
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 16/16 [==============================] - 15s 958ms/step - loss: 0.6735 - accuracy: 0.5990
# Epoch 4/120 - Time: 16.27s - Memory Usage: 6744.71MB - val_loss: 0.625950276851654 - val_accuracy: 0.80859375
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 16/16 [==============================] - 17s 1s/step - loss: 0.6736 - accuracy: 0.5760
# Epoch 5/120 - Time: 17.85s - Memory Usage: 6999.11MB - val_loss: 0.6853260397911072 - val_accuracy: 0.5
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 16/16 [==============================] - 16s 987ms/step - loss: 0.6600 - accuracy: 0.5840
# Epoch 6/120 - Time: 16.77s - Memory Usage: 6498.75MB - val_loss: 0.6228755712509155 - val_accuracy: 0.59375
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 16/16 [==============================] - 16s 991ms/step - loss: 0.6603 - accuracy: 0.6230
# Epoch 7/120 - Time: 21.29s - Memory Usage: 6702.59MB - val_loss: 0.6040104031562805 - val_accuracy: 0.6328125
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 16/16 [==============================] - 17s 1s/step - loss: 0.6497 - accuracy: 0.6540
# Epoch 8/120 - Time: 17.93s - Memory Usage: 6982.43MB - val_loss: 0.6993571519851685 - val_accuracy: 0.5
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 16/16 [==============================] - 16s 975ms/step - loss: 0.6366 - accuracy: 0.6280
# Epoch 9/120 - Time: 16.48s - Memory Usage: 7114.52MB - val_loss: 0.6240134835243225 - val_accuracy: 0.578125
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 16/16 [==============================] - 16s 972ms/step - loss: 0.6815 - accuracy: 0.6120
# Epoch 10/120 - Time: 22.00s - Memory Usage: 6536.57MB - val_loss: 0.6463290452957153 - val_accuracy: 0.83984375
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 16/16 [==============================] - 16s 964ms/step - loss: 0.6610 - accuracy: 0.6150
# Epoch 11/120 - Time: 16.42s - Memory Usage: 6956.51MB - val_loss: 0.5917275547981262 - val_accuracy: 0.75
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 16/16 [==============================] - 16s 956ms/step - loss: 0.6374 - accuracy: 0.6810
# Epoch 12/120 - Time: 17.41s - Memory Usage: 7159.27MB - val_loss: 0.6694061756134033 - val_accuracy: 0.5078125
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 16/16 [==============================] - 16s 976ms/step - loss: 0.6460 - accuracy: 0.6130
# Epoch 13/120 - Time: 16.52s - Memory Usage: 7292.46MB - val_loss: 0.5129015445709229 - val_accuracy: 0.85546875
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 16/16 [==============================] - 16s 974ms/step - loss: 0.6304 - accuracy: 0.6450
# Epoch 14/120 - Time: 16.59s - Memory Usage: 6667.80MB - val_loss: 0.5901826620101929 - val_accuracy: 0.64453125
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 16/16 [==============================] - 16s 956ms/step - loss: 0.5870 - accuracy: 0.7010
# Epoch 15/120 - Time: 21.89s - Memory Usage: 6995.25MB - val_loss: 0.605728268623352 - val_accuracy: 0.640625
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 16/16 [==============================] - 16s 968ms/step - loss: 0.5825 - accuracy: 0.6920
# Epoch 16/120 - Time: 21.26s - Memory Usage: 7128.73MB - val_loss: 0.4021439552307129 - val_accuracy: 0.859375
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 16/16 [==============================] - 16s 981ms/step - loss: 0.5843 - accuracy: 0.6940
# Epoch 17/120 - Time: 21.29s - Memory Usage: 7298.20MB - val_loss: 0.4016987681388855 - val_accuracy: 0.8515625
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 16/16 [==============================] - 16s 975ms/step - loss: 0.5857 - accuracy: 0.6940
# Epoch 18/120 - Time: 17.03s - Memory Usage: 6594.14MB - val_loss: 0.5064066052436829 - val_accuracy: 0.7421875
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 16/16 [==============================] - 17s 1s/step - loss: 0.5187 - accuracy: 0.7540
# Epoch 19/120 - Time: 21.30s - Memory Usage: 6781.25MB - val_loss: 0.6789470911026001 - val_accuracy: 0.640625
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 16/16 [==============================] - 16s 947ms/step - loss: 0.5453 - accuracy: 0.7190
# Epoch 20/120 - Time: 21.96s - Memory Usage: 6975.49MB - val_loss: 0.32708078622817993 - val_accuracy: 0.88671875
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 16/16 [==============================] - 15s 962ms/step - loss: 0.5538 - accuracy: 0.7020
# Epoch 21/120 - Time: 21.27s - Memory Usage: 7198.05MB - val_loss: 0.7012653350830078 - val_accuracy: 0.63671875
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 16/16 [==============================] - 16s 967ms/step - loss: 0.5149 - accuracy: 0.7470
# Epoch 22/120 - Time: 21.35s - Memory Usage: 6656.62MB - val_loss: 0.3306543827056885 - val_accuracy: 0.87890625
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 16/16 [==============================] - 16s 968ms/step - loss: 0.4970 - accuracy: 0.7640
# Epoch 23/120 - Time: 21.29s - Memory Usage: 6876.78MB - val_loss: 0.3374933898448944 - val_accuracy: 0.86328125
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 16/16 [==============================] - 17s 994ms/step - loss: 0.4861 - accuracy: 0.7640
# Epoch 24/120 - Time: 17.50s - Memory Usage: 7004.80MB - val_loss: 0.28473764657974243 - val_accuracy: 0.90625
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 16/16 [==============================] - 16s 970ms/step - loss: 0.4973 - accuracy: 0.7600
# Epoch 25/120 - Time: 21.27s - Memory Usage: 7247.89MB - val_loss: 0.5749412775039673 - val_accuracy: 0.75
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 16/16 [==============================] - 17s 994ms/step - loss: 0.4590 - accuracy: 0.7880
# Epoch 26/120 - Time: 18.12s - Memory Usage: 6623.18MB - val_loss: 0.3681285083293915 - val_accuracy: 0.84765625
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 16/16 [==============================] - 16s 969ms/step - loss: 0.4493 - accuracy: 0.7790
# Epoch 27/120 - Time: 21.28s - Memory Usage: 6547.92MB - val_loss: 0.6696531176567078 - val_accuracy: 0.73046875
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 16/16 [==============================] - 16s 979ms/step - loss: 0.4574 - accuracy: 0.7720
# Epoch 28/120 - Time: 17.77s - Memory Usage: 6708.37MB - val_loss: 0.3063371479511261 - val_accuracy: 0.87890625
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 16/16 [==============================] - 16s 982ms/step - loss: 0.4598 - accuracy: 0.7740
# Epoch 29/120 - Time: 21.93s - Memory Usage: 6903.60MB - val_loss: 0.45935046672821045 - val_accuracy: 0.8203125
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 16/16 [==============================] - 15s 958ms/step - loss: 0.4169 - accuracy: 0.8060
# Epoch 30/120 - Time: 21.51s - Memory Usage: 7089.07MB - val_loss: 0.5306699275970459 - val_accuracy: 0.80078125
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 16/16 [==============================] - 16s 998ms/step - loss: 0.4784 - accuracy: 0.7930
# Epoch 31/120 - Time: 21.30s - Memory Usage: 6708.25MB - val_loss: 0.776115894317627 - val_accuracy: 0.62890625
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 16/16 [==============================] - ETA: 0s - loss: 0.4577 - accuracy: 0.7870Epoch 32/120 - Time: 21.28s - Memory Usage: 6859.59MB - val_loss: 0.584174633026123 - val_accuracy: 0.7734375
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 16/16 [==============================] - 15s 963ms/step - loss: 0.4284 - accuracy: 0.8060
# Epoch 33/120 - Time: 21.28s - Memory Usage: 7052.67MB - val_loss: 0.9193345904350281 - val_accuracy: 0.63671875
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 16/16 [==============================] - 16s 967ms/step - loss: 0.4708 - accuracy: 0.7580
# Epoch 34/120 - Time: 21.78s - Memory Usage: 7298.89MB - val_loss: 0.6399065852165222 - val_accuracy: 0.72265625
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 16/16 [==============================] - 15s 958ms/step - loss: 0.3865 - accuracy: 0.8330
# Epoch 35/120 - Time: 21.29s - Memory Usage: 6956.86MB - val_loss: 0.6347516179084778 - val_accuracy: 0.78125
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 16/16 [==============================] - 16s 968ms/step - loss: 0.4396 - accuracy: 0.7920
# Epoch 36/120 - Time: 16.44s - Memory Usage: 7035.84MB - val_loss: 0.6245496869087219 - val_accuracy: 0.7734375
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 16/16 [==============================] - 15s 963ms/step - loss: 0.3464 - accuracy: 0.8500
# Epoch 37/120 - Time: 16.26s - Memory Usage: 7199.80MB - val_loss: 0.7065675854682922 - val_accuracy: 0.7734375
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 16/16 [==============================] - 16s 968ms/step - loss: 0.4055 - accuracy: 0.8150
# Epoch 38/120 - Time: 21.86s - Memory Usage: 7466.20MB - val_loss: 0.5573047399520874 - val_accuracy: 0.796875
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 16/16 [==============================] - 17s 991ms/step - loss: 0.3683 - accuracy: 0.8260
# Epoch 39/120 - Time: 21.90s - Memory Usage: 7091.28MB - val_loss: 0.6018384695053101 - val_accuracy: 0.78515625
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 16/16 [==============================] - 16s 1s/step - loss: 0.4034 - accuracy: 0.8230
# Epoch 40/120 - Time: 21.33s - Memory Usage: 7226.40MB - val_loss: 0.46082720160484314 - val_accuracy: 0.8359375
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 16/16 [==============================] - 15s 960ms/step - loss: 0.3791 - accuracy: 0.8290
# Epoch 41/120 - Time: 21.76s - Memory Usage: 7478.79MB - val_loss: 0.5893078446388245 - val_accuracy: 0.80078125
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 16/16 [==============================] - 16s 989ms/step - loss: 0.3746 - accuracy: 0.8310
# Epoch 42/120 - Time: 16.89s - Memory Usage: 7666.87MB - val_loss: 0.5360637307167053 - val_accuracy: 0.82421875
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 16/16 [==============================] - 15s 954ms/step - loss: 0.3757 - accuracy: 0.8150
# Epoch 43/120 - Time: 21.33s - Memory Usage: 7279.64MB - val_loss: 0.6895561218261719 - val_accuracy: 0.76171875
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 16/16 [==============================] - 16s 974ms/step - loss: 0.3800 - accuracy: 0.8120
# Epoch 44/120 - Time: 21.29s - Memory Usage: 7500.37MB - val_loss: 0.5526255369186401 - val_accuracy: 0.8046875
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 16/16 [==============================] - 16s 995ms/step - loss: 0.3614 - accuracy: 0.8380
# Epoch 45/120 - Time: 16.90s - Memory Usage: 7662.59MB - val_loss: 0.6965882182121277 - val_accuracy: 0.77734375
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 16/16 [==============================] - 17s 1s/step - loss: 0.3888 - accuracy: 0.8310
# Epoch 46/120 - Time: 21.33s - Memory Usage: 7832.84MB - val_loss: 0.6572124361991882 - val_accuracy: 0.79296875
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 16/16 [==============================] - 16s 967ms/step - loss: 0.3743 - accuracy: 0.8340
# Epoch 47/120 - Time: 21.28s - Memory Usage: 7441.58MB - val_loss: 0.9081005454063416 - val_accuracy: 0.70703125
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 16/16 [==============================] - 15s 950ms/step - loss: 0.3568 - accuracy: 0.8250
# Epoch 48/120 - Time: 21.30s - Memory Usage: 7697.65MB - val_loss: 0.5617007613182068 - val_accuracy: 0.80859375
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 16/16 [==============================] - 16s 985ms/step - loss: 0.3680 - accuracy: 0.8260
# Epoch 49/120 - Time: 17.41s - Memory Usage: 7828.85MB - val_loss: 0.5010759830474854 - val_accuracy: 0.828125
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 16/16 [==============================] - 16s 978ms/step - loss: 0.3305 - accuracy: 0.8440
# Epoch 50/120 - Time: 16.54s - Memory Usage: 8023.75MB - val_loss: 0.7899335622787476 - val_accuracy: 0.75
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 16/16 [==============================] - 15s 956ms/step - loss: 0.3243 - accuracy: 0.8450
# Epoch 51/120 - Time: 21.33s - Memory Usage: 7636.07MB - val_loss: 0.7919474244117737 - val_accuracy: 0.78515625
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 16/16 [==============================] - 15s 962ms/step - loss: 0.3181 - accuracy: 0.8590
# Epoch 52/120 - Time: 16.29s - Memory Usage: 7847.91MB - val_loss: 0.7866266369819641 - val_accuracy: 0.7578125
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 16/16 [==============================] - 16s 961ms/step - loss: 0.3228 - accuracy: 0.8660
# Epoch 53/120 - Time: 21.31s - Memory Usage: 8077.01MB - val_loss: 0.557523787021637 - val_accuracy: 0.82421875
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 16/16 [==============================] - 15s 949ms/step - loss: 0.3700 - accuracy: 0.8450
# Epoch 54/120 - Time: 21.28s - Memory Usage: 8280.56MB - val_loss: 0.41722193360328674 - val_accuracy: 0.85546875
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 16/16 [==============================] - 16s 983ms/step - loss: 0.3504 - accuracy: 0.8520
# Epoch 55/120 - Time: 17.30s - Memory Usage: 7870.16MB - val_loss: 0.58507239818573 - val_accuracy: 0.80078125
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 16/16 [==============================] - 16s 971ms/step - loss: 0.3237 - accuracy: 0.8510
# Epoch 56/120 - Time: 16.48s - Memory Usage: 8085.86MB - val_loss: 0.5923957824707031 - val_accuracy: 0.82421875
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 16/16 [==============================] - 15s 985ms/step - loss: 0.3137 - accuracy: 0.8540
# Epoch 57/120 - Time: 21.33s - Memory Usage: 8276.83MB - val_loss: 0.5961941480636597 - val_accuracy: 0.80859375
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 16/16 [==============================] - 16s 967ms/step - loss: 0.3526 - accuracy: 0.8460
# Epoch 58/120 - Time: 21.27s - Memory Usage: 8502.00MB - val_loss: 0.3651614785194397 - val_accuracy: 0.859375
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 16/16 [==============================] - 17s 1s/step - loss: 0.3114 - accuracy: 0.8620
# Epoch 59/120 - Time: 21.47s - Memory Usage: 7935.80MB - val_loss: 0.8855147361755371 - val_accuracy: 0.73828125
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 16/16 [==============================] - 15s 985ms/step - loss: 0.3142 - accuracy: 0.8570
# Epoch 60/120 - Time: 21.29s - Memory Usage: 8087.32MB - val_loss: 0.9037878513336182 - val_accuracy: 0.7265625
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 16/16 [==============================] - 15s 945ms/step - loss: 0.3406 - accuracy: 0.8420
# Epoch 61/120 - Time: 21.29s - Memory Usage: 8357.09MB - val_loss: 0.6344583034515381 - val_accuracy: 0.80859375
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 16/16 [==============================] - 16s 971ms/step - loss: 0.3196 - accuracy: 0.8410
# Epoch 62/120 - Time: 21.29s - Memory Usage: 8559.32MB - val_loss: 0.928737461566925 - val_accuracy: 0.7421875
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 16/16 [==============================] - 16s 979ms/step - loss: 0.2884 - accuracy: 0.8760
# Epoch 63/120 - Time: 17.89s - Memory Usage: 7922.30MB - val_loss: 0.7269971370697021 - val_accuracy: 0.80078125
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 16/16 [==============================] - 16s 968ms/step - loss: 0.2790 - accuracy: 0.8740
# Epoch 64/120 - Time: 16.43s - Memory Usage: 8081.12MB - val_loss: 0.5973723530769348 - val_accuracy: 0.8125
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 16/16 [==============================] - 15s 965ms/step - loss: 0.3538 - accuracy: 0.8320
# Epoch 65/120 - Time: 21.29s - Memory Usage: 8333.32MB - val_loss: 0.6865782141685486 - val_accuracy: 0.79296875
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 16/16 [==============================] - 15s 954ms/step - loss: 0.3232 - accuracy: 0.8520
# Epoch 66/120 - Time: 16.18s - Memory Usage: 8470.98MB - val_loss: 0.6808334589004517 - val_accuracy: 0.80859375
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 16/16 [==============================] - 16s 973ms/step - loss: 0.3004 - accuracy: 0.8670
# Epoch 67/120 - Time: 16.54s - Memory Usage: 7937.73MB - val_loss: 0.6560394763946533 - val_accuracy: 0.80078125
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 16/16 [==============================] - 16s 966ms/step - loss: 0.3429 - accuracy: 0.8420
# Epoch 68/120 - Time: 21.91s - Memory Usage: 8132.76MB - val_loss: 0.8490890860557556 - val_accuracy: 0.76171875
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 16/16 [==============================] - 17s 1s/step - loss: 0.3181 - accuracy: 0.8610
# Epoch 69/120 - Time: 21.30s - Memory Usage: 8266.07MB - val_loss: 0.780676007270813 - val_accuracy: 0.765625
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 16/16 [==============================] - 16s 968ms/step - loss: 0.3304 - accuracy: 0.8520
# Epoch 70/120 - Time: 16.38s - Memory Usage: 8440.85MB - val_loss: 0.7186392545700073 - val_accuracy: 0.80078125
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 16/16 [==============================] - 15s 962ms/step - loss: 0.3047 - accuracy: 0.8580
# Epoch 71/120 - Time: 16.31s - Memory Usage: 7874.08MB - val_loss: 0.911297619342804 - val_accuracy: 0.7421875
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 16/16 [==============================] - 16s 968ms/step - loss: 0.2574 - accuracy: 0.8890
# Epoch 72/120 - Time: 17.72s - Memory Usage: 8078.18MB - val_loss: 0.5921525955200195 - val_accuracy: 0.83984375
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 16/16 [==============================] - 15s 959ms/step - loss: 0.3554 - accuracy: 0.8400
# Epoch 73/120 - Time: 21.29s - Memory Usage: 8251.97MB - val_loss: 0.6311663389205933 - val_accuracy: 0.80078125
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 16/16 [==============================] - 17s 1s/step - loss: 0.3399 - accuracy: 0.8470
# Epoch 74/120 - Time: 18.14s - Memory Usage: 8407.31MB - val_loss: 0.5908973813056946 - val_accuracy: 0.80859375
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 16/16 [==============================] - 16s 968ms/step - loss: 0.2761 - accuracy: 0.8830
# Epoch 75/120 - Time: 16.47s - Memory Usage: 7897.96MB - val_loss: 0.8315795660018921 - val_accuracy: 0.78515625
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 16/16 [==============================] - 16s 972ms/step - loss: 0.2929 - accuracy: 0.8570
# Epoch 76/120 - Time: 21.31s - Memory Usage: 8038.97MB - val_loss: 0.9877453446388245 - val_accuracy: 0.7578125
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 16/16 [==============================] - 16s 968ms/step - loss: 0.2937 - accuracy: 0.8670
# Epoch 77/120 - Time: 21.30s - Memory Usage: 8253.33MB - val_loss: 0.8746973276138306 - val_accuracy: 0.7734375
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 16/16 [==============================] - 17s 1s/step - loss: 0.2837 - accuracy: 0.8740
# Epoch 78/120 - Time: 21.91s - Memory Usage: 8502.85MB - val_loss: 0.6549549698829651 - val_accuracy: 0.8203125
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 16/16 [==============================] - 16s 979ms/step - loss: 0.3697 - accuracy: 0.8230
# Epoch 79/120 - Time: 16.63s - Memory Usage: 7901.48MB - val_loss: 0.8582181930541992 - val_accuracy: 0.765625
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 16/16 [==============================] - 17s 1s/step - loss: 0.3092 - accuracy: 0.8550
# Epoch 80/120 - Time: 22.02s - Memory Usage: 8091.67MB - val_loss: 0.9518671035766602 - val_accuracy: 0.7578125
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 16/16 [==============================] - 15s 962ms/step - loss: 0.3134 - accuracy: 0.8390
# Epoch 81/120 - Time: 21.28s - Memory Usage: 8345.89MB - val_loss: 0.8255606293678284 - val_accuracy: 0.7890625
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 16/16 [==============================] - 16s 968ms/step - loss: 0.2819 - accuracy: 0.8740
# Epoch 82/120 - Time: 16.40s - Memory Usage: 8467.36MB - val_loss: 0.8531056642532349 - val_accuracy: 0.78515625
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 16/16 [==============================] - 16s 985ms/step - loss: 0.2767 - accuracy: 0.8800
# Epoch 83/120 - Time: 21.38s - Memory Usage: 7933.39MB - val_loss: 0.7787455320358276 - val_accuracy: 0.8046875
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 16/16 [==============================] - 16s 969ms/step - loss: 0.3387 - accuracy: 0.8330
# Epoch 84/120 - Time: 16.38s - Memory Usage: 8146.67MB - val_loss: 0.9063528776168823 - val_accuracy: 0.7734375
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 16/16 [==============================] - 16s 990ms/step - loss: 0.2792 - accuracy: 0.8780
# Epoch 85/120 - Time: 21.31s - Memory Usage: 8399.53MB - val_loss: 0.7179485559463501 - val_accuracy: 0.80859375
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 16/16 [==============================] - 16s 1s/step - loss: 0.2582 - accuracy: 0.8990
# Epoch 86/120 - Time: 17.24s - Memory Usage: 8517.46MB - val_loss: 0.9251055121421814 - val_accuracy: 0.77734375
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 16/16 [==============================] - 17s 1s/step - loss: 0.2987 - accuracy: 0.8700
# Epoch 87/120 - Time: 17.72s - Memory Usage: 7959.62MB - val_loss: 0.855387270450592 - val_accuracy: 0.7890625
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 16/16 [==============================] - 15s 960ms/step - loss: 0.2610 - accuracy: 0.8820
# Epoch 88/120 - Time: 16.25s - Memory Usage: 8181.25MB - val_loss: 0.797190248966217 - val_accuracy: 0.80859375
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 16/16 [==============================] - 16s 964ms/step - loss: 0.2924 - accuracy: 0.8740
# Epoch 89/120 - Time: 21.31s - Memory Usage: 8357.29MB - val_loss: 0.9594221115112305 - val_accuracy: 0.7734375
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 16/16 [==============================] - 17s 1s/step - loss: 0.2569 - accuracy: 0.8900
# Epoch 90/120 - Time: 21.28s - Memory Usage: 8585.86MB - val_loss: 0.8349408507347107 - val_accuracy: 0.80078125
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 16/16 [==============================] - 16s 975ms/step - loss: 0.2789 - accuracy: 0.8910
# Epoch 91/120 - Time: 21.30s - Memory Usage: 8025.43MB - val_loss: 0.7444990873336792 - val_accuracy: 0.8125
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 16/16 [==============================] - 16s 965ms/step - loss: 0.2563 - accuracy: 0.8860
# Epoch 92/120 - Time: 16.39s - Memory Usage: 8127.12MB - val_loss: 0.7318005561828613 - val_accuracy: 0.80859375
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 16/16 [==============================] - 16s 970ms/step - loss: 0.2943 - accuracy: 0.8730
# Epoch 93/120 - Time: 16.36s - Memory Usage: 8347.79MB - val_loss: 0.8048821091651917 - val_accuracy: 0.8046875
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 16/16 [==============================] - 16s 984ms/step - loss: 0.2469 - accuracy: 0.8950
# Epoch 94/120 - Time: 17.46s - Memory Usage: 8453.70MB - val_loss: 1.0304678678512573 - val_accuracy: 0.77734375
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 16/16 [==============================] - 16s 990ms/step - loss: 0.2574 - accuracy: 0.8790
# Epoch 95/120 - Time: 21.33s - Memory Usage: 7917.21MB - val_loss: 1.0101358890533447 - val_accuracy: 0.7734375
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 16/16 [==============================] - 16s 962ms/step - loss: 0.2681 - accuracy: 0.8820
# Epoch 96/120 - Time: 16.49s - Memory Usage: 8059.68MB - val_loss: 1.0531370639801025 - val_accuracy: 0.73828125
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 16/16 [==============================] - 15s 948ms/step - loss: 0.2781 - accuracy: 0.8810
# Epoch 97/120 - Time: 16.07s - Memory Usage: 8279.18MB - val_loss: 0.8330355286598206 - val_accuracy: 0.78125
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 16/16 [==============================] - 16s 969ms/step - loss: 0.2766 - accuracy: 0.8740
# Epoch 98/120 - Time: 16.50s - Memory Usage: 8469.81MB - val_loss: 0.8389802575111389 - val_accuracy: 0.77734375
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 16/16 [==============================] - 16s 963ms/step - loss: 0.2881 - accuracy: 0.8740
# Epoch 99/120 - Time: 16.96s - Memory Usage: 7865.69MB - val_loss: 0.8672472238540649 - val_accuracy: 0.7890625
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 16/16 [==============================] - 16s 971ms/step - loss: 0.2623 - accuracy: 0.8860
# Epoch 100/120 - Time: 21.28s - Memory Usage: 8113.95MB - val_loss: 0.8429480791091919 - val_accuracy: 0.80078125
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 16/16 [==============================] - 17s 1s/step - loss: 0.2870 - accuracy: 0.8740
# Epoch 101/120 - Time: 18.44s - Memory Usage: 8245.35MB - val_loss: 1.1038110256195068 - val_accuracy: 0.75
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 16/16 [==============================] - 15s 964ms/step - loss: 0.2654 - accuracy: 0.8920
# Epoch 102/120 - Time: 16.36s - Memory Usage: 8468.62MB - val_loss: 1.3877562284469604 - val_accuracy: 0.68359375
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 16/16 [==============================] - 16s 989ms/step - loss: 0.2992 - accuracy: 0.8520
# Epoch 103/120 - Time: 16.82s - Memory Usage: 7920.14MB - val_loss: 0.6483696103096008 - val_accuracy: 0.80859375
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 16/16 [==============================] - 15s 956ms/step - loss: 0.2546 - accuracy: 0.8900
# Epoch 104/120 - Time: 16.46s - Memory Usage: 8084.54MB - val_loss: 0.9978886842727661 - val_accuracy: 0.77734375
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 16/16 [==============================] - 15s 948ms/step - loss: 0.2384 - accuracy: 0.8940
# Epoch 105/120 - Time: 16.03s - Memory Usage: 8288.59MB - val_loss: 1.1442039012908936 - val_accuracy: 0.75
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 16/16 [==============================] - 15s 947ms/step - loss: 0.2444 - accuracy: 0.8980
# Epoch 106/120 - Time: 16.02s - Memory Usage: 8485.52MB - val_loss: 1.0429123640060425 - val_accuracy: 0.76171875
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 16/16 [==============================] - 16s 973ms/step - loss: 0.2513 - accuracy: 0.8910
# Epoch 107/120 - Time: 22.08s - Memory Usage: 7946.29MB - val_loss: 0.9022245407104492 - val_accuracy: 0.79296875
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 16/16 [==============================] - 16s 967ms/step - loss: 0.2625 - accuracy: 0.8740
# Epoch 108/120 - Time: 21.31s - Memory Usage: 8046.79MB - val_loss: 0.95991450548172 - val_accuracy: 0.7890625
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 16/16 [==============================] - 15s 963ms/step - loss: 0.2165 - accuracy: 0.9110
# Epoch 109/120 - Time: 21.25s - Memory Usage: 8316.73MB - val_loss: 0.8842523097991943 - val_accuracy: 0.8046875
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 16/16 [==============================] - 15s 949ms/step - loss: 0.3118 - accuracy: 0.8590
# Epoch 110/120 - Time: 16.12s - Memory Usage: 8476.62MB - val_loss: 0.7542125582695007 - val_accuracy: 0.80859375
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 16/16 [==============================] - 15s 986ms/step - loss: 0.2609 - accuracy: 0.8960
# Epoch 111/120 - Time: 16.28s - Memory Usage: 7801.82MB - val_loss: 1.2418925762176514 - val_accuracy: 0.734375
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 16/16 [==============================] - 18s 1s/step - loss: 0.2348 - accuracy: 0.8930
# Epoch 112/120 - Time: 21.27s - Memory Usage: 8020.36MB - val_loss: 1.251243233680725 - val_accuracy: 0.75
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 16/16 [==============================] - 15s 951ms/step - loss: 0.2717 - accuracy: 0.8800
# Epoch 113/120 - Time: 21.27s - Memory Usage: 8211.72MB - val_loss: 0.8584017157554626 - val_accuracy: 0.8046875
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 16/16 [==============================] - 15s 957ms/step - loss: 0.2668 - accuracy: 0.8810
# Epoch 114/120 - Time: 21.79s - Memory Usage: 8384.14MB - val_loss: 0.8950149416923523 - val_accuracy: 0.80078125
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 16/16 [==============================] - 16s 992ms/step - loss: 0.2351 - accuracy: 0.9060
# Epoch 115/120 - Time: 16.94s - Memory Usage: 7885.87MB - val_loss: 0.8998867273330688 - val_accuracy: 0.796875
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 16/16 [==============================] - 15s 949ms/step - loss: 0.2632 - accuracy: 0.8790
# Epoch 116/120 - Time: 16.17s - Memory Usage: 8101.25MB - val_loss: 0.8412572741508484 - val_accuracy: 0.80078125
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 16/16 [==============================] - 15s 960ms/step - loss: 0.2394 - accuracy: 0.9010
# Epoch 117/120 - Time: 16.24s - Memory Usage: 8283.68MB - val_loss: 0.9449155330657959 - val_accuracy: 0.796875
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 16/16 [==============================] - 16s 974ms/step - loss: 0.2402 - accuracy: 0.9110
# Epoch 118/120 - Time: 16.53s - Memory Usage: 8474.39MB - val_loss: 0.8293260931968689 - val_accuracy: 0.8125
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 16/16 [==============================] - 15s 980ms/step - loss: 0.2505 - accuracy: 0.8770
# Epoch 119/120 - Time: 16.99s - Memory Usage: 7852.80MB - val_loss: 0.9133058190345764 - val_accuracy: 0.796875
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 16/16 [==============================] - 15s 950ms/step - loss: 0.2436 - accuracy: 0.8910
# Epoch 120/120 - Time: 16.09s - Memory Usage: 8111.48MB - val_loss: 0.773306667804718 - val_accuracy: 0.80859375
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*

# %% [markdown]
# ###Metrics Evaluation###

# %%
predictedLabels = model.predict(testImages)
predictedClasses = np.argmax(predictedLabels, axis = 1)

report = classification_report(testLabels.argmax(axis = 1), predictedClasses)
print(report)
# Out:
# 8/8 [==============================] - 2s 99ms/step
#               precision    recall  f1-score   support
#
#            0       1.00      0.62      0.76       128
#            1       0.72      1.00      0.84       128
#
#     accuracy                           0.81       256
#    macro avg       0.86      0.81      0.80       256
# weighted avg       0.86      0.81      0.80       256

# %%
plt.figure(figsize=(8, 5))
plt.plot(range(1, num_epochs + 1), testAccuracy, color='b')
plt.xlabel('Epoch')
plt.ylabel('Test Accuracy')
plt.title('Test Accuracy over Epochs')
plt.ylim([0, 1])  # Set y-axis limit between 0 and 1
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(10, 5))

plt.subplot(1, 2, 1)
plt.plot(range(1, num_epochs + 1), training_times)
plt.xlabel('Epoch')
plt.ylabel('Time (s)')
plt.title('Training Speed per Epoch')

plt.subplot(1, 2, 2)
plt.plot(range(1, num_epochs + 1), memory_usage, color='orange')
plt.xlabel('Epoch')
plt.ylabel('Memory Usage (GB)')
plt.title('Memory Usage per Epoch')

plt.tight_layout()
plt.show()
