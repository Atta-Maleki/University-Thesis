# %% [markdown]
# ###Start###

# %% [markdown]
# This version is the most normal version of all versions. In this version unitary initialization used but BN and L2 have been removed from architecture of the model.

# %%
import tensorflow as tf
import numpy as np
import os, random
import matplotlib.pyplot as plt
from keras import layers
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras import regularizers
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras.models import load_model
from tensorflow.keras.optimizers.schedules import ExponentialDecay
from tensorflow.keras.optimizers import Adam
from imblearn.over_sampling import RandomOverSampler
from sklearn.metrics import classification_report
import time
import psutil

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
path = '/content/drive/MyDrive/tf_HH/NP_data/'
trainImages = np.load(path + 'trainImages.npy')
trainLabels = np.load(path + 'trainLabels.npy')
testImages  = np.load(path + 'testImages.npy')
testLabels  = np.load(path + 'testLabels.npy')

# %%
augmented = ImageDataGenerator(rotation_range=12,
                               width_shift_range = 0.1,
                               height_shift_range= 0.1,
                               zoom_range=0.1,
                               horizontal_flip= True)
augmented.fit(trainImages)
augmented.fit(testImages)

# %% [markdown]
# ###Data Check

# %%
#Data Loading Check
plt.imshow(trainImages[254])
print(trainImages.shape, " ", trainImages.dtype)
print(trainLabels.shape)
print(testImages.shape)
print(testLabels.shape)
# Out:
# (1000, 256, 256, 3)   float32
# (1000, 2)
# (256, 256, 256, 3)
# (256, 2)

# %%
\
classes = ['AD', 'CN']

figure, axes = plt.subplots(4, 5, figsize= (12,12))
for i in range(len(trainImages)):
  if trainLabels[i][0] == 1 :
    titleIndex = 0
  else :
    titleIndex = 1
  ax_row = i // 5
  ax_col = i % 5
  if ax_row ==4 or ax_col==5:
    break
  ax = axes[ax_row][ax_col]
  ax.imshow(trainImages[i])
  ax.set_title(classes[titleIndex])
  ax.axis('off')

plt.tight_layout()
plt.show()
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %% [markdown]
# ###Unitary Regularizer###

# %%
# used version 1.2
import tensorflow.keras.backend as K
class UnitaryRegularizer(tf.keras.regularizers.Regularizer):
    def __init__(self, lambd):
        self.lambd = lambd

    def __call__(self, weights):
        # Get the number of output neurons
        num_output_neurons = weights.shape[-1]

        # Reshape the weight matrix to be a 2D matrix (flatten filters)
        flattened_weights = tf.reshape(weights, (-1, num_output_neurons))

        # Calculate the matrix product and the identity matrix
        product = tf.matmul(flattened_weights, tf.transpose(flattened_weights))
        identity_matrix = tf.eye(product.shape[0])

        # Calculate the Frobenius norm for each filter separately
        filter_norms = tf.norm(product - identity_matrix, axis=[-2, -1])
        #print(filter_norms)

        # Calculate the regularization term as the sum of squared Frobenius norms
        regularization = 0.5 * self.lambd * tf.reduce_sum(tf.square(filter_norms))
        #tf.print(regularization)
        return regularization

    def get_config(self):
        return {'lambd': self.lambd}

# %% [markdown]
# ###MODEL

# %%
my_resnet = tf.keras.applications.ResNet50(input_shape=(256, 256, 3), include_top=False)
my_resnet.trainable = False
custom_lambd = 0.01
model = tf.keras.Sequential([
    tf.keras.layers.Input((256, 256, 3)),
    tf.keras.layers.BatchNormalization(),
    my_resnet,
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.Conv2D(filters = 256, kernel_size = (3, 3),
                             activation = tf.nn.
                           relu , name='conv1', padding='same'),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.MaxPool2D(pool_size=(2, 2), name='pool1'),
    tf.keras.layers.Conv2D(filters = 128, kernel_size = (3, 3),
                             activation = tf.nn.relu, padding='same',
                            name='conv2'),
                           #kernel_regularizer= UnitaryRegularizer(lambd=custom_lambd) ),
    tf.keras.layers.Conv2D(filters = 64, kernel_size = (3, 3),
                             activation = tf.nn.relu, name='conv3',
                            padding='same'),
    tf.keras.layers.MaxPool2D(pool_size=(2, 2), name='pool3'),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.Conv2D(filters = 32, kernel_size = (3, 3),
                           activation= tf.nn.relu, padding='same',
                           name='conv4'),
                           #kernel_regularizer= UnitaryRegularizer(lambd=custom_lambd) ),
    tf.keras.layers.Conv2D(filters = 32, kernel_size = (3, 3),
                           activation= tf.nn.relu, padding='same',
                           name='conv5'),
                           #kernel_regularizer= UnitaryRegularizer(lambd=custom_lambd) ),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(128, activation = tf.nn.relu),
    tf.keras.layers.Dense(64, activation = tf.nn.relu),
                          #kernel_regularizer=regularizers.l2(0.01)),
    tf.keras.layers.Dense(2, activation = 'sigmoid')
])
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50_weights_tf_dim_ordering_tf_kernels_notop.h5
# 94765736/94765736 [==============================] - 1s 0us/step

# %% [markdown]
# ###Unitary Initialization###

# %%
# this function below is utilizing CPU because of using NUMPY
def unitarizer(weightArr):
  unitaryMatrices = np.empty_like(weightArr)
  print("1")
  weightArr_tr = np.transpose(weightArr, (3, 2, 0, 1))
  print("2 tr: ", weightArr_tr.shape)
  U, SIGMA, V_trans = np.linalg.svd(weightArr_tr)
  print("3 ", V_trans.shape)
  W = V_trans.T
  print("4 ", W.shape)
  W = np.reshape(W, weightArr.shape)
  print("5")
  #unitaryMatrices[:,:,i,j] = unitarySingleKernel
  return W

# %%
trainableWeights = model.trainable_weights
print("the shape of trainable weights in first conv", trainableWeights[16].shape)
# Out:
# the shape of trainable weights in first conv (3, 3, 32, 32)

# %%
indecies = [8, 14, 16]

for idx in indecies:
  print("***********************  Convolution is unitarizing ", idx, " ************************")
  convWeights  = trainableWeights[idx]
  print(convWeights.shape)
  U_convWeights = unitarizer(convWeights)
  print(U_convWeights[0][0][16][16])
  print("*************************  Convolution unitarized ", idx, "  *************************")
  model.trainable_weights[idx].assign(U_convWeights)
  convtester = model.trainable_weights[idx]
  print("************************* Convolution unitaryCheck ", idx, " *************************")
  print(convtester[0][0][16][16])
# Out:
# ***********************  Convolution is unitarizing  8  ************************
# (3, 3, 256, 128)
# 1
# 2 tr:  (128, 256, 3, 3)
# 3  (128, 256, 3, 3)
# 4  (3, 3, 256, 128)
# 5
# 0.7739001
# *************************  Convolution unitarized  8   *************************
# ************************* Convolution unitaryCheck  8  *************************
# tf.Tensor(0.7739001, shape=(), dtype=float32)
# ***********************  Convolution is unitarizing  14  ************************
# (3, 3, 64, 32)
# 1
# 2 tr:  (32, 64, 3, 3)
# 3  (32, 64, 3, 3)
# 4  (3, 3, 64, 32)
# 5
# 0.6513524
# *************************  Convolution unitarized  14   *************************
# ************************* Convolution unitaryCheck  14  *************************
# tf.Tensor(0.6513524, shape=(), dtype=float32)
# ***********************  Convolution is unitarizing  16  ************************
# (3, 3, 32, 32)
# 1
# 2 tr:  (32, 32, 3, 3)
# 3  (32, 32, 3, 3)
# 4  (3, 3, 32, 32)
# 5
# 0.66046655
# *************************  Convolution unitarized  16   *************************
# ************************* Convolution unitaryCheck  16  *************************
# tf.Tensor(0.66046655, shape=(), dtype=float32)

# %%
#not needed when we regularize it.
model.layers[6].trainable=False
model.layers[10].trainable=False
model.layers[11].trainable=False

# %% [markdown]
# ###Model compile###

# %%
model.compile(optimizer='sgd', loss='binary_crossentropy', metrics=['accuracy'])

# %%
checkpointPath = "/content/drive/MyDrive/Kag-adni-unBalance/finalCheckPoints/FinalRuns3/"

checkPointCallBack = ModelCheckpoint(filepath = checkpointPath,
                                     monitor = 'val_accuracy',
                                     mode='max', save_best_only = True)

# %% [markdown]
# ###Model Check

# %%
tf.keras.utils.plot_model(model, show_shapes = True,
                          show_layer_activations=True, show_trainable= True)

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  batch_normalization (BatchN  (None, 256, 256, 3)      12
#  ormalization)
#
#  resnet50 (Functional)       (None, 8, 8, 2048)        23587712
#
#  batch_normalization_1 (Batc  (None, 8, 8, 2048)       8192
#  hNormalization)
#
#  conv1 (Conv2D)              (None, 8, 8, 256)         4718848
#
#  batch_normalization_2 (Batc  (None, 8, 8, 256)        1024
#  hNormalization)
#
#  pool1 (MaxPooling2D)        (None, 4, 4, 256)         0
#
#  conv2 (Conv2D)              (None, 4, 4, 128)         295040
#
#  conv3 (Conv2D)              (None, 4, 4, 64)          73792
#
#  pool3 (MaxPooling2D)        (None, 2, 2, 64)          0
#
#  batch_normalization_3 (Batc  (None, 2, 2, 64)         256
#  hNormalization)
#
#  conv4 (Conv2D)              (None, 2, 2, 32)          18464
#
#  conv5 (Conv2D)              (None, 2, 2, 32)          9248
#
#  batch_normalization_4 (Batc  (None, 2, 2, 32)         128
#  hNormalization)
#
#  flatten (Flatten)           (None, 128)               0
#
#  dense (Dense)               (None, 128)               16512
#
#  dense_1 (Dense)             (None, 64)                8256
#
#  dense_2 (Dense)             (None, 2)                 130
#
# =================================================================
# Total params: 28,737,614
# Trainable params: 4,822,344
# Non-trainable params: 23,915,270
# _________________________________________________________________

# %% [markdown]
# ###RUN###

# %%
training_times = []
memory_usage = []
testAccuracy = []
num_epochs = 120
for epoch in range(num_epochs):
  startTime = time.time()
  history = model.fit(augmented.flow(trainImages, trainLabels, batch_size = 64),
                    epochs = 1)
          #validation_data=(testImages, testLabels))
                    #callbacks=[checkPointCallBack])#with version 1.2
  endTime = time.time()
  epochTime = endTime - startTime
  training_times.append(epochTime)
  memory_usage.append(psutil.virtual_memory().used/1024**2)
  testLoss , testAcc = model.evaluate(testImages, testLabels, verbose = 0)
  testAccuracy.append(testAcc)
  print(f"Epoch {epoch + 1}/{num_epochs} - Time: {epochTime:.2f}s - Memory Usage: {memory_usage[-1]:.2f}MB - val_loss: {testLoss} - val_accuracy: {testAcc}")
  print("*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*")
# Out:
# 16/16 [==============================] - 41s 1s/step - loss: 0.6198 - accuracy: 0.7090
# Epoch 1/120 - Time: 46.90s - Memory Usage: 5464.52MB - val_loss: 3.750013589859009 - val_accuracy: 0.5
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 16/16 [==============================] - 18s 1s/step - loss: 0.4491 - accuracy: 0.8670
# Epoch 2/120 - Time: 19.11s - Memory Usage: 5788.62MB - val_loss: 1.2483211755752563 - val_accuracy: 0.5
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 16/16 [==============================] - 21s 1s/step - loss: 0.3619 - accuracy: 0.8870
# Epoch 3/120 - Time: 21.56s - Memory Usage: 6109.93MB - val_loss: 0.6852099895477295 - val_accuracy: 0.56640625
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 16/16 [==============================] - 19s 1s/step - loss: 0.2734 - accuracy: 0.9280
# Epoch 4/120 - Time: 19.54s - Memory Usage: 6369.61MB - val_loss: 0.47799164056777954 - val_accuracy: 0.76171875
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 16/16 [==============================] - 18s 1s/step - loss: 0.2068 - accuracy: 0.9510
# Epoch 5/120 - Time: 18.78s - Memory Usage: 6540.50MB - val_loss: 0.3972601294517517 - val_accuracy: 0.83203125
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 16/16 [==============================] - 19s 1s/step - loss: 0.1712 - accuracy: 0.9570
# Epoch 6/120 - Time: 19.50s - Memory Usage: 6205.64MB - val_loss: 0.2963330149650574 - val_accuracy: 0.87890625
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 16/16 [==============================] - 18s 1s/step - loss: 0.1364 - accuracy: 0.9710
# Epoch 7/120 - Time: 18.78s - Memory Usage: 6544.29MB - val_loss: 0.3624555468559265 - val_accuracy: 0.875
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 16/16 [==============================] - 19s 1s/step - loss: 0.1034 - accuracy: 0.9730
# Epoch 8/120 - Time: 21.29s - Memory Usage: 6634.97MB - val_loss: 0.30839961767196655 - val_accuracy: 0.8984375
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 16/16 [==============================] - 18s 1s/step - loss: 0.0944 - accuracy: 0.9770
# Epoch 9/120 - Time: 21.28s - Memory Usage: 6822.70MB - val_loss: 0.29672324657440186 - val_accuracy: 0.8984375
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 16/16 [==============================] - 18s 1s/step - loss: 0.0905 - accuracy: 0.9770
# Epoch 10/120 - Time: 19.70s - Memory Usage: 6594.78MB - val_loss: 0.30719122290611267 - val_accuracy: 0.90234375
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 16/16 [==============================] - 18s 1s/step - loss: 0.0763 - accuracy: 0.9810
# Epoch 11/120 - Time: 21.27s - Memory Usage: 6887.89MB - val_loss: 0.293707937002182 - val_accuracy: 0.90625
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 16/16 [==============================] - 18s 1s/step - loss: 0.0708 - accuracy: 0.9820
# Epoch 12/120 - Time: 18.88s - Memory Usage: 7118.70MB - val_loss: 0.31322941184043884 - val_accuracy: 0.90234375
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 16/16 [==============================] - 19s 1s/step - loss: 0.0559 - accuracy: 0.9870
# Epoch 13/120 - Time: 20.13s - Memory Usage: 7499.32MB - val_loss: 0.2506314814090729 - val_accuracy: 0.9140625
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 16/16 [==============================] - 18s 1s/step - loss: 0.0479 - accuracy: 0.9890
# Epoch 14/120 - Time: 21.32s - Memory Usage: 7062.60MB - val_loss: 0.2175210416316986 - val_accuracy: 0.91796875
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 16/16 [==============================] - 21s 1s/step - loss: 0.0512 - accuracy: 0.9890
# Epoch 15/120 - Time: 42.51s - Memory Usage: 7283.68MB - val_loss: 0.22662095725536346 - val_accuracy: 0.92578125
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 16/16 [==============================] - 18s 1s/step - loss: 0.0438 - accuracy: 0.9900
# Epoch 16/120 - Time: 19.51s - Memory Usage: 7568.33MB - val_loss: 0.19805775582790375 - val_accuracy: 0.921875
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 16/16 [==============================] - 18s 1s/step - loss: 0.0369 - accuracy: 0.9920
# Epoch 17/120 - Time: 21.27s - Memory Usage: 7698.96MB - val_loss: 0.20438623428344727 - val_accuracy: 0.91796875
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 16/16 [==============================] - 18s 1s/step - loss: 0.0443 - accuracy: 0.9860
# Epoch 18/120 - Time: 18.52s - Memory Usage: 7150.02MB - val_loss: 0.18334895372390747 - val_accuracy: 0.94140625
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 16/16 [==============================] - 19s 1s/step - loss: 0.0331 - accuracy: 0.9950
# Epoch 19/120 - Time: 21.25s - Memory Usage: 7346.33MB - val_loss: 0.199778750538826 - val_accuracy: 0.94140625
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 16/16 [==============================] - 18s 1s/step - loss: 0.0294 - accuracy: 0.9930
# Epoch 20/120 - Time: 18.62s - Memory Usage: 7464.20MB - val_loss: 0.22083212435245514 - val_accuracy: 0.921875
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 16/16 [==============================] - 19s 1s/step - loss: 0.0345 - accuracy: 0.9910
# Epoch 21/120 - Time: 19.88s - Memory Usage: 7678.62MB - val_loss: 0.188723623752594 - val_accuracy: 0.9453125
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 16/16 [==============================] - 18s 1s/step - loss: 0.0172 - accuracy: 0.9990
# Epoch 22/120 - Time: 18.98s - Memory Usage: 7204.16MB - val_loss: 0.19413447380065918 - val_accuracy: 0.94140625
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 16/16 [==============================] - 19s 1s/step - loss: 0.0239 - accuracy: 0.9940
# Epoch 23/120 - Time: 19.82s - Memory Usage: 7414.90MB - val_loss: 0.2282441407442093 - val_accuracy: 0.93359375
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 16/16 [==============================] - 18s 1s/step - loss: 0.0167 - accuracy: 0.9980
# Epoch 24/120 - Time: 18.31s - Memory Usage: 7607.17MB - val_loss: 0.25966039299964905 - val_accuracy: 0.91796875
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 16/16 [==============================] - 20s 1s/step - loss: 0.0279 - accuracy: 0.9940
# Epoch 25/120 - Time: 21.25s - Memory Usage: 7742.86MB - val_loss: 0.22456765174865723 - val_accuracy: 0.93359375
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 16/16 [==============================] - 18s 1s/step - loss: 0.0242 - accuracy: 0.9920
# Epoch 26/120 - Time: 18.61s - Memory Usage: 7207.63MB - val_loss: 0.2902136743068695 - val_accuracy: 0.90625
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 16/16 [==============================] - 20s 1s/step - loss: 0.0211 - accuracy: 0.9950
# Epoch 27/120 - Time: 20.77s - Memory Usage: 6704.71MB - val_loss: 0.3120603561401367 - val_accuracy: 0.9140625
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 16/16 [==============================] - 18s 1s/step - loss: 0.0273 - accuracy: 0.9890
# Epoch 28/120 - Time: 18.50s - Memory Usage: 6827.97MB - val_loss: 0.23375537991523743 - val_accuracy: 0.92578125
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 16/16 [==============================] - 18s 1s/step - loss: 0.0140 - accuracy: 0.9980
# Epoch 29/120 - Time: 18.49s - Memory Usage: 7069.96MB - val_loss: 0.2513904273509979 - val_accuracy: 0.9296875
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 16/16 [==============================] - 18s 1s/step - loss: 0.0131 - accuracy: 0.9980
# Epoch 30/120 - Time: 21.83s - Memory Usage: 7256.84MB - val_loss: 0.25669947266578674 - val_accuracy: 0.93359375
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 16/16 [==============================] - 19s 1s/step - loss: 0.0166 - accuracy: 0.9950
# Epoch 31/120 - Time: 19.88s - Memory Usage: 6933.89MB - val_loss: 0.25760793685913086 - val_accuracy: 0.921875
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 16/16 [==============================] - 18s 1s/step - loss: 0.0165 - accuracy: 0.9980
# Epoch 32/120 - Time: 21.28s - Memory Usage: 7001.80MB - val_loss: 0.325548380613327 - val_accuracy: 0.8984375
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 16/16 [==============================] - 18s 1s/step - loss: 0.0096 - accuracy: 1.0000
# Epoch 33/120 - Time: 21.86s - Memory Usage: 7195.57MB - val_loss: 0.3790554404258728 - val_accuracy: 0.89453125
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 16/16 [==============================] - 18s 1s/step - loss: 0.0121 - accuracy: 0.9980
# Epoch 34/120 - Time: 21.24s - Memory Usage: 7337.39MB - val_loss: 0.39441603422164917 - val_accuracy: 0.88671875
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 16/16 [==============================] - 18s 1s/step - loss: 0.0139 - accuracy: 0.9960
# Epoch 35/120 - Time: 19.12s - Memory Usage: 7010.92MB - val_loss: 0.43884629011154175 - val_accuracy: 0.87890625
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 16/16 [==============================] - 19s 1s/step - loss: 0.0140 - accuracy: 0.9940
# Epoch 36/120 - Time: 21.88s - Memory Usage: 7249.32MB - val_loss: 0.4131438732147217 - val_accuracy: 0.89453125
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 16/16 [==============================] - 18s 1s/step - loss: 0.0072 - accuracy: 1.0000
# Epoch 37/120 - Time: 21.25s - Memory Usage: 7422.82MB - val_loss: 0.43372654914855957 - val_accuracy: 0.88671875
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 16/16 [==============================] - 18s 1s/step - loss: 0.0192 - accuracy: 0.9940
# Epoch 38/120 - Time: 18.80s - Memory Usage: 7612.48MB - val_loss: 0.45636487007141113 - val_accuracy: 0.8828125
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 16/16 [==============================] - 20s 1s/step - loss: 0.0133 - accuracy: 0.9970
# Epoch 39/120 - Time: 20.63s - Memory Usage: 7224.18MB - val_loss: 0.5357738733291626 - val_accuracy: 0.8671875
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 16/16 [==============================] - 18s 1s/step - loss: 0.0087 - accuracy: 1.0000
# Epoch 40/120 - Time: 18.38s - Memory Usage: 7493.91MB - val_loss: 0.5846160650253296 - val_accuracy: 0.86328125
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 16/16 [==============================] - 18s 1s/step - loss: 0.0078 - accuracy: 0.9990
# Epoch 41/120 - Time: 19.20s - Memory Usage: 7756.73MB - val_loss: 0.620622992515564 - val_accuracy: 0.859375
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 16/16 [==============================] - 18s 1s/step - loss: 0.0154 - accuracy: 0.9950
# Epoch 42/120 - Time: 21.24s - Memory Usage: 7874.71MB - val_loss: 0.5398963689804077 - val_accuracy: 0.86328125
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 16/16 [==============================] - 19s 1s/step - loss: 0.0103 - accuracy: 0.9980
# Epoch 43/120 - Time: 21.74s - Memory Usage: 7310.12MB - val_loss: 0.5301677584648132 - val_accuracy: 0.87109375
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 16/16 [==============================] - 18s 1s/step - loss: 0.0132 - accuracy: 0.9970
# Epoch 44/120 - Time: 18.62s - Memory Usage: 7503.61MB - val_loss: 0.6292487978935242 - val_accuracy: 0.8515625
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 16/16 [==============================] - 18s 1s/step - loss: 0.0084 - accuracy: 0.9990
# Epoch 45/120 - Time: 21.84s - Memory Usage: 7731.77MB - val_loss: 0.6896153092384338 - val_accuracy: 0.83984375
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 16/16 [==============================] - 20s 1s/step - loss: 0.0088 - accuracy: 0.9990
# Epoch 46/120 - Time: 21.25s - Memory Usage: 7927.00MB - val_loss: 0.6590514779090881 - val_accuracy: 0.84375
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 16/16 [==============================] - 18s 1s/step - loss: 0.0113 - accuracy: 0.9980
# Epoch 47/120 - Time: 21.28s - Memory Usage: 7341.77MB - val_loss: 0.7078279852867126 - val_accuracy: 0.83984375
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 16/16 [==============================] - 18s 1s/step - loss: 0.0050 - accuracy: 1.0000
# Epoch 48/120 - Time: 19.58s - Memory Usage: 7546.95MB - val_loss: 0.6147622466087341 - val_accuracy: 0.859375
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 16/16 [==============================] - 18s 1s/step - loss: 0.0100 - accuracy: 0.9980
# Epoch 49/120 - Time: 18.42s - Memory Usage: 7727.50MB - val_loss: 0.6411762237548828 - val_accuracy: 0.859375
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 16/16 [==============================] - 18s 1s/step - loss: 0.0078 - accuracy: 0.9980
# Epoch 50/120 - Time: 21.90s - Memory Usage: 7927.83MB - val_loss: 0.7089071273803711 - val_accuracy: 0.8515625
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 16/16 [==============================] - 18s 1s/step - loss: 0.0058 - accuracy: 0.9990
# Epoch 51/120 - Time: 19.40s - Memory Usage: 7367.66MB - val_loss: 0.7447589635848999 - val_accuracy: 0.84375
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 16/16 [==============================] - 18s 1s/step - loss: 0.0091 - accuracy: 0.9980
# Epoch 52/120 - Time: 21.24s - Memory Usage: 7502.36MB - val_loss: 0.6394004821777344 - val_accuracy: 0.8515625
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 16/16 [==============================] - 19s 1s/step - loss: 0.0312 - accuracy: 0.9900
# Epoch 53/120 - Time: 21.25s - Memory Usage: 7702.15MB - val_loss: 0.7932267189025879 - val_accuracy: 0.84765625
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 16/16 [==============================] - 18s 1s/step - loss: 0.0176 - accuracy: 0.9940
# Epoch 54/120 - Time: 18.49s - Memory Usage: 7875.98MB - val_loss: 0.7849389314651489 - val_accuracy: 0.84375
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 16/16 [==============================] - 19s 1s/step - loss: 0.0171 - accuracy: 0.9950
# Epoch 55/120 - Time: 21.91s - Memory Usage: 7323.50MB - val_loss: 0.8066611289978027 - val_accuracy: 0.8359375
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 16/16 [==============================] - 18s 1s/step - loss: 0.0073 - accuracy: 0.9990
# Epoch 56/120 - Time: 21.23s - Memory Usage: 7506.66MB - val_loss: 0.7544370293617249 - val_accuracy: 0.84375
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 16/16 [==============================] - 18s 1s/step - loss: 0.0093 - accuracy: 0.9970
# Epoch 57/120 - Time: 21.85s - Memory Usage: 7763.89MB - val_loss: 0.7230570316314697 - val_accuracy: 0.85546875
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 16/16 [==============================] - 18s 1s/step - loss: 0.0120 - accuracy: 0.9960
# Epoch 58/120 - Time: 18.82s - Memory Usage: 7919.57MB - val_loss: 0.6915018558502197 - val_accuracy: 0.85546875
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 16/16 [==============================] - 18s 1s/step - loss: 0.0063 - accuracy: 0.9990
# Epoch 59/120 - Time: 18.67s - Memory Usage: 7371.16MB - val_loss: 0.6657496690750122 - val_accuracy: 0.8515625
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 16/16 [==============================] - 18s 1s/step - loss: 0.0123 - accuracy: 0.9940
# Epoch 60/120 - Time: 21.68s - Memory Usage: 7523.50MB - val_loss: 0.6649722456932068 - val_accuracy: 0.85546875
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 16/16 [==============================] - 19s 1s/step - loss: 0.0051 - accuracy: 1.0000
# Epoch 61/120 - Time: 19.39s - Memory Usage: 7685.75MB - val_loss: 0.7508973479270935 - val_accuracy: 0.8359375
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 16/16 [==============================] - 19s 1s/step - loss: 0.0058 - accuracy: 0.9990
# Epoch 62/120 - Time: 19.56s - Memory Usage: 7906.34MB - val_loss: 0.67974853515625 - val_accuracy: 0.8515625
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 16/16 [==============================] - 19s 1s/step - loss: 0.0053 - accuracy: 0.9990
# Epoch 63/120 - Time: 19.42s - Memory Usage: 7267.22MB - val_loss: 0.9011744856834412 - val_accuracy: 0.8203125
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 16/16 [==============================] - 18s 1s/step - loss: 0.0049 - accuracy: 0.9980
# Epoch 64/120 - Time: 21.24s - Memory Usage: 7562.99MB - val_loss: 0.91530841588974 - val_accuracy: 0.8203125
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 16/16 [==============================] - 19s 1s/step - loss: 0.0082 - accuracy: 0.9960
# Epoch 65/120 - Time: 21.69s - Memory Usage: 7755.48MB - val_loss: 0.7661957740783691 - val_accuracy: 0.828125
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 16/16 [==============================] - 18s 1s/step - loss: 0.0083 - accuracy: 0.9970
# Epoch 66/120 - Time: 21.25s - Memory Usage: 7953.67MB - val_loss: 0.8597322702407837 - val_accuracy: 0.8203125
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 16/16 [==============================] - 19s 1s/step - loss: 0.0077 - accuracy: 0.9980
# Epoch 67/120 - Time: 19.75s - Memory Usage: 7359.88MB - val_loss: 0.7852654457092285 - val_accuracy: 0.83203125
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 16/16 [==============================] - 18s 1s/step - loss: 0.0028 - accuracy: 1.0000
# Epoch 68/120 - Time: 21.23s - Memory Usage: 7579.39MB - val_loss: 0.8029515743255615 - val_accuracy: 0.83203125
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 16/16 [==============================] - 17s 1s/step - loss: 0.0038 - accuracy: 1.0000
# Epoch 69/120 - Time: 18.21s - Memory Usage: 7822.60MB - val_loss: 0.7881674766540527 - val_accuracy: 0.83203125
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 16/16 [==============================] - 19s 1s/step - loss: 0.0041 - accuracy: 1.0000
# Epoch 70/120 - Time: 19.61s - Memory Usage: 8036.22MB - val_loss: 0.7935078740119934 - val_accuracy: 0.83203125
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 16/16 [==============================] - 18s 1s/step - loss: 0.0027 - accuracy: 1.0000
# Epoch 71/120 - Time: 18.69s - Memory Usage: 7451.18MB - val_loss: 0.808373749256134 - val_accuracy: 0.83203125
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 16/16 [==============================] - 19s 1s/step - loss: 0.0062 - accuracy: 0.9980
# Epoch 72/120 - Time: 19.85s - Memory Usage: 7636.00MB - val_loss: 0.7818611860275269 - val_accuracy: 0.83984375
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 16/16 [==============================] - 21s 1s/step - loss: 0.0048 - accuracy: 0.9990
# Epoch 73/120 - Time: 21.33s - Memory Usage: 7897.86MB - val_loss: 0.7218554019927979 - val_accuracy: 0.83984375
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 16/16 [==============================] - 18s 1s/step - loss: 0.0049 - accuracy: 0.9990
# Epoch 74/120 - Time: 21.82s - Memory Usage: 8030.15MB - val_loss: 0.8418182730674744 - val_accuracy: 0.82421875
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 16/16 [==============================] - 18s 1s/step - loss: 0.0037 - accuracy: 1.0000
# Epoch 75/120 - Time: 18.48s - Memory Usage: 7401.86MB - val_loss: 0.776951014995575 - val_accuracy: 0.83984375
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 16/16 [==============================] - 19s 1s/step - loss: 0.0028 - accuracy: 0.9990
# Epoch 76/120 - Time: 19.71s - Memory Usage: 7559.32MB - val_loss: 0.7804692387580872 - val_accuracy: 0.8359375
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 16/16 [==============================] - 18s 1s/step - loss: 0.0023 - accuracy: 1.0000
# Epoch 77/120 - Time: 18.88s - Memory Usage: 7682.44MB - val_loss: 0.7738624215126038 - val_accuracy: 0.84375
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 16/16 [==============================] - 19s 1s/step - loss: 0.0101 - accuracy: 0.9960
# Epoch 78/120 - Time: 21.26s - Memory Usage: 7898.47MB - val_loss: 0.8383710384368896 - val_accuracy: 0.8359375
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 16/16 [==============================] - 19s 1s/step - loss: 0.0037 - accuracy: 0.9990
# Epoch 79/120 - Time: 19.73s - Memory Usage: 7358.26MB - val_loss: 0.8495678305625916 - val_accuracy: 0.84375
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 16/16 [==============================] - 18s 1s/step - loss: 0.0038 - accuracy: 0.9990
# Epoch 80/120 - Time: 21.26s - Memory Usage: 7515.38MB - val_loss: 0.7528543472290039 - val_accuracy: 0.84375
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 16/16 [==============================] - 18s 1s/step - loss: 0.0034 - accuracy: 0.9990
# Epoch 81/120 - Time: 21.85s - Memory Usage: 7718.72MB - val_loss: 0.7631280422210693 - val_accuracy: 0.84375
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 16/16 [==============================] - 19s 1s/step - loss: 0.0038 - accuracy: 1.0000
# Epoch 82/120 - Time: 21.28s - Memory Usage: 7931.71MB - val_loss: 0.8499558568000793 - val_accuracy: 0.84375
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 16/16 [==============================] - 18s 1s/step - loss: 0.0036 - accuracy: 0.9980
# Epoch 83/120 - Time: 18.64s - Memory Usage: 7304.26MB - val_loss: 0.8202970027923584 - val_accuracy: 0.84375
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 16/16 [==============================] - 19s 1s/step - loss: 0.0051 - accuracy: 0.9980
# Epoch 84/120 - Time: 19.96s - Memory Usage: 7519.15MB - val_loss: 0.8292557001113892 - val_accuracy: 0.8359375
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 16/16 [==============================] - 18s 1s/step - loss: 0.0028 - accuracy: 1.0000
# Epoch 85/120 - Time: 18.43s - Memory Usage: 7763.83MB - val_loss: 0.7681837677955627 - val_accuracy: 0.85546875
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 16/16 [==============================] - 19s 1s/step - loss: 0.0035 - accuracy: 0.9990
# Epoch 86/120 - Time: 21.25s - Memory Usage: 7973.23MB - val_loss: 0.722808301448822 - val_accuracy: 0.85546875
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 16/16 [==============================] - 18s 1s/step - loss: 0.0056 - accuracy: 0.9980
# Epoch 87/120 - Time: 21.28s - Memory Usage: 7390.42MB - val_loss: 0.7766574025154114 - val_accuracy: 0.85546875
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 16/16 [==============================] - 19s 1s/step - loss: 0.0024 - accuracy: 1.0000
# Epoch 88/120 - Time: 20.74s - Memory Usage: 7572.01MB - val_loss: 0.7924666404724121 - val_accuracy: 0.85546875
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 16/16 [==============================] - 18s 1s/step - loss: 0.0028 - accuracy: 0.9990
# Epoch 89/120 - Time: 18.42s - Memory Usage: 7764.54MB - val_loss: 0.8320410251617432 - val_accuracy: 0.8515625
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 16/16 [==============================] - 18s 1s/step - loss: 0.0031 - accuracy: 1.0000
# Epoch 90/120 - Time: 21.75s - Memory Usage: 7965.46MB - val_loss: 0.8601519465446472 - val_accuracy: 0.83203125
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 16/16 [==============================] - 19s 1s/step - loss: 0.0022 - accuracy: 1.0000
# Epoch 91/120 - Time: 19.91s - Memory Usage: 7379.69MB - val_loss: 0.861936628818512 - val_accuracy: 0.83203125
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 16/16 [==============================] - 18s 1s/step - loss: 0.0025 - accuracy: 1.0000
# Epoch 92/120 - Time: 21.25s - Memory Usage: 7507.86MB - val_loss: 0.8586673140525818 - val_accuracy: 0.8359375
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 16/16 [==============================] - 18s 1s/step - loss: 0.0059 - accuracy: 0.9990
# Epoch 93/120 - Time: 19.65s - Memory Usage: 7704.28MB - val_loss: 0.8602712154388428 - val_accuracy: 0.83203125
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 16/16 [==============================] - 18s 1s/step - loss: 0.0071 - accuracy: 0.9980
# Epoch 94/120 - Time: 21.29s - Memory Usage: 7957.05MB - val_loss: 0.8379198312759399 - val_accuracy: 0.83984375
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 16/16 [==============================] - 18s 1s/step - loss: 0.0045 - accuracy: 0.9990
# Epoch 95/120 - Time: 21.29s - Memory Usage: 7385.60MB - val_loss: 0.8577671051025391 - val_accuracy: 0.83984375
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 16/16 [==============================] - 19s 1s/step - loss: 0.0034 - accuracy: 1.0000
# Epoch 96/120 - Time: 20.11s - Memory Usage: 7564.65MB - val_loss: 0.8739771842956543 - val_accuracy: 0.828125
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 16/16 [==============================] - 18s 1s/step - loss: 0.0038 - accuracy: 0.9990
# Epoch 97/120 - Time: 21.23s - Memory Usage: 7814.39MB - val_loss: 0.9722768068313599 - val_accuracy: 0.81640625
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 16/16 [==============================] - 19s 1s/step - loss: 0.0038 - accuracy: 0.9990
# Epoch 98/120 - Time: 20.30s - Memory Usage: 8006.84MB - val_loss: 0.8796408772468567 - val_accuracy: 0.83984375
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 16/16 [==============================] - 19s 1s/step - loss: 0.0050 - accuracy: 0.9990
# Epoch 99/120 - Time: 21.28s - Memory Usage: 7432.89MB - val_loss: 0.894279956817627 - val_accuracy: 0.82421875
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 16/16 [==============================] - 18s 1s/step - loss: 0.0054 - accuracy: 0.9990
# Epoch 100/120 - Time: 21.35s - Memory Usage: 7550.93MB - val_loss: 0.9644770622253418 - val_accuracy: 0.81640625
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 16/16 [==============================] - 19s 1s/step - loss: 0.0034 - accuracy: 0.9990
# Epoch 101/120 - Time: 19.97s - Memory Usage: 7693.75MB - val_loss: 1.0004903078079224 - val_accuracy: 0.81640625
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 16/16 [==============================] - 18s 1s/step - loss: 0.0026 - accuracy: 1.0000
# Epoch 102/120 - Time: 18.53s - Memory Usage: 7974.01MB - val_loss: 1.0174353122711182 - val_accuracy: 0.81640625
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 16/16 [==============================] - 20s 1s/step - loss: 0.0033 - accuracy: 0.9990
# Epoch 103/120 - Time: 20.56s - Memory Usage: 7382.37MB - val_loss: 1.0812053680419922 - val_accuracy: 0.80859375
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 16/16 [==============================] - 18s 1s/step - loss: 0.0027 - accuracy: 0.9990
# Epoch 104/120 - Time: 19.03s - Memory Usage: 7548.17MB - val_loss: 0.9871487617492676 - val_accuracy: 0.81640625
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 16/16 [==============================] - 20s 1s/step - loss: 0.0019 - accuracy: 1.0000
# Epoch 105/120 - Time: 20.40s - Memory Usage: 7773.34MB - val_loss: 1.0148255825042725 - val_accuracy: 0.81640625
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 16/16 [==============================] - 18s 1s/step - loss: 0.0023 - accuracy: 1.0000
# Epoch 106/120 - Time: 21.26s - Memory Usage: 8037.69MB - val_loss: 1.00909423828125 - val_accuracy: 0.81640625
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 16/16 [==============================] - 18s 1s/step - loss: 0.0030 - accuracy: 0.9990
# Epoch 107/120 - Time: 21.73s - Memory Usage: 7491.57MB - val_loss: 0.8181293606758118 - val_accuracy: 0.8515625
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 16/16 [==============================] - 19s 1s/step - loss: 0.0017 - accuracy: 1.0000
# Epoch 108/120 - Time: 19.68s - Memory Usage: 7740.51MB - val_loss: 0.8186675310134888 - val_accuracy: 0.8515625
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 16/16 [==============================] - 19s 1s/step - loss: 0.0035 - accuracy: 0.9990
# Epoch 109/120 - Time: 21.23s - Memory Usage: 7871.22MB - val_loss: 0.8531244397163391 - val_accuracy: 0.83984375
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 16/16 [==============================] - 20s 1s/step - loss: 0.0062 - accuracy: 0.9980
# Epoch 110/120 - Time: 21.10s - Memory Usage: 8054.45MB - val_loss: 0.8499128818511963 - val_accuracy: 0.8515625
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 16/16 [==============================] - 18s 1s/step - loss: 0.0015 - accuracy: 1.0000
# Epoch 111/120 - Time: 18.44s - Memory Usage: 7370.63MB - val_loss: 0.9011704921722412 - val_accuracy: 0.84765625
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 16/16 [==============================] - 18s 1s/step - loss: 0.0021 - accuracy: 0.9990
# Epoch 112/120 - Time: 19.51s - Memory Usage: 7551.08MB - val_loss: 0.917100727558136 - val_accuracy: 0.83984375
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 16/16 [==============================] - 18s 1s/step - loss: 0.0032 - accuracy: 1.0000
# Epoch 113/120 - Time: 21.27s - Memory Usage: 7776.14MB - val_loss: 0.9742667078971863 - val_accuracy: 0.82421875
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 16/16 [==============================] - 18s 1s/step - loss: 0.0013 - accuracy: 1.0000
# Epoch 114/120 - Time: 18.37s - Memory Usage: 7919.59MB - val_loss: 0.9534875154495239 - val_accuracy: 0.828125
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 16/16 [==============================] - 18s 1s/step - loss: 0.0036 - accuracy: 0.9990
# Epoch 115/120 - Time: 18.85s - Memory Usage: 7403.58MB - val_loss: 0.9458240866661072 - val_accuracy: 0.828125
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 16/16 [==============================] - 18s 1s/step - loss: 0.0052 - accuracy: 0.9980
# Epoch 116/120 - Time: 19.08s - Memory Usage: 7595.79MB - val_loss: 0.9249014854431152 - val_accuracy: 0.84375
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 16/16 [==============================] - 18s 1s/step - loss: 0.0021 - accuracy: 1.0000
# Epoch 117/120 - Time: 21.25s - Memory Usage: 7781.61MB - val_loss: 0.8851287364959717 - val_accuracy: 0.84765625
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 16/16 [==============================] - 18s 1s/step - loss: 0.0044 - accuracy: 0.9990
# Epoch 118/120 - Time: 21.27s - Memory Usage: 8028.50MB - val_loss: 0.8597521781921387 - val_accuracy: 0.8515625
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 16/16 [==============================] - 18s 1s/step - loss: 0.0022 - accuracy: 1.0000
# Epoch 119/120 - Time: 19.56s - Memory Usage: 7386.38MB - val_loss: 0.8527389764785767 - val_accuracy: 0.8515625
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 16/16 [==============================] - 19s 1s/step - loss: 0.0021 - accuracy: 0.9990
# Epoch 120/120 - Time: 21.24s - Memory Usage: 7522.64MB - val_loss: 0.869136393070221 - val_accuracy: 0.8515625
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*

# %% [markdown]
# ###Metrics Evaluation###

# %%
predictedLabels = model.predict(testImages)
predictedClasses = np.argmax(predictedLabels, axis = 1)

report = classification_report(testLabels.argmax(axis = 1), predictedClasses)
print(report)
# Out:
# 8/8 [==============================] - 2s 102ms/step
#               precision    recall  f1-score   support
#
#            0       1.00      0.70      0.83       128
#            1       0.77      1.00      0.87       128
#
#     accuracy                           0.85       256
#    macro avg       0.89      0.85      0.85       256
# weighted avg       0.89      0.85      0.85       256

# %%
plt.figure(figsize=(8, 5))
plt.plot(range(1, num_epochs + 1), testAccuracy, color='b')
plt.xlabel('Epoch')
plt.ylabel('Test Accuracy')
plt.title('Test Accuracy over Epochs')
plt.ylim([0, 1])  # Set y-axis limit between 0 and 1
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(10, 5))

plt.subplot(1, 2, 1)
plt.plot(range(1, num_epochs + 1), training_times)
plt.xlabel('Epoch')
plt.ylabel('Time (s)')
plt.title('Training Speed per Epoch')

plt.subplot(1, 2, 2)
plt.plot(range(1, num_epochs + 1), memory_usage, color='orange')
plt.xlabel('Epoch')
plt.ylabel('Memory Usage (GB)')
plt.title('Memory Usage per Epoch')

plt.tight_layout()
plt.show()
