# %% [markdown]
# ###Start###

# %% [markdown]
# This version is the most normal version of all versions. In this version unitary initialization used but BN and L2 have been removed from architecture of the model.

# %%
import tensorflow as tf
import numpy as np
import os, random
import matplotlib.pyplot as plt
from keras import layers
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras import regularizers
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras.models import load_model
from tensorflow.keras.optimizers.schedules import ExponentialDecay
from tensorflow.keras.optimizers import Adam
from imblearn.over_sampling import RandomOverSampler
from sklearn.metrics import classification_report
import time
import psutil

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
path = '/content/drive/MyDrive/tf_HH/NP_data/'
trainImages = np.load(path + 'trainImages.npy')
trainLabels = np.load(path + 'trainLabels.npy')
testImages  = np.load(path + 'testImages.npy')
testLabels  = np.load(path + 'testLabels.npy')

# %%
augmented = ImageDataGenerator(rotation_range=12,
                               width_shift_range = 0.1,
                               height_shift_range= 0.1,
                               zoom_range=0.1,
                               horizontal_flip= True)
augmented.fit(trainImages)
augmented.fit(testImages)

# %% [markdown]
# ###Data Check

# %%
#Data Loading Check
plt.imshow(trainImages[254])
print(trainImages.shape, " ", trainImages.dtype)
print(trainLabels.shape)
print(testImages.shape)
print(testLabels.shape)
# Out:
# (1000, 256, 256, 3)   float32
# (1000, 2)
# (256, 256, 256, 3)
# (256, 2)

# %%
classes = ['AD', 'CN']

figure, axes = plt.subplots(4, 5, figsize= (12,12))
for i in range(len(trainImages)):
  if trainLabels[i][0] == 1 :
    titleIndex = 0
  else :
    titleIndex = 1
  ax_row = i // 5
  ax_col = i % 5
  if ax_row ==4 or ax_col==5:
    break
  ax = axes[ax_row][ax_col]
  ax.imshow(trainImages[i])
  ax.set_title(classes[titleIndex])
  ax.axis('off')

plt.tight_layout()
plt.show()

# %% [markdown]
# ###Unitary Regularizer###

# %%
# used version 1.2
import tensorflow.keras.backend as K
class UnitaryRegularizer(tf.keras.regularizers.Regularizer):
    def __init__(self, lambd):
        self.lambd = lambd

    def __call__(self, weights):
        # Get the number of output neurons
        num_output_neurons = weights.shape[-1]

        # Reshape the weight matrix to be a 2D matrix (flatten filters)
        flattened_weights = tf.reshape(weights, (-1, num_output_neurons))

        # Calculate the matrix product and the identity matrix
        product = tf.matmul(flattened_weights, tf.transpose(flattened_weights))
        identity_matrix = tf.eye(product.shape[0])

        # Calculate the Frobenius norm for each filter separately
        filter_norms = tf.norm(product - identity_matrix, axis=[-2, -1])
        #print(filter_norms)

        # Calculate the regularization term as the sum of squared Frobenius norms
        regularization = 0.5 * self.lambd * tf.reduce_sum(tf.square(filter_norms))
        #tf.print(regularization)
        return regularization

    def get_config(self):
        return {'lambd': self.lambd}

# %% [markdown]
# ###MODEL

# %%
my_resnet = tf.keras.applications.ResNet50(input_shape=(256, 256, 3), include_top=False)
my_resnet.trainable = False
custom_lambd = 0.01
model = tf.keras.Sequential([
    tf.keras.layers.Input((256, 256, 3)),
    #tf.keras.layers.BatchNormalization(),
    my_resnet,
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.Conv2D(filters = 256, kernel_size = (3, 3),
                             activation = tf.nn.
                           relu , name='conv1', padding='same'),
    #tf.keras.layers.BatchNormalization(),
    tf.keras.layers.MaxPool2D(pool_size=(2, 2), name='pool1'),
    tf.keras.layers.Conv2D(filters = 128, kernel_size = (3, 3),
                             activation = tf.nn.relu, padding='same',
                            name='conv2'),
                           #kernel_regularizer= UnitaryRegularizer(lambd=custom_lambd) ),

    tf.keras.layers.Conv2D(filters = 64, kernel_size = (3, 3),
                             activation = tf.nn.relu, name='conv3',
                            padding='same'),
    tf.keras.layers.MaxPool2D(pool_size=(2, 2), name='pool3'),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.Conv2D(filters = 32, kernel_size = (3, 3),
                           activation= tf.nn.relu, padding='same',
                           name='conv4'),
                           #kernel_regularizer= UnitaryRegularizer(lambd=custom_lambd) ),
    tf.keras.layers.Conv2D(filters = 32, kernel_size = (3, 3),
                           activation= tf.nn.relu, padding='same',
                           name='conv5'),
                           #kernel_regularizer= UnitaryRegularizer(lambd=custom_lambd) ),
    #tf.keras.layers.BatchNormalization(),
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(128, activation = tf.nn.relu),
    tf.keras.layers.Dense(64, activation = tf.nn.relu),
                          #,kernel_regularizer=regularizers.l2(0.01)),
    tf.keras.layers.Dense(2, activation = 'sigmoid')
])
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50_weights_tf_dim_ordering_tf_kernels_notop.h5
# 94765736/94765736 [==============================] - 1s 0us/step

# %% [markdown]
# ###Unitary Initialization###

# %%
# this function below is utilizing CPU because of using NUMPY
def unitarizer(weightArr):
  unitaryMatrices = np.empty_like(weightArr)
  print("1")
  weightArr_tr = np.transpose(weightArr, (3, 2, 0, 1))
  print("2 tr: ", weightArr_tr.shape)
  U, SIGMA, V_trans = np.linalg.svd(weightArr_tr)
  print("3 ", V_trans.shape)
  W = V_trans.T
  print("4 ", W.shape)
  W = np.reshape(W, weightArr.shape)
  print("5")
  #unitaryMatrices[:,:,i,j] = unitarySingleKernel
  return W

# %%
trainableWeights = model.trainable_weights
print("the shape of trainable weights in first conv", trainableWeights[4].shape)
# Out:
# the shape of trainable weights in first conv (3, 3, 256, 128)

# %%
indecies = [4, 10, 12]

for idx in indecies:
  print("***********************  Convolution is unitarizing ", idx, " ************************")
  convWeights  = trainableWeights[idx]
  print(convWeights.shape)
  U_convWeights = unitarizer(convWeights)
  print(U_convWeights[0][0][16][16])
  print("*************************  Convolution unitarized ", idx, "  *************************")
  model.trainable_weights[idx].assign(U_convWeights)
  convtester = model.trainable_weights[idx]
  print("************************* Convolution unitaryCheck ", idx, " *************************")
  print(convtester[0][0][16][16])
# Out:
# ***********************  Convolution is unitarizing  4  ************************
# (3, 3, 256, 128)
# 1
# 2 tr:  (128, 256, 3, 3)
# 3  (128, 256, 3, 3)
# 4  (3, 3, 256, 128)
# 5
# -0.64928347
# *************************  Convolution unitarized  4   *************************
# ************************* Convolution unitaryCheck  4  *************************
# tf.Tensor(-0.64928347, shape=(), dtype=float32)
# ***********************  Convolution is unitarizing  10  ************************
# (3, 3, 64, 32)
# 1
# 2 tr:  (32, 64, 3, 3)
# 3  (32, 64, 3, 3)
# 4  (3, 3, 64, 32)
# 5
# 0.5581907
# *************************  Convolution unitarized  10   *************************
# ************************* Convolution unitaryCheck  10  *************************
# tf.Tensor(0.5581907, shape=(), dtype=float32)
# ***********************  Convolution is unitarizing  12  ************************
# (3, 3, 32, 32)
# 1
# 2 tr:  (32, 32, 3, 3)
# 3  (32, 32, 3, 3)
# 4  (3, 3, 32, 32)
# 5
# -0.61629444
# *************************  Convolution unitarized  12   *************************
# ************************* Convolution unitaryCheck  12  *************************
# tf.Tensor(-0.61629444, shape=(), dtype=float32)

# %%
#not needed when we regularize it.
# model.layers[6].trainable=False
# model.layers[10].trainable=False
# model.layers[11].trainable=False

# %% [markdown]
# ###Model compile###

# %%
model.compile(optimizer='sgd', loss='binary_crossentropy', metrics=['accuracy'])

# %%
checkpointPath = "/content/drive/MyDrive/Kag-adni-unBalance/finalCheckPoints/FinalRuns1/"

checkPointCallBack = ModelCheckpoint(filepath = checkpointPath,
                                     monitor = 'val_accuracy',
                                     mode='max', save_best_only = True)

# %% [markdown]
# ###Model Check

# %%
tf.keras.utils.plot_model(model, show_shapes = True,
                          show_layer_activations=True, show_trainable= True)

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  resnet50 (Functional)       (None, 8, 8, 2048)        23587712
#
#  batch_normalization (BatchN  (None, 8, 8, 2048)       8192
#  ormalization)
#
#  conv1 (Conv2D)              (None, 8, 8, 256)         4718848
#
#  pool1 (MaxPooling2D)        (None, 4, 4, 256)         0
#
#  conv2 (Conv2D)              (None, 4, 4, 128)         295040
#
#  conv3 (Conv2D)              (None, 4, 4, 64)          73792
#
#  pool3 (MaxPooling2D)        (None, 2, 2, 64)          0
#
#  batch_normalization_1 (Batc  (None, 2, 2, 64)         256
#  hNormalization)
#
#  conv4 (Conv2D)              (None, 2, 2, 32)          18464
#
#  conv5 (Conv2D)              (None, 2, 2, 32)          9248
#
#  flatten (Flatten)           (None, 128)               0
#
#  dense (Dense)               (None, 128)               16512
#
#  dense_1 (Dense)             (None, 64)                8256
#
#  dense_2 (Dense)             (None, 2)                 130
#
# =================================================================
# Total params: 28,736,450
# Trainable params: 5,144,514
# Non-trainable params: 23,591,936
# _________________________________________________________________

# %% [markdown]
# ###RUN###

# %%
training_times = []
memory_usage = []
testAccuracy = []
num_epochs = 120
for epoch in range(num_epochs):
  startTime = time.time()
  history = model.fit(augmented.flow(trainImages, trainLabels, batch_size = 64),
                    epochs = 1)
          #validation_data=(testImages, testLabels))
                    #callbacks=[checkPointCallBack])#with version 1.2
  endTime = time.time()
  epochTime = endTime - startTime
  training_times.append(epochTime)
  memory_usage.append(psutil.virtual_memory().used/1024**2)
  testLoss , testAcc = model.evaluate(testImages, testLabels, verbose = 0)
  testAccuracy.append(testAcc)
  print(f"Epoch {epoch + 1}/{num_epochs} - Time: {epochTime:.2f}s - Memory Usage: {memory_usage[-1]:.2f}MB - val_loss: {testLoss} - val_accuracy: {testAcc}")
  print("*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*")
# Out:
# 16/16 [==============================] - 33s 1s/step - loss: 7.8393 - accuracy: 0.5030
# Epoch 1/120 - Time: 34.15s - Memory Usage: 5190.67MB - val_loss: 8.733940124511719 - val_accuracy: 0.5
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 16/16 [==============================] - 16s 951ms/step - loss: 0.6832 - accuracy: 0.5530
# Epoch 2/120 - Time: 17.11s - Memory Usage: 5636.12MB - val_loss: 4.192211151123047 - val_accuracy: 0.5
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 16/16 [==============================] - 16s 987ms/step - loss: 0.6769 - accuracy: 0.5670
# Epoch 3/120 - Time: 21.36s - Memory Usage: 5899.62MB - val_loss: 2.1770825386047363 - val_accuracy: 0.5
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 16/16 [==============================] - 15s 934ms/step - loss: 0.6757 - accuracy: 0.6000
# Epoch 4/120 - Time: 16.62s - Memory Usage: 6268.81MB - val_loss: 1.2665319442749023 - val_accuracy: 0.47265625
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 16/16 [==============================] - 16s 976ms/step - loss: 0.6572 - accuracy: 0.6230
# Epoch 5/120 - Time: 17.52s - Memory Usage: 6412.79MB - val_loss: 0.787517249584198 - val_accuracy: 0.5859375
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 16/16 [==============================] - 16s 968ms/step - loss: 0.5885 - accuracy: 0.7140
# Epoch 6/120 - Time: 21.36s - Memory Usage: 6780.34MB - val_loss: 0.8215796947479248 - val_accuracy: 0.484375
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 16/16 [==============================] - 16s 981ms/step - loss: 0.6268 - accuracy: 0.6700
# Epoch 7/120 - Time: 21.32s - Memory Usage: 6421.23MB - val_loss: 0.7401476502418518 - val_accuracy: 0.4765625
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 16/16 [==============================] - 16s 1s/step - loss: 0.5883 - accuracy: 0.6970
# Epoch 8/120 - Time: 16.95s - Memory Usage: 6634.25MB - val_loss: 0.7955651879310608 - val_accuracy: 0.5078125
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 16/16 [==============================] - 15s 964ms/step - loss: 0.5592 - accuracy: 0.7270
# Epoch 9/120 - Time: 16.27s - Memory Usage: 6834.10MB - val_loss: 0.8260727524757385 - val_accuracy: 0.51953125
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 16/16 [==============================] - 16s 971ms/step - loss: 0.5768 - accuracy: 0.7190
# Epoch 10/120 - Time: 17.19s - Memory Usage: 7019.80MB - val_loss: 1.0162789821624756 - val_accuracy: 0.5078125
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 16/16 [==============================] - 15s 954ms/step - loss: 0.5212 - accuracy: 0.7560
# Epoch 11/120 - Time: 21.38s - Memory Usage: 6507.95MB - val_loss: 1.1861032247543335 - val_accuracy: 0.51171875
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 16/16 [==============================] - 16s 951ms/step - loss: 0.5286 - accuracy: 0.7200
# Epoch 12/120 - Time: 21.90s - Memory Usage: 6813.77MB - val_loss: 0.5391385555267334 - val_accuracy: 0.76171875
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 16/16 [==============================] - 15s 954ms/step - loss: 0.4306 - accuracy: 0.7930
# Epoch 13/120 - Time: 21.25s - Memory Usage: 7016.93MB - val_loss: 1.0506224632263184 - val_accuracy: 0.546875
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 16/16 [==============================] - 15s 940ms/step - loss: 0.4578 - accuracy: 0.7800
# Epoch 14/120 - Time: 21.26s - Memory Usage: 7173.71MB - val_loss: 0.6464797258377075 - val_accuracy: 0.62109375
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 16/16 [==============================] - 16s 961ms/step - loss: 0.4220 - accuracy: 0.8090
# Epoch 15/120 - Time: 17.19s - Memory Usage: 6562.73MB - val_loss: 0.5863828659057617 - val_accuracy: 0.65625
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 16/16 [==============================] - 15s 935ms/step - loss: 0.4315 - accuracy: 0.8060
# Epoch 16/120 - Time: 15.89s - Memory Usage: 6758.07MB - val_loss: 0.8209887146949768 - val_accuracy: 0.61328125
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 16/16 [==============================] - 15s 957ms/step - loss: 0.3827 - accuracy: 0.8230
# Epoch 17/120 - Time: 16.24s - Memory Usage: 7033.95MB - val_loss: 1.2416731119155884 - val_accuracy: 0.52734375
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 16/16 [==============================] - 16s 946ms/step - loss: 0.3910 - accuracy: 0.8280
# Epoch 18/120 - Time: 21.93s - Memory Usage: 7248.89MB - val_loss: 0.8695762157440186 - val_accuracy: 0.5703125
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 16/16 [==============================] - 15s 939ms/step - loss: 0.4627 - accuracy: 0.7970
# Epoch 19/120 - Time: 21.38s - Memory Usage: 6660.57MB - val_loss: 0.48017510771751404 - val_accuracy: 0.80078125
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 16/16 [==============================] - 15s 950ms/step - loss: 0.4447 - accuracy: 0.7840
# Epoch 20/120 - Time: 16.17s - Memory Usage: 6885.30MB - val_loss: 0.6587148308753967 - val_accuracy: 0.609375
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 16/16 [==============================] - 16s 979ms/step - loss: 0.3776 - accuracy: 0.8320
# Epoch 21/120 - Time: 21.29s - Memory Usage: 6997.20MB - val_loss: 0.593682587146759 - val_accuracy: 0.66796875
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 16/16 [==============================] - 15s 941ms/step - loss: 0.4229 - accuracy: 0.8000
# Epoch 22/120 - Time: 21.30s - Memory Usage: 7181.02MB - val_loss: 1.1645563840866089 - val_accuracy: 0.55078125
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 16/16 [==============================] - 17s 1s/step - loss: 0.3432 - accuracy: 0.8510
# Epoch 23/120 - Time: 18.14s - Memory Usage: 6707.10MB - val_loss: 0.3661292493343353 - val_accuracy: 0.859375
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 16/16 [==============================] - 16s 975ms/step - loss: 0.3892 - accuracy: 0.8350
# Epoch 24/120 - Time: 16.51s - Memory Usage: 6846.91MB - val_loss: 0.5190449953079224 - val_accuracy: 0.6875
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 16/16 [==============================] - 16s 976ms/step - loss: 0.3839 - accuracy: 0.8190
# Epoch 25/120 - Time: 21.29s - Memory Usage: 7056.98MB - val_loss: 1.3358083963394165 - val_accuracy: 0.5
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 16/16 [==============================] - 15s 939ms/step - loss: 0.4081 - accuracy: 0.8170
# Epoch 26/120 - Time: 15.95s - Memory Usage: 7343.63MB - val_loss: 0.7462329268455505 - val_accuracy: 0.58203125
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 16/16 [==============================] - 15s 944ms/step - loss: 0.3573 - accuracy: 0.8320
# Epoch 27/120 - Time: 21.31s - Memory Usage: 6773.38MB - val_loss: 0.6294498443603516 - val_accuracy: 0.6796875
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 16/16 [==============================] - 15s 948ms/step - loss: 0.3401 - accuracy: 0.8320
# Epoch 28/120 - Time: 21.27s - Memory Usage: 6932.26MB - val_loss: 0.8293386101722717 - val_accuracy: 0.6328125
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 16/16 [==============================] - 15s 955ms/step - loss: 0.3046 - accuracy: 0.8750
# Epoch 29/120 - Time: 21.28s - Memory Usage: 7147.19MB - val_loss: 0.6201106905937195 - val_accuracy: 0.75
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 16/16 [==============================] - 16s 933ms/step - loss: 0.3026 - accuracy: 0.8720
# Epoch 30/120 - Time: 17.11s - Memory Usage: 7313.22MB - val_loss: 0.5325241088867188 - val_accuracy: 0.78515625
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 16/16 [==============================] - 15s 928ms/step - loss: 0.3157 - accuracy: 0.8590
# Epoch 31/120 - Time: 15.81s - Memory Usage: 6767.38MB - val_loss: 0.9294882416725159 - val_accuracy: 0.640625
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 16/16 [==============================] - 15s 940ms/step - loss: 0.3485 - accuracy: 0.8410
# Epoch 32/120 - Time: 15.98s - Memory Usage: 6892.68MB - val_loss: 0.4662388861179352 - val_accuracy: 0.8359375
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 16/16 [==============================] - 16s 970ms/step - loss: 0.2610 - accuracy: 0.8930
# Epoch 33/120 - Time: 21.33s - Memory Usage: 7091.35MB - val_loss: 0.899237871170044 - val_accuracy: 0.703125
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 16/16 [==============================] - 15s 947ms/step - loss: 0.3170 - accuracy: 0.8530
# Epoch 34/120 - Time: 16.00s - Memory Usage: 7304.37MB - val_loss: 0.37866055965423584 - val_accuracy: 0.84765625
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 16/16 [==============================] - 16s 982ms/step - loss: 0.3092 - accuracy: 0.8580
# Epoch 35/120 - Time: 16.66s - Memory Usage: 6737.46MB - val_loss: 0.6628136038780212 - val_accuracy: 0.7265625
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 16/16 [==============================] - 15s 952ms/step - loss: 0.2548 - accuracy: 0.9020
# Epoch 36/120 - Time: 21.40s - Memory Usage: 6992.98MB - val_loss: 0.5364602208137512 - val_accuracy: 0.83203125
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 16/16 [==============================] - 16s 974ms/step - loss: 0.2741 - accuracy: 0.8760
# Epoch 37/120 - Time: 16.68s - Memory Usage: 7162.69MB - val_loss: 0.9625059962272644 - val_accuracy: 0.71484375
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 16/16 [==============================] - 15s 955ms/step - loss: 0.2427 - accuracy: 0.8970
# Epoch 38/120 - Time: 16.34s - Memory Usage: 7322.27MB - val_loss: 0.8614886999130249 - val_accuracy: 0.7421875
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 16/16 [==============================] - 15s 956ms/step - loss: 0.3370 - accuracy: 0.8370
# Epoch 39/120 - Time: 16.21s - Memory Usage: 6792.13MB - val_loss: 1.0090351104736328 - val_accuracy: 0.67578125
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 16/16 [==============================] - 17s 1s/step - loss: 0.2389 - accuracy: 0.9130
# Epoch 40/120 - Time: 17.64s - Memory Usage: 6934.55MB - val_loss: 1.18014657497406 - val_accuracy: 0.68359375
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 16/16 [==============================] - 15s 947ms/step - loss: 0.2851 - accuracy: 0.8750
# Epoch 41/120 - Time: 16.63s - Memory Usage: 7111.23MB - val_loss: 0.8916034698486328 - val_accuracy: 0.7578125
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 16/16 [==============================] - 15s 941ms/step - loss: 0.2729 - accuracy: 0.8790
# Epoch 42/120 - Time: 15.95s - Memory Usage: 7297.18MB - val_loss: 0.5210655927658081 - val_accuracy: 0.828125
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 16/16 [==============================] - 15s 933ms/step - loss: 0.2885 - accuracy: 0.8870
# Epoch 43/120 - Time: 15.91s - Memory Usage: 6802.95MB - val_loss: 0.7608983516693115 - val_accuracy: 0.796875
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 16/16 [==============================] - 16s 939ms/step - loss: 0.2291 - accuracy: 0.9000
# Epoch 44/120 - Time: 21.86s - Memory Usage: 7020.84MB - val_loss: 0.6644008159637451 - val_accuracy: 0.81640625
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 16/16 [==============================] - 15s 969ms/step - loss: 0.2309 - accuracy: 0.9030
# Epoch 45/120 - Time: 21.26s - Memory Usage: 7228.28MB - val_loss: 2.127469062805176 - val_accuracy: 0.61328125
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 16/16 [==============================] - 15s 944ms/step - loss: 0.2663 - accuracy: 0.8850
# Epoch 46/120 - Time: 21.26s - Memory Usage: 7423.40MB - val_loss: 1.2535905838012695 - val_accuracy: 0.73828125
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 16/16 [==============================] - 15s 940ms/step - loss: 0.2435 - accuracy: 0.9000
# Epoch 47/120 - Time: 16.41s - Memory Usage: 6833.38MB - val_loss: 1.379012107849121 - val_accuracy: 0.8046875
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 16/16 [==============================] - 15s 944ms/step - loss: 0.4003 - accuracy: 0.8250
# Epoch 48/120 - Time: 21.27s - Memory Usage: 6966.41MB - val_loss: 2.75567889213562 - val_accuracy: 0.4921875
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 16/16 [==============================] - 15s 949ms/step - loss: 0.2987 - accuracy: 0.8710
# Epoch 49/120 - Time: 16.34s - Memory Usage: 7227.27MB - val_loss: 4.827394008636475 - val_accuracy: 0.4921875
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 16/16 [==============================] - 15s 950ms/step - loss: 0.2806 - accuracy: 0.8790
# Epoch 50/120 - Time: 21.29s - Memory Usage: 7394.36MB - val_loss: 3.89180850982666 - val_accuracy: 0.4921875
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 16/16 [==============================] - 15s 951ms/step - loss: 0.2785 - accuracy: 0.8900
# Epoch 51/120 - Time: 21.30s - Memory Usage: 6838.50MB - val_loss: 3.1437582969665527 - val_accuracy: 0.4921875
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 16/16 [==============================] - 16s 978ms/step - loss: 0.2260 - accuracy: 0.9110
# Epoch 52/120 - Time: 17.03s - Memory Usage: 7044.82MB - val_loss: 3.469069480895996 - val_accuracy: 0.49609375
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 16/16 [==============================] - 15s 961ms/step - loss: 0.2067 - accuracy: 0.9110
# Epoch 53/120 - Time: 16.29s - Memory Usage: 7198.05MB - val_loss: 2.6415116786956787 - val_accuracy: 0.59375
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 16/16 [==============================] - 15s 950ms/step - loss: 0.2429 - accuracy: 0.8940
# Epoch 54/120 - Time: 21.27s - Memory Usage: 7281.84MB - val_loss: 2.213059663772583 - val_accuracy: 0.64453125
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 16/16 [==============================] - 15s 942ms/step - loss: 0.1907 - accuracy: 0.9260
# Epoch 55/120 - Time: 21.30s - Memory Usage: 6727.13MB - val_loss: 1.9903515577316284 - val_accuracy: 0.6875
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 16/16 [==============================] - 16s 955ms/step - loss: 0.1551 - accuracy: 0.9360
# Epoch 56/120 - Time: 17.40s - Memory Usage: 6990.31MB - val_loss: 1.898428201675415 - val_accuracy: 0.7265625
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 16/16 [==============================] - 15s 944ms/step - loss: 0.2046 - accuracy: 0.9260
# Epoch 57/120 - Time: 21.29s - Memory Usage: 7117.72MB - val_loss: 1.0490367412567139 - val_accuracy: 0.828125
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 16/16 [==============================] - 16s 934ms/step - loss: 0.1920 - accuracy: 0.9240
# Epoch 58/120 - Time: 21.87s - Memory Usage: 7360.95MB - val_loss: 2.2885937690734863 - val_accuracy: 0.6875
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 16/16 [==============================] - 15s 933ms/step - loss: 0.1717 - accuracy: 0.9310
# Epoch 59/120 - Time: 15.94s - Memory Usage: 6794.55MB - val_loss: 1.8070082664489746 - val_accuracy: 0.734375
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 16/16 [==============================] - 16s 948ms/step - loss: 0.1744 - accuracy: 0.9320
# Epoch 60/120 - Time: 17.24s - Memory Usage: 6919.92MB - val_loss: 3.040334701538086 - val_accuracy: 0.65625
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 16/16 [==============================] - 15s 942ms/step - loss: 0.1544 - accuracy: 0.9400
# Epoch 61/120 - Time: 21.28s - Memory Usage: 7129.96MB - val_loss: 1.628615140914917 - val_accuracy: 0.78125
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 16/16 [==============================] - 15s 935ms/step - loss: 0.1699 - accuracy: 0.9330
# Epoch 62/120 - Time: 21.90s - Memory Usage: 7307.42MB - val_loss: 2.5773401260375977 - val_accuracy: 0.6640625
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 16/16 [==============================] - 15s 926ms/step - loss: 0.1632 - accuracy: 0.9290
# Epoch 63/120 - Time: 15.76s - Memory Usage: 6721.48MB - val_loss: 1.5489189624786377 - val_accuracy: 0.81640625
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 16/16 [==============================] - 16s 951ms/step - loss: 0.1758 - accuracy: 0.9290
# Epoch 64/120 - Time: 16.96s - Memory Usage: 6856.74MB - val_loss: 1.6932129859924316 - val_accuracy: 0.79296875
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 16/16 [==============================] - 15s 945ms/step - loss: 0.1360 - accuracy: 0.9490
# Epoch 65/120 - Time: 16.00s - Memory Usage: 7034.00MB - val_loss: 2.523895502090454 - val_accuracy: 0.70703125
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 16/16 [==============================] - 15s 946ms/step - loss: 0.1772 - accuracy: 0.9270
# Epoch 66/120 - Time: 16.03s - Memory Usage: 7257.73MB - val_loss: 2.0689046382904053 - val_accuracy: 0.765625
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 16/16 [==============================] - 16s 969ms/step - loss: 0.1549 - accuracy: 0.9380
# Epoch 67/120 - Time: 17.31s - Memory Usage: 6711.85MB - val_loss: 1.7989585399627686 - val_accuracy: 0.81640625
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 16/16 [==============================] - 15s 937ms/step - loss: 0.1446 - accuracy: 0.9450
# Epoch 68/120 - Time: 21.28s - Memory Usage: 6897.87MB - val_loss: 2.6485071182250977 - val_accuracy: 0.73828125
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 16/16 [==============================] - 16s 973ms/step - loss: 0.1603 - accuracy: 0.9280
# Epoch 69/120 - Time: 17.56s - Memory Usage: 7098.79MB - val_loss: 2.6288084983825684 - val_accuracy: 0.734375
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 16/16 [==============================] - 15s 952ms/step - loss: 0.1451 - accuracy: 0.9400
# Epoch 70/120 - Time: 21.29s - Memory Usage: 7400.16MB - val_loss: 2.1523423194885254 - val_accuracy: 0.765625
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 16/16 [==============================] - 16s 966ms/step - loss: 0.1453 - accuracy: 0.9330
# Epoch 71/120 - Time: 21.98s - Memory Usage: 6825.67MB - val_loss: 1.5640249252319336 - val_accuracy: 0.85546875
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 16/16 [==============================] - 15s 944ms/step - loss: 0.1539 - accuracy: 0.9360
# Epoch 72/120 - Time: 21.29s - Memory Usage: 7013.32MB - val_loss: 2.163160800933838 - val_accuracy: 0.76953125
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 16/16 [==============================] - 15s 950ms/step - loss: 0.1605 - accuracy: 0.9450
# Epoch 73/120 - Time: 21.26s - Memory Usage: 7232.59MB - val_loss: 3.7908637523651123 - val_accuracy: 0.65625
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 16/16 [==============================] - 15s 937ms/step - loss: 0.1471 - accuracy: 0.9380
# Epoch 74/120 - Time: 16.41s - Memory Usage: 7361.86MB - val_loss: 3.8137247562408447 - val_accuracy: 0.640625
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 16/16 [==============================] - 15s 946ms/step - loss: 0.1136 - accuracy: 0.9540
# Epoch 75/120 - Time: 16.09s - Memory Usage: 6807.37MB - val_loss: 3.7758498191833496 - val_accuracy: 0.66015625
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 16/16 [==============================] - 15s 946ms/step - loss: 0.1268 - accuracy: 0.9420
# Epoch 76/120 - Time: 16.11s - Memory Usage: 7018.45MB - val_loss: 3.5689926147460938 - val_accuracy: 0.69921875
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 16/16 [==============================] - 16s 937ms/step - loss: 0.1382 - accuracy: 0.9380
# Epoch 77/120 - Time: 17.00s - Memory Usage: 7195.81MB - val_loss: 4.605213642120361 - val_accuracy: 0.60546875
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 16/16 [==============================] - 15s 933ms/step - loss: 0.1265 - accuracy: 0.9550
# Epoch 78/120 - Time: 21.29s - Memory Usage: 7386.31MB - val_loss: 3.4911389350891113 - val_accuracy: 0.6953125
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 16/16 [==============================] - 16s 942ms/step - loss: 0.1575 - accuracy: 0.9340
# Epoch 79/120 - Time: 21.98s - Memory Usage: 6818.32MB - val_loss: 3.128146171569824 - val_accuracy: 0.57421875
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 16/16 [==============================] - 15s 943ms/step - loss: 0.3062 - accuracy: 0.8670
# Epoch 80/120 - Time: 21.30s - Memory Usage: 7025.96MB - val_loss: 1.7666399478912354 - val_accuracy: 0.84375
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 16/16 [==============================] - 15s 942ms/step - loss: 0.1886 - accuracy: 0.9300
# Epoch 81/120 - Time: 21.29s - Memory Usage: 7198.67MB - val_loss: 1.989192247390747 - val_accuracy: 0.83203125
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 16/16 [==============================] - 15s 950ms/step - loss: 0.1330 - accuracy: 0.9500
# Epoch 82/120 - Time: 16.13s - Memory Usage: 7413.58MB - val_loss: 4.413721561431885 - val_accuracy: 0.56640625
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 16/16 [==============================] - 15s 945ms/step - loss: 0.1370 - accuracy: 0.9450
# Epoch 83/120 - Time: 16.06s - Memory Usage: 6812.04MB - val_loss: 3.2650508880615234 - val_accuracy: 0.68359375
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 16/16 [==============================] - 15s 944ms/step - loss: 0.1405 - accuracy: 0.9440
# Epoch 84/120 - Time: 21.29s - Memory Usage: 7059.37MB - val_loss: 2.9039931297302246 - val_accuracy: 0.70703125
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 16/16 [==============================] - 15s 960ms/step - loss: 0.1355 - accuracy: 0.9490
# Epoch 85/120 - Time: 21.25s - Memory Usage: 7276.46MB - val_loss: 3.0334413051605225 - val_accuracy: 0.71875
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 16/16 [==============================] - 16s 1s/step - loss: 0.1051 - accuracy: 0.9600
# Epoch 86/120 - Time: 21.26s - Memory Usage: 7475.00MB - val_loss: 2.684438705444336 - val_accuracy: 0.76953125
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 16/16 [==============================] - 16s 957ms/step - loss: 0.1280 - accuracy: 0.9510
# Epoch 87/120 - Time: 17.46s - Memory Usage: 6885.89MB - val_loss: 3.437929630279541 - val_accuracy: 0.67578125
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 16/16 [==============================] - 15s 949ms/step - loss: 0.1158 - accuracy: 0.9590
# Epoch 88/120 - Time: 16.04s - Memory Usage: 7044.96MB - val_loss: 4.248448371887207 - val_accuracy: 0.62890625
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 16/16 [==============================] - 15s 949ms/step - loss: 0.2178 - accuracy: 0.9110
# Epoch 89/120 - Time: 21.29s - Memory Usage: 7181.15MB - val_loss: 2.93209171295166 - val_accuracy: 0.7109375
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 16/16 [==============================] - 15s 936ms/step - loss: 0.1340 - accuracy: 0.9520
# Epoch 90/120 - Time: 21.25s - Memory Usage: 7448.62MB - val_loss: 2.4644265174865723 - val_accuracy: 0.7265625
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 16/16 [==============================] - 16s 948ms/step - loss: 0.1357 - accuracy: 0.9430
# Epoch 91/120 - Time: 21.92s - Memory Usage: 6853.73MB - val_loss: 4.4066314697265625 - val_accuracy: 0.58203125
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 16/16 [==============================] - 15s 955ms/step - loss: 0.1239 - accuracy: 0.9540
# Epoch 92/120 - Time: 16.17s - Memory Usage: 7060.08MB - val_loss: 3.4461112022399902 - val_accuracy: 0.69140625
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 16/16 [==============================] - 16s 948ms/step - loss: 0.1028 - accuracy: 0.9590
# Epoch 93/120 - Time: 21.84s - Memory Usage: 7283.62MB - val_loss: 4.480777740478516 - val_accuracy: 0.578125
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 16/16 [==============================] - 15s 943ms/step - loss: 0.0993 - accuracy: 0.9680
# Epoch 94/120 - Time: 15.94s - Memory Usage: 7469.70MB - val_loss: 2.838238477706909 - val_accuracy: 0.7265625
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 16/16 [==============================] - 16s 959ms/step - loss: 0.1130 - accuracy: 0.9540
# Epoch 95/120 - Time: 21.54s - Memory Usage: 6863.98MB - val_loss: 2.3535287380218506 - val_accuracy: 0.765625
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 16/16 [==============================] - 15s 926ms/step - loss: 0.1047 - accuracy: 0.9620
# Epoch 96/120 - Time: 21.24s - Memory Usage: 6499.85MB - val_loss: 4.808950901031494 - val_accuracy: 0.55078125
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 16/16 [==============================] - 15s 953ms/step - loss: 0.1055 - accuracy: 0.9600
# Epoch 97/120 - Time: 21.25s - Memory Usage: 6669.34MB - val_loss: 2.5585179328918457 - val_accuracy: 0.765625
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 16/16 [==============================] - 16s 958ms/step - loss: 0.0980 - accuracy: 0.9570
# Epoch 98/120 - Time: 17.36s - Memory Usage: 6839.08MB - val_loss: 2.5589139461517334 - val_accuracy: 0.7578125
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 16/16 [==============================] - 15s 949ms/step - loss: 0.1052 - accuracy: 0.9590
# Epoch 99/120 - Time: 21.26s - Memory Usage: 7006.91MB - val_loss: 4.110070705413818 - val_accuracy: 0.6640625
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 16/16 [==============================] - 18s 1s/step - loss: 0.1034 - accuracy: 0.9570
# Epoch 100/120 - Time: 21.89s - Memory Usage: 6695.78MB - val_loss: 4.451324939727783 - val_accuracy: 0.625
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 16/16 [==============================] - 16s 972ms/step - loss: 0.0607 - accuracy: 0.9790
# Epoch 101/120 - Time: 16.45s - Memory Usage: 6875.89MB - val_loss: 3.361253023147583 - val_accuracy: 0.71484375
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 16/16 [==============================] - 16s 948ms/step - loss: 0.1275 - accuracy: 0.9580
# Epoch 102/120 - Time: 17.35s - Memory Usage: 7073.64MB - val_loss: 2.6195662021636963 - val_accuracy: 0.765625
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 16/16 [==============================] - 15s 940ms/step - loss: 0.1482 - accuracy: 0.9480
# Epoch 103/120 - Time: 21.26s - Memory Usage: 7269.72MB - val_loss: 4.158510208129883 - val_accuracy: 0.640625
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 16/16 [==============================] - 16s 951ms/step - loss: 0.0880 - accuracy: 0.9620
# Epoch 104/120 - Time: 21.90s - Memory Usage: 6877.45MB - val_loss: 3.6609225273132324 - val_accuracy: 0.69921875
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 16/16 [==============================] - 15s 958ms/step - loss: 0.1044 - accuracy: 0.9660
# Epoch 105/120 - Time: 21.24s - Memory Usage: 7025.20MB - val_loss: 4.249029636383057 - val_accuracy: 0.64453125
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 16/16 [==============================] - 15s 943ms/step - loss: 0.0837 - accuracy: 0.9680
# Epoch 106/120 - Time: 16.00s - Memory Usage: 7212.38MB - val_loss: 4.0840535163879395 - val_accuracy: 0.671875
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 16/16 [==============================] - 15s 942ms/step - loss: 0.1012 - accuracy: 0.9580
# Epoch 107/120 - Time: 21.32s - Memory Usage: 7379.70MB - val_loss: 3.4001784324645996 - val_accuracy: 0.71875
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 16/16 [==============================] - 16s 981ms/step - loss: 0.1163 - accuracy: 0.9460
# Epoch 108/120 - Time: 21.32s - Memory Usage: 7018.92MB - val_loss: 4.776023864746094 - val_accuracy: 0.58984375
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 16/16 [==============================] - 16s 978ms/step - loss: 0.1004 - accuracy: 0.9620
# Epoch 109/120 - Time: 21.56s - Memory Usage: 7202.61MB - val_loss: 4.219790458679199 - val_accuracy: 0.65234375
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 16/16 [==============================] - 16s 987ms/step - loss: 0.1051 - accuracy: 0.9600
# Epoch 110/120 - Time: 16.72s - Memory Usage: 7365.33MB - val_loss: 3.819862127304077 - val_accuracy: 0.70703125
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 16/16 [==============================] - 15s 932ms/step - loss: 0.0883 - accuracy: 0.9650
# Epoch 111/120 - Time: 16.21s - Memory Usage: 7651.23MB - val_loss: 5.43280553817749 - val_accuracy: 0.57421875
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 16/16 [==============================] - 15s 956ms/step - loss: 0.0979 - accuracy: 0.9640
# Epoch 112/120 - Time: 16.21s - Memory Usage: 7269.38MB - val_loss: 4.795636177062988 - val_accuracy: 0.640625
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 16/16 [==============================] - 17s 1s/step - loss: 0.0831 - accuracy: 0.9700
# Epoch 113/120 - Time: 21.29s - Memory Usage: 6687.85MB - val_loss: 3.4378225803375244 - val_accuracy: 0.7421875
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 16/16 [==============================] - 15s 941ms/step - loss: 0.0975 - accuracy: 0.9630
# Epoch 114/120 - Time: 15.96s - Memory Usage: 6859.11MB - val_loss: 3.40071439743042 - val_accuracy: 0.6953125
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 16/16 [==============================] - 16s 961ms/step - loss: 0.0877 - accuracy: 0.9670
# Epoch 115/120 - Time: 16.74s - Memory Usage: 7076.26MB - val_loss: 6.109026908874512 - val_accuracy: 0.56640625
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 16/16 [==============================] - 15s 944ms/step - loss: 0.1579 - accuracy: 0.9320
# Epoch 116/120 - Time: 15.98s - Memory Usage: 6694.19MB - val_loss: 0.9912779331207275 - val_accuracy: 0.8203125
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 16/16 [==============================] - 15s 971ms/step - loss: 0.0920 - accuracy: 0.9640
# Epoch 117/120 - Time: 21.28s - Memory Usage: 6890.19MB - val_loss: 3.488786458969116 - val_accuracy: 0.65625
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 16/16 [==============================] - 15s 929ms/step - loss: 0.0560 - accuracy: 0.9820
# Epoch 118/120 - Time: 21.28s - Memory Usage: 7032.62MB - val_loss: 6.442173480987549 - val_accuracy: 0.515625
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 16/16 [==============================] - 15s 899ms/step - loss: 0.0850 - accuracy: 0.9610
# Epoch 119/120 - Time: 15.41s - Memory Usage: 7238.80MB - val_loss: 2.5465691089630127 - val_accuracy: 0.73046875
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 16/16 [==============================] - 15s 945ms/step - loss: 0.0667 - accuracy: 0.9780
# Epoch 120/120 - Time: 21.30s - Memory Usage: 6884.91MB - val_loss: 6.086308479309082 - val_accuracy: 0.54296875
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*

# %% [markdown]
# ###Metrics Evaluation###

# %%
predictedLabels = model.predict(testImages)
predictedClasses = np.argmax(predictedLabels, axis = 1)

report = classification_report(testLabels.argmax(axis = 1), predictedClasses)
print(report)
# Out:
# 8/8 [==============================] - 2s 98ms/step
#               precision    recall  f1-score   support
#
#            0       0.92      0.09      0.17       128
#            1       0.52      0.99      0.68       128
#
#     accuracy                           0.54       256
#    macro avg       0.72      0.54      0.43       256
# weighted avg       0.72      0.54      0.43       256

# %%
plt.figure(figsize=(8, 5))
plt.plot(range(1, num_epochs + 1), testAccuracy, color='b')
plt.xlabel('Epoch')
plt.ylabel('Test Accuracy')
plt.title('Test Accuracy over Epochs')
plt.ylim([0, 1])  # Set y-axis limit between 0 and 1
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(10, 5))

plt.subplot(1, 2, 1)
plt.plot(range(1, num_epochs + 1), training_times)
plt.xlabel('Epoch')
plt.ylabel('Time (s)')
plt.title('Training Speed per Epoch')

plt.subplot(1, 2, 2)
plt.plot(range(1, num_epochs + 1), memory_usage, color='orange')
plt.xlabel('Epoch')
plt.ylabel('Memory Usage (GB)')
plt.title('Memory Usage per Epoch')

plt.tight_layout()
plt.show()
