# %% [markdown]
# ###Start###

# %% [markdown]
# This version is the most normal version of all versions. In this version unitary initialization used but BN and L2 have been removed from architecture of the model. additionally unitary weights are freezed and not trainable.

# %%
import tensorflow as tf
import numpy as np
import os, random
import matplotlib.pyplot as plt
from keras import layers
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras import regularizers
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras.models import load_model
from tensorflow.keras.optimizers.schedules import ExponentialDecay
from tensorflow.keras.optimizers import Adam
from imblearn.over_sampling import RandomOverSampler
from sklearn.metrics import classification_report
import time
import psutil

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
path = '/content/drive/MyDrive/Kag-adni-unBalance/Preprocessed/'
trainImages = np.load(path + 'trainImages.npy')
trainLabels = np.load(path + 'trainLabels.npy')
testImages  = np.load(path + 'testImages.npy')
testLabels  = np.load(path + 'testLabels.npy')

# %%
augmented = ImageDataGenerator(rotation_range=12,
                               width_shift_range = 0.1,
                               height_shift_range= 0.1,
                               zoom_range=0.1,
                               horizontal_flip= True)
augmented.fit(trainImages)
augmented.fit(testImages)

# %% [markdown]
# ###Data Check

# %%
#Data Loading Check
plt.imshow(trainImages[254])
print(trainImages.shape, " ", trainImages.dtype)
print(trainLabels.shape)
print(testImages.shape)
print(testLabels.shape)
# Out:
# (960, 256, 256, 3)   float32
# (960, 2)
# (111, 256, 256, 3)
# (111, 2)

# %%
\
classes = ['AD', 'CN']

figure, axes = plt.subplots(4, 5, figsize= (12,12))
for i in range(len(trainImages)):
  if trainLabels[i][0] == 1 :
    titleIndex = 0
  else :
    titleIndex = 1
  ax_row = i // 5
  ax_col = i % 5
  if ax_row ==4 or ax_col==5:
    break
  ax = axes[ax_row][ax_col]
  ax.imshow(trainImages[i])
  ax.set_title(classes[titleIndex])
  ax.axis('off')

plt.tight_layout()
plt.show()

# %% [markdown]
# ###Unitary Regularizer###

# %%
# used version 1.2
import tensorflow.keras.backend as K
class UnitaryRegularizer(tf.keras.regularizers.Regularizer):
    def __init__(self, lambd):
        self.lambd = lambd

    def __call__(self, weights):
        # Get the number of output neurons
        num_output_neurons = weights.shape[-1]

        # Reshape the weight matrix to be a 2D matrix (flatten filters)
        flattened_weights = tf.reshape(weights, (-1, num_output_neurons))

        # Calculate the matrix product and the identity matrix
        product = tf.matmul(flattened_weights, tf.transpose(flattened_weights))
        identity_matrix = tf.eye(product.shape[0])

        # Calculate the Frobenius norm for each filter separately
        filter_norms = tf.norm(product - identity_matrix, axis=[-2, -1])
        #print(filter_norms)

        # Calculate the regularization term as the sum of squared Frobenius norms
        regularization = 0.5 * self.lambd * tf.reduce_sum(tf.square(filter_norms))
        #tf.print(regularization)
        return regularization

    def get_config(self):
        return {'lambd': self.lambd}

# %% [markdown]
# ###MODEL

# %%
my_resnet = tf.keras.applications.ResNet50(input_shape=(256, 256, 3), include_top=False)
my_resnet.trainable = False
custom_lambd = 0.01
model = tf.keras.Sequential([
    tf.keras.layers.Input((256, 256, 3)),
    tf.keras.layers.BatchNormalization(),
    my_resnet,
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.Conv2D(filters = 256, kernel_size = (3, 3),
                             activation = tf.nn.
                           relu , name='conv1', padding='same'),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.MaxPool2D(pool_size=(2, 2), name='pool1'),
    tf.keras.layers.Conv2D(filters = 128, kernel_size = (3, 3),
                             activation = tf.nn.relu, padding='same',
                            name='conv2',
                           kernel_regularizer= UnitaryRegularizer(lambd=custom_lambd) ),
    tf.keras.layers.Conv2D(filters = 64, kernel_size = (3, 3),
                             activation = tf.nn.relu, name='conv3',
                            padding='same'),
    tf.keras.layers.MaxPool2D(pool_size=(2, 2), name='pool3'),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.Conv2D(filters = 32, kernel_size = (3, 3),
                           activation= tf.nn.relu, padding='same',
                           name='conv4',
                           kernel_regularizer= UnitaryRegularizer(lambd=custom_lambd) ),
    tf.keras.layers.Conv2D(filters = 32, kernel_size = (3, 3),
                           activation= tf.nn.relu, padding='same',
                           name='conv5',
                           kernel_regularizer= UnitaryRegularizer(lambd=custom_lambd) ),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(128, activation = tf.nn.relu),
    tf.keras.layers.Dense(64, activation = tf.nn.relu),
                          #kernel_regularizer=regularizers.l2(0.01)),
    tf.keras.layers.Dense(2, activation = 'sigmoid')
])
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50_weights_tf_dim_ordering_tf_kernels_notop.h5
# 94765736/94765736 [==============================] - 0s 0us/step

# %% [markdown]
# ###Unitary Initialization###

# %%
# this function below is utilizing CPU because of using NUMPY
def unitarizer(weightArr):
  unitaryMatrices = np.empty_like(weightArr)
  print("1")
  weightArr_tr = np.transpose(weightArr, (3, 2, 0, 1))
  print("2 tr: ", weightArr_tr.shape)
  U, SIGMA, V_trans = np.linalg.svd(weightArr_tr)
  print("3 ", V_trans.shape)
  W = V_trans.T
  print("4 ", W.shape)
  W = np.reshape(W, weightArr.shape)
  print("5")
  #unitaryMatrices[:,:,i,j] = unitarySingleKernel
  return W

# %%
trainableWeights = model.trainable_weights
print("the shape of trainable weights in first conv", trainableWeights[14].shape)
# Out:
# the shape of trainable weights in first conv (3, 3, 64, 32)

# %%
indecies = [8, 14, 16]

for idx in indecies:
  print("***********************  Convolution is unitarizing ", idx, " ************************")
  convWeights  = trainableWeights[idx]
  print(convWeights.shape)
  U_convWeights = unitarizer(convWeights)
  print(U_convWeights[0][0][16][16])
  print("*************************  Convolution unitarized ", idx, "  *************************")
  model.trainable_weights[idx].assign(U_convWeights)
  convtester = model.trainable_weights[idx]
  print("************************* Convolution unitaryCheck ", idx, " *************************")
  print(convtester[0][0][16][16])
# Out:
# ***********************  Convolution is unitarizing  8  ************************
# (3, 3, 256, 128)
# 1
# 2 tr:  (128, 256, 3, 3)
# 3  (128, 256, 3, 3)
# 4  (3, 3, 256, 128)
# 5
# -0.756721
# *************************  Convolution unitarized  8   *************************
# ************************* Convolution unitaryCheck  8  *************************
# tf.Tensor(-0.756721, shape=(), dtype=float32)
# ***********************  Convolution is unitarizing  14  ************************
# (3, 3, 64, 32)
# 1
# 2 tr:  (32, 64, 3, 3)
# 3  (32, 64, 3, 3)
# 4  (3, 3, 64, 32)
# 5
# -0.688525
# *************************  Convolution unitarized  14   *************************
# ************************* Convolution unitaryCheck  14  *************************
# tf.Tensor(-0.688525, shape=(), dtype=float32)
# ***********************  Convolution is unitarizing  16  ************************
# (3, 3, 32, 32)
# 1
# 2 tr:  (32, 32, 3, 3)
# 3  (32, 32, 3, 3)
# 4  (3, 3, 32, 32)
# 5
# 0.5891599
# *************************  Convolution unitarized  16   *************************
# ************************* Convolution unitaryCheck  16  *************************
# tf.Tensor(0.5891599, shape=(), dtype=float32)

# %%
#not needed when we regularize it.
#model.layers[4].trainable=False
#model.layers[8].trainable=False
#model.layers[9].trainable=False

# %% [markdown]
# ###Model compile###

# %%
model.compile(optimizer='sgd', loss='binary_crossentropy', metrics=['accuracy'])

# %%
checkpointPath = "/content/drive/MyDrive/Kag-adni-unBalance/finalCheckPoints/FinalRuns3/"

checkPointCallBack = ModelCheckpoint(filepath = checkpointPath,
                                     monitor = 'val_accuracy',
                                     mode='max', save_best_only = True)

# %% [markdown]
# ###Model Check

# %%
tf.keras.utils.plot_model(model, show_shapes = True,
                          show_layer_activations=True, show_trainable= True)

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  batch_normalization (BatchN  (None, 256, 256, 3)      12
#  ormalization)
#
#  resnet50 (Functional)       (None, 8, 8, 2048)        23587712
#
#  batch_normalization_1 (Batc  (None, 8, 8, 2048)       8192
#  hNormalization)
#
#  conv1 (Conv2D)              (None, 8, 8, 256)         4718848
#
#  batch_normalization_2 (Batc  (None, 8, 8, 256)        1024
#  hNormalization)
#
#  pool1 (MaxPooling2D)        (None, 4, 4, 256)         0
#
#  conv2 (Conv2D)              (None, 4, 4, 128)         295040
#
#  conv3 (Conv2D)              (None, 4, 4, 64)          73792
#
#  pool3 (MaxPooling2D)        (None, 2, 2, 64)          0
#
#  batch_normalization_3 (Batc  (None, 2, 2, 64)         256
#  hNormalization)
#
#  conv4 (Conv2D)              (None, 2, 2, 32)          18464
#
#  conv5 (Conv2D)              (None, 2, 2, 32)          9248
#
#  batch_normalization_4 (Batc  (None, 2, 2, 32)         128
#  hNormalization)
#
#  flatten (Flatten)           (None, 128)               0
#
#  dense (Dense)               (None, 128)               16512
#
#  dense_1 (Dense)             (None, 64)                8256
#
#  dense_2 (Dense)             (None, 2)                 130
#
# =================================================================
# Total params: 28,737,614
# Trainable params: 5,145,096
# Non-trainable params: 23,592,518
# _________________________________________________________________

# %%
#early_stopping = EarlyStopping(patience=5, restore_best_weights=True)

# %% [markdown]
# ###RUN###

# %%
training_times = []
memory_usage = []
testAccuracy = []
num_epochs = 120
for epoch in range(num_epochs):
  startTime = time.time()
  history = model.fit(augmented.flow(trainImages, trainLabels, batch_size = 64),
                    epochs = 1)
          #validation_data=(testImages, testLabels))
                    #callbacks=[checkPointCallBack])#with version 1.2
  endTime = time.time()
  epochTime = endTime - startTime
  training_times.append(epochTime)
  memory_usage.append(psutil.virtual_memory().used/1024**2)
  testLoss , testAcc = model.evaluate(testImages, testLabels, verbose = 0)
  testAccuracy.append(testAcc)
  print(f"Epoch {epoch + 1}/{num_epochs} - Time: {epochTime:.2f}s - Memory Usage: {memory_usage[-1]:.2f}MB - val_loss: {testLoss} - val_accuracy: {testAcc}")
  print("*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*")
# Out:
# 15/15 [==============================] - 40s 1s/step - loss: 76063.3906 - accuracy: 0.5698
# Epoch 1/120 - Time: 47.78s - Memory Usage: 5329.69MB - val_loss: 11828.3369140625 - val_accuracy: 0.22522522509098053
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 15/15 [==============================] - 19s 1s/step - loss: 7092.8809 - accuracy: 0.6094
# Epoch 2/120 - Time: 20.46s - Memory Usage: 5385.85MB - val_loss: 3971.671142578125 - val_accuracy: 0.22522522509098053
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 15/15 [==============================] - 20s 1s/step - loss: 2883.3091 - accuracy: 0.6687
# Epoch 3/120 - Time: 21.43s - Memory Usage: 5568.09MB - val_loss: 2002.3802490234375 - val_accuracy: 0.6396396160125732
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 15/15 [==============================] - 19s 1s/step - loss: 1583.1731 - accuracy: 0.7073
# Epoch 4/120 - Time: 20.15s - Memory Usage: 5648.25MB - val_loss: 1211.344970703125 - val_accuracy: 0.7747747898101807
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 15/15 [==============================] - 21s 1s/step - loss: 1005.9647 - accuracy: 0.7208
# Epoch 5/120 - Time: 41.90s - Memory Usage: 5814.53MB - val_loss: 814.0302734375 - val_accuracy: 0.7747747898101807
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 15/15 [==============================] - 20s 1s/step - loss: 698.0823 - accuracy: 0.7375
# Epoch 6/120 - Time: 21.41s - Memory Usage: 5642.12MB - val_loss: 586.063720703125 - val_accuracy: 0.7747747898101807
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 15/15 [==============================] - 19s 1s/step - loss: 514.1620 - accuracy: 0.7646
# Epoch 7/120 - Time: 21.40s - Memory Usage: 5762.36MB - val_loss: 443.1815490722656 - val_accuracy: 0.7117117047309875
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 15/15 [==============================] - 20s 1s/step - loss: 395.4233 - accuracy: 0.7885
# Epoch 8/120 - Time: 21.40s - Memory Usage: 5936.77MB - val_loss: 347.6073303222656 - val_accuracy: 0.7837837934494019
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 15/15 [==============================] - 19s 1s/step - loss: 314.3023 - accuracy: 0.7990
# Epoch 9/120 - Time: 20.06s - Memory Usage: 6088.99MB - val_loss: 280.60498046875 - val_accuracy: 0.8018018007278442
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 15/15 [==============================] - 20s 1s/step - loss: 256.4228 - accuracy: 0.8010
# Epoch 10/120 - Time: 41.88s - Memory Usage: 5864.66MB - val_loss: 231.82589721679688 - val_accuracy: 0.8108108043670654
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 15/15 [==============================] - 21s 1s/step - loss: 213.7017 - accuracy: 0.8125
# Epoch 11/120 - Time: 42.60s - Memory Usage: 6016.48MB - val_loss: 195.23692321777344 - val_accuracy: 0.7297297120094299
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 15/15 [==============================] - 19s 1s/step - loss: 181.2316 - accuracy: 0.8333
# Epoch 12/120 - Time: 20.56s - Memory Usage: 6120.17MB - val_loss: 167.0390625 - val_accuracy: 0.7567567825317383
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 15/15 [==============================] - 20s 1s/step - loss: 156.0213 - accuracy: 0.8302
# Epoch 13/120 - Time: 20.51s - Memory Usage: 6256.88MB - val_loss: 144.89813232421875 - val_accuracy: 0.7837837934494019
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 15/15 [==============================] - 19s 1s/step - loss: 136.0420 - accuracy: 0.8510
# Epoch 14/120 - Time: 20.42s - Memory Usage: 6087.69MB - val_loss: 127.14273834228516 - val_accuracy: 0.8198198080062866
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 15/15 [==============================] - 20s 1s/step - loss: 119.9533 - accuracy: 0.8448
# Epoch 15/120 - Time: 20.45s - Memory Usage: 6191.95MB - val_loss: 112.8048095703125 - val_accuracy: 0.7837837934494019
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 15/15 [==============================] - 19s 1s/step - loss: 106.8210 - accuracy: 0.8427
# Epoch 16/120 - Time: 20.74s - Memory Usage: 6293.11MB - val_loss: 100.89447021484375 - val_accuracy: 0.8108108043670654
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 15/15 [==============================] - 19s 1s/step - loss: 95.9292 - accuracy: 0.8719
# Epoch 17/120 - Time: 21.43s - Memory Usage: 6467.48MB - val_loss: 91.08189392089844 - val_accuracy: 0.8198198080062866
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 15/15 [==============================] - 19s 1s/step - loss: 86.8233 - accuracy: 0.8740
# Epoch 18/120 - Time: 21.40s - Memory Usage: 6312.77MB - val_loss: 82.77562713623047 - val_accuracy: 0.8288288116455078
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 15/15 [==============================] - 21s 1s/step - loss: 79.1543 - accuracy: 0.8708
# Epoch 19/120 - Time: 41.88s - Memory Usage: 6401.22MB - val_loss: 75.77626037597656 - val_accuracy: 0.7567567825317383
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 15/15 [==============================] - 21s 1s/step - loss: 72.6100 - accuracy: 0.8854
# Epoch 20/120 - Time: 21.58s - Memory Usage: 6433.91MB - val_loss: 69.73831176757812 - val_accuracy: 0.792792797088623
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 15/15 [==============================] - 19s 1s/step - loss: 67.0059 - accuracy: 0.8802
# Epoch 21/120 - Time: 20.14s - Memory Usage: 6551.23MB - val_loss: 64.53350067138672 - val_accuracy: 0.792792797088623
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 15/15 [==============================] - 20s 1s/step - loss: 62.1215 - accuracy: 0.8792
# Epoch 22/120 - Time: 21.60s - Memory Usage: 6341.60MB - val_loss: 60.06110382080078 - val_accuracy: 0.7747747898101807
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 15/15 [==============================] - 19s 1s/step - loss: 57.8647 - accuracy: 0.9010
# Epoch 23/120 - Time: 21.39s - Memory Usage: 6438.29MB - val_loss: 56.08269500732422 - val_accuracy: 0.7837837934494019
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 15/15 [==============================] - 20s 1s/step - loss: 54.1623 - accuracy: 0.9094
# Epoch 24/120 - Time: 22.09s - Memory Usage: 6495.37MB - val_loss: 52.628421783447266 - val_accuracy: 0.792792797088623
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 15/15 [==============================] - 19s 1s/step - loss: 50.9031 - accuracy: 0.9000
# Epoch 25/120 - Time: 21.39s - Memory Usage: 6639.36MB - val_loss: 49.659427642822266 - val_accuracy: 0.6936936974525452
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 15/15 [==============================] - 19s 1s/step - loss: 48.0390 - accuracy: 0.8823
# Epoch 26/120 - Time: 19.94s - Memory Usage: 6470.55MB - val_loss: 46.853145599365234 - val_accuracy: 0.792792797088623
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 15/15 [==============================] - 20s 1s/step - loss: 45.4488 - accuracy: 0.9135
# Epoch 27/120 - Time: 21.10s - Memory Usage: 6566.63MB - val_loss: 44.39986801147461 - val_accuracy: 0.8198198080062866
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 15/15 [==============================] - 19s 1s/step - loss: 43.1650 - accuracy: 0.9031
# Epoch 28/120 - Time: 22.11s - Memory Usage: 5697.19MB - val_loss: 42.32878875732422 - val_accuracy: 0.7297297120094299
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 15/15 [==============================] - 20s 1s/step - loss: 41.0973 - accuracy: 0.9229
# Epoch 29/120 - Time: 21.84s - Memory Usage: 5759.68MB - val_loss: 40.36069869995117 - val_accuracy: 0.8108108043670654
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 15/15 [==============================] - 19s 1s/step - loss: 39.2632 - accuracy: 0.9177
# Epoch 30/120 - Time: 20.20s - Memory Usage: 5596.82MB - val_loss: 38.6063346862793 - val_accuracy: 0.8018018007278442
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 15/15 [==============================] - 19s 1s/step - loss: 37.5774 - accuracy: 0.9323
# Epoch 31/120 - Time: 19.62s - Memory Usage: 5687.34MB - val_loss: 37.036014556884766 - val_accuracy: 0.792792797088623
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 15/15 [==============================] - 20s 1s/step - loss: 36.0711 - accuracy: 0.9177
# Epoch 32/120 - Time: 20.83s - Memory Usage: 5731.57MB - val_loss: 35.61008071899414 - val_accuracy: 0.8108108043670654
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 15/15 [==============================] - 19s 1s/step - loss: 34.7132 - accuracy: 0.9240
# Epoch 33/120 - Time: 19.58s - Memory Usage: 5869.98MB - val_loss: 34.31245803833008 - val_accuracy: 0.8018018007278442
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 15/15 [==============================] - 20s 1s/step - loss: 33.4404 - accuracy: 0.9229
# Epoch 34/120 - Time: 21.42s - Memory Usage: 5705.07MB - val_loss: 33.141170501708984 - val_accuracy: 0.8018018007278442
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 15/15 [==============================] - 19s 1s/step - loss: 32.3260 - accuracy: 0.9167
# Epoch 35/120 - Time: 19.57s - Memory Usage: 5774.73MB - val_loss: 32.072628021240234 - val_accuracy: 0.7657657861709595
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 15/15 [==============================] - 19s 1s/step - loss: 31.2772 - accuracy: 0.9219
# Epoch 36/120 - Time: 20.62s - Memory Usage: 5809.32MB - val_loss: 31.166271209716797 - val_accuracy: 0.7117117047309875
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 15/15 [==============================] - 21s 1s/step - loss: 30.3150 - accuracy: 0.9260
# Epoch 37/120 - Time: 41.88s - Memory Usage: 5900.54MB - val_loss: 30.212270736694336 - val_accuracy: 0.7657657861709595
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 15/15 [==============================] - 20s 1s/step - loss: 29.4457 - accuracy: 0.9146
# Epoch 38/120 - Time: 21.86s - Memory Usage: 5782.91MB - val_loss: 29.530271530151367 - val_accuracy: 0.630630612373352
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 15/15 [==============================] - 19s 1s/step - loss: 28.6312 - accuracy: 0.9260
# Epoch 39/120 - Time: 21.39s - Memory Usage: 5794.12MB - val_loss: 28.659578323364258 - val_accuracy: 0.6936936974525452
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 15/15 [==============================] - 19s 1s/step - loss: 27.8849 - accuracy: 0.9135
# Epoch 40/120 - Time: 21.38s - Memory Usage: 5925.54MB - val_loss: 27.904253005981445 - val_accuracy: 0.7477477192878723
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 15/15 [==============================] - 19s 1s/step - loss: 27.2203 - accuracy: 0.9146
# Epoch 41/120 - Time: 22.09s - Memory Usage: 6015.64MB - val_loss: 27.30912971496582 - val_accuracy: 0.7207207083702087
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 15/15 [==============================] - 20s 1s/step - loss: 26.5170 - accuracy: 0.9406
# Epoch 42/120 - Time: 20.70s - Memory Usage: 5865.71MB - val_loss: 26.799606323242188 - val_accuracy: 0.6486486196517944
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 15/15 [==============================] - 19s 1s/step - loss: 25.9380 - accuracy: 0.9312
# Epoch 43/120 - Time: 21.56s - Memory Usage: 5991.98MB - val_loss: 26.10496711730957 - val_accuracy: 0.7477477192878723
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 15/15 [==============================] - 19s 1s/step - loss: 25.3790 - accuracy: 0.9385
# Epoch 44/120 - Time: 20.94s - Memory Usage: 6110.57MB - val_loss: 25.674909591674805 - val_accuracy: 0.7117117047309875
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 15/15 [==============================] - 20s 1s/step - loss: 24.8861 - accuracy: 0.9323
# Epoch 45/120 - Time: 21.33s - Memory Usage: 6154.36MB - val_loss: 25.054746627807617 - val_accuracy: 0.8108108043670654
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 15/15 [==============================] - 19s 1s/step - loss: 24.3629 - accuracy: 0.9531
# Epoch 46/120 - Time: 21.41s - Memory Usage: 5974.75MB - val_loss: 24.604753494262695 - val_accuracy: 0.8018018007278442
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 15/15 [==============================] - 20s 1s/step - loss: 23.9231 - accuracy: 0.9469
# Epoch 47/120 - Time: 21.81s - Memory Usage: 6053.26MB - val_loss: 24.23052406311035 - val_accuracy: 0.7657657861709595
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 15/15 [==============================] - 20s 1s/step - loss: 23.5063 - accuracy: 0.9427
# Epoch 48/120 - Time: 21.38s - Memory Usage: 6073.78MB - val_loss: 23.752473831176758 - val_accuracy: 0.8018018007278442
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 15/15 [==============================] - 19s 1s/step - loss: 23.1196 - accuracy: 0.9396
# Epoch 49/120 - Time: 19.82s - Memory Usage: 6173.16MB - val_loss: 23.434553146362305 - val_accuracy: 0.7387387156486511
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 15/15 [==============================] - 20s 1s/step - loss: 22.7263 - accuracy: 0.9563
# Epoch 50/120 - Time: 20.98s - Memory Usage: 5977.53MB - val_loss: 23.060792922973633 - val_accuracy: 0.7567567825317383
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 15/15 [==============================] - 19s 1s/step - loss: 22.3950 - accuracy: 0.9469
# Epoch 51/120 - Time: 19.70s - Memory Usage: 6145.02MB - val_loss: 22.865612030029297 - val_accuracy: 0.6756756901741028
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 15/15 [==============================] - 19s 1s/step - loss: 22.0785 - accuracy: 0.9479
# Epoch 52/120 - Time: 22.09s - Memory Usage: 6180.41MB - val_loss: 22.566946029663086 - val_accuracy: 0.684684693813324
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 15/15 [==============================] - 20s 1s/step - loss: 21.7770 - accuracy: 0.9490
# Epoch 53/120 - Time: 20.77s - Memory Usage: 6259.72MB - val_loss: 22.117700576782227 - val_accuracy: 0.8018018007278442
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 15/15 [==============================] - 20s 1s/step - loss: 21.4415 - accuracy: 0.9677
# Epoch 54/120 - Time: 20.88s - Memory Usage: 6057.53MB - val_loss: 21.816810607910156 - val_accuracy: 0.7837837934494019
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 15/15 [==============================] - 19s 1s/step - loss: 21.1926 - accuracy: 0.9583
# Epoch 55/120 - Time: 22.00s - Memory Usage: 6139.93MB - val_loss: 21.570505142211914 - val_accuracy: 0.792792797088623
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 15/15 [==============================] - 20s 1s/step - loss: 20.9352 - accuracy: 0.9573
# Epoch 56/120 - Time: 20.50s - Memory Usage: 6192.13MB - val_loss: 21.289884567260742 - val_accuracy: 0.8018018007278442
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 15/15 [==============================] - 19s 1s/step - loss: 20.7069 - accuracy: 0.9500
# Epoch 57/120 - Time: 19.57s - Memory Usage: 6302.26MB - val_loss: 21.10015106201172 - val_accuracy: 0.7747747898101807
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 15/15 [==============================] - 20s 1s/step - loss: 20.4763 - accuracy: 0.9458
# Epoch 58/120 - Time: 20.70s - Memory Usage: 6107.87MB - val_loss: 20.992528915405273 - val_accuracy: 0.7297297120094299
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 15/15 [==============================] - 19s 1s/step - loss: 20.2801 - accuracy: 0.9375
# Epoch 59/120 - Time: 19.63s - Memory Usage: 6258.85MB - val_loss: 21.00562858581543 - val_accuracy: 0.6216216087341309
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 15/15 [==============================] - 20s 1s/step - loss: 20.0450 - accuracy: 0.9604
# Epoch 60/120 - Time: 21.50s - Memory Usage: 6364.00MB - val_loss: 20.74712371826172 - val_accuracy: 0.6666666865348816
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 15/15 [==============================] - 19s 1s/step - loss: 19.8490 - accuracy: 0.9573
# Epoch 61/120 - Time: 21.39s - Memory Usage: 6517.11MB - val_loss: 20.64423370361328 - val_accuracy: 0.6396396160125732
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 15/15 [==============================] - 19s 1s/step - loss: 19.6993 - accuracy: 0.9396
# Epoch 62/120 - Time: 21.40s - Memory Usage: 6264.80MB - val_loss: 20.181161880493164 - val_accuracy: 0.8108108043670654
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 15/15 [==============================] - 21s 1s/step - loss: 19.4830 - accuracy: 0.9635
# Epoch 63/120 - Time: 22.10s - Memory Usage: 6364.77MB - val_loss: 20.026836395263672 - val_accuracy: 0.7207207083702087
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 15/15 [==============================] - 19s 1s/step - loss: 19.3051 - accuracy: 0.9604
# Epoch 64/120 - Time: 21.41s - Memory Usage: 6458.19MB - val_loss: 19.91473388671875 - val_accuracy: 0.7837837934494019
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 15/15 [==============================] - 19s 1s/step - loss: 19.1402 - accuracy: 0.9698
# Epoch 65/120 - Time: 21.40s - Memory Usage: 6475.60MB - val_loss: 19.702295303344727 - val_accuracy: 0.7477477192878723
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 15/15 [==============================] - 19s 1s/step - loss: 19.0080 - accuracy: 0.9583
# Epoch 66/120 - Time: 22.08s - Memory Usage: 6353.09MB - val_loss: 19.677183151245117 - val_accuracy: 0.6936936974525452
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 15/15 [==============================] - 20s 1s/step - loss: 18.8502 - accuracy: 0.9604
# Epoch 67/120 - Time: 21.39s - Memory Usage: 6395.37MB - val_loss: 19.42996597290039 - val_accuracy: 0.7567567825317383
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 15/15 [==============================] - 19s 1s/step - loss: 18.7174 - accuracy: 0.9625
# Epoch 68/120 - Time: 21.41s - Memory Usage: 6460.85MB - val_loss: 19.40275764465332 - val_accuracy: 0.6396396160125732
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 15/15 [==============================] - 19s 1s/step - loss: 18.5754 - accuracy: 0.9688
# Epoch 69/120 - Time: 20.71s - Memory Usage: 6533.63MB - val_loss: 19.371009826660156 - val_accuracy: 0.6486486196517944
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 15/15 [==============================] - 19s 1s/step - loss: 18.4973 - accuracy: 0.9542
# Epoch 70/120 - Time: 21.39s - Memory Usage: 6396.43MB - val_loss: 19.09345817565918 - val_accuracy: 0.7117117047309875
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 15/15 [==============================] - 19s 1s/step - loss: 18.3328 - accuracy: 0.9646
# Epoch 71/120 - Time: 21.40s - Memory Usage: 6503.80MB - val_loss: 18.99057388305664 - val_accuracy: 0.7117117047309875
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 15/15 [==============================] - 20s 1s/step - loss: 18.2424 - accuracy: 0.9594
# Epoch 72/120 - Time: 22.18s - Memory Usage: 6567.84MB - val_loss: 18.814584732055664 - val_accuracy: 0.7837837934494019
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 15/15 [==============================] - 19s 1s/step - loss: 18.1337 - accuracy: 0.9604
# Epoch 73/120 - Time: 21.41s - Memory Usage: 6620.38MB - val_loss: 18.68756103515625 - val_accuracy: 0.8018018007278442
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 15/15 [==============================] - 19s 1s/step - loss: 18.0159 - accuracy: 0.9583
# Epoch 74/120 - Time: 19.68s - Memory Usage: 6446.65MB - val_loss: 18.720932006835938 - val_accuracy: 0.8108108043670654
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 15/15 [==============================] - 20s 1s/step - loss: 17.9228 - accuracy: 0.9656
# Epoch 75/120 - Time: 20.81s - Memory Usage: 6579.88MB - val_loss: 18.671356201171875 - val_accuracy: 0.7207207083702087
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 15/15 [==============================] - 19s 1s/step - loss: 17.8027 - accuracy: 0.9719
# Epoch 76/120 - Time: 21.42s - Memory Usage: 6661.73MB - val_loss: 18.49814796447754 - val_accuracy: 0.7117117047309875
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 15/15 [==============================] - 19s 1s/step - loss: 17.7379 - accuracy: 0.9594
# Epoch 77/120 - Time: 19.94s - Memory Usage: 6789.73MB - val_loss: 18.423107147216797 - val_accuracy: 0.7027027010917664
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 15/15 [==============================] - 20s 1s/step - loss: 17.6127 - accuracy: 0.9760
# Epoch 78/120 - Time: 21.78s - Memory Usage: 4946.34MB - val_loss: 18.362194061279297 - val_accuracy: 0.7747747898101807
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 15/15 [==============================] - 19s 1s/step - loss: 17.5298 - accuracy: 0.9833
# Epoch 79/120 - Time: 19.67s - Memory Usage: 5029.52MB - val_loss: 18.22442054748535 - val_accuracy: 0.7747747898101807
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 15/15 [==============================] - 19s 1s/step - loss: 17.5017 - accuracy: 0.9531
# Epoch 80/120 - Time: 20.89s - Memory Usage: 5099.71MB - val_loss: 18.451143264770508 - val_accuracy: 0.6396396160125732
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 15/15 [==============================] - 20s 1s/step - loss: 17.3752 - accuracy: 0.9719
# Epoch 81/120 - Time: 21.40s - Memory Usage: 5225.71MB - val_loss: 18.073461532592773 - val_accuracy: 0.792792797088623
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 15/15 [==============================] - 19s 1s/step - loss: 17.3206 - accuracy: 0.9635
# Epoch 82/120 - Time: 21.49s - Memory Usage: 4968.74MB - val_loss: 17.93016242980957 - val_accuracy: 0.792792797088623
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 15/15 [==============================] - 20s 1s/step - loss: 17.2337 - accuracy: 0.9677
# Epoch 83/120 - Time: 20.77s - Memory Usage: 5021.93MB - val_loss: 17.855955123901367 - val_accuracy: 0.8108108043670654
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 15/15 [==============================] - 19s 1s/step - loss: 17.2086 - accuracy: 0.9521
# Epoch 84/120 - Time: 21.39s - Memory Usage: 5148.71MB - val_loss: 17.835826873779297 - val_accuracy: 0.7657657861709595
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 15/15 [==============================] - 19s 1s/step - loss: 17.1214 - accuracy: 0.9656
# Epoch 85/120 - Time: 19.68s - Memory Usage: 5250.28MB - val_loss: 17.842634201049805 - val_accuracy: 0.7387387156486511
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 15/15 [==============================] - 20s 1s/step - loss: 17.0323 - accuracy: 0.9792
# Epoch 86/120 - Time: 21.42s - Memory Usage: 4967.11MB - val_loss: 17.751462936401367 - val_accuracy: 0.7117117047309875
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 15/15 [==============================] - 19s 1s/step - loss: 16.9739 - accuracy: 0.9750
# Epoch 87/120 - Time: 21.40s - Memory Usage: 5043.28MB - val_loss: 17.61250877380371 - val_accuracy: 0.792792797088623
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 15/15 [==============================] - 19s 1s/step - loss: 16.9182 - accuracy: 0.9729
# Epoch 88/120 - Time: 20.48s - Memory Usage: 5102.48MB - val_loss: 17.64272117614746 - val_accuracy: 0.7567567825317383
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 15/15 [==============================] - 19s 1s/step - loss: 16.9328 - accuracy: 0.9438
# Epoch 89/120 - Time: 20.21s - Memory Usage: 5233.95MB - val_loss: 17.69232749938965 - val_accuracy: 0.8108108043670654
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 15/15 [==============================] - 20s 1s/step - loss: 16.8363 - accuracy: 0.9604
# Epoch 90/120 - Time: 20.91s - Memory Usage: 4988.21MB - val_loss: 17.55242919921875 - val_accuracy: 0.7837837934494019
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 15/15 [==============================] - 20s 1s/step - loss: 16.7442 - accuracy: 0.9781
# Epoch 91/120 - Time: 21.40s - Memory Usage: 5066.06MB - val_loss: 17.56464195251465 - val_accuracy: 0.7477477192878723
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 15/15 [==============================] - 19s 1s/step - loss: 16.7022 - accuracy: 0.9781
# Epoch 92/120 - Time: 21.38s - Memory Usage: 5151.61MB - val_loss: 17.58189582824707 - val_accuracy: 0.8018018007278442
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 15/15 [==============================] - 19s 1s/step - loss: 16.6561 - accuracy: 0.9740
# Epoch 93/120 - Time: 19.55s - Memory Usage: 5271.06MB - val_loss: 17.46673583984375 - val_accuracy: 0.7567567825317383
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 15/15 [==============================] - 20s 1s/step - loss: 16.6113 - accuracy: 0.9729
# Epoch 94/120 - Time: 21.42s - Memory Usage: 5061.01MB - val_loss: 17.50970458984375 - val_accuracy: 0.6756756901741028
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 15/15 [==============================] - 19s 1s/step - loss: 16.5505 - accuracy: 0.9802
# Epoch 95/120 - Time: 21.40s - Memory Usage: 5131.23MB - val_loss: 17.356002807617188 - val_accuracy: 0.8018018007278442
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 15/15 [==============================] - 19s 1s/step - loss: 16.5229 - accuracy: 0.9719
# Epoch 96/120 - Time: 20.05s - Memory Usage: 5206.17MB - val_loss: 17.373701095581055 - val_accuracy: 0.7117117047309875
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 15/15 [==============================] - 20s 1s/step - loss: 16.4725 - accuracy: 0.9750
# Epoch 97/120 - Time: 21.40s - Memory Usage: 5321.64MB - val_loss: 17.267698287963867 - val_accuracy: 0.7477477192878723
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 15/15 [==============================] - 19s 1s/step - loss: 16.4411 - accuracy: 0.9729
# Epoch 98/120 - Time: 19.79s - Memory Usage: 5058.33MB - val_loss: 17.90986442565918 - val_accuracy: 0.5855855941772461
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 15/15 [==============================] - 20s 1s/step - loss: 16.3869 - accuracy: 0.9792
# Epoch 99/120 - Time: 21.44s - Memory Usage: 5135.19MB - val_loss: 17.129621505737305 - val_accuracy: 0.792792797088623
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 15/15 [==============================] - 19s 1s/step - loss: 16.3489 - accuracy: 0.9781
# Epoch 100/120 - Time: 20.82s - Memory Usage: 5164.07MB - val_loss: 17.141254425048828 - val_accuracy: 0.8018018007278442
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 15/15 [==============================] - 19s 1s/step - loss: 16.3329 - accuracy: 0.9646
# Epoch 101/120 - Time: 21.40s - Memory Usage: 5244.79MB - val_loss: 16.98958969116211 - val_accuracy: 0.8018018007278442
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 15/15 [==============================] - 20s 1s/step - loss: 16.2770 - accuracy: 0.9812
# Epoch 102/120 - Time: 21.41s - Memory Usage: 4963.24MB - val_loss: 17.070459365844727 - val_accuracy: 0.7387387156486511
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 15/15 [==============================] - 19s 1s/step - loss: 16.2887 - accuracy: 0.9604
# Epoch 103/120 - Time: 19.96s - Memory Usage: 4970.79MB - val_loss: 16.963754653930664 - val_accuracy: 0.8108108043670654
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 15/15 [==============================] - 19s 1s/step - loss: 16.2209 - accuracy: 0.9750
# Epoch 104/120 - Time: 21.80s - Memory Usage: 5071.45MB - val_loss: 17.281620025634766 - val_accuracy: 0.6396396160125732
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 15/15 [==============================] - 20s 1s/step - loss: 16.1858 - accuracy: 0.9698
# Epoch 105/120 - Time: 20.57s - Memory Usage: 5175.42MB - val_loss: 17.069856643676758 - val_accuracy: 0.7297297120094299
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 15/15 [==============================] - 19s 1s/step - loss: 16.1666 - accuracy: 0.9708
# Epoch 106/120 - Time: 21.43s - Memory Usage: 4939.66MB - val_loss: 16.99566650390625 - val_accuracy: 0.7747747898101807
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 15/15 [==============================] - 19s 1s/step - loss: 16.1211 - accuracy: 0.9740
# Epoch 107/120 - Time: 21.62s - Memory Usage: 4993.18MB - val_loss: 16.911861419677734 - val_accuracy: 0.7657657861709595
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 15/15 [==============================] - 20s 1s/step - loss: 16.0922 - accuracy: 0.9760
# Epoch 108/120 - Time: 20.67s - Memory Usage: 5125.78MB - val_loss: 16.942607879638672 - val_accuracy: 0.7387387156486511
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 15/15 [==============================] - 20s 1s/step - loss: 16.0351 - accuracy: 0.9854
# Epoch 109/120 - Time: 20.91s - Memory Usage: 5229.60MB - val_loss: 16.828704833984375 - val_accuracy: 0.7747747898101807
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 15/15 [==============================] - 20s 1s/step - loss: 16.0129 - accuracy: 0.9875
# Epoch 110/120 - Time: 22.17s - Memory Usage: 5016.52MB - val_loss: 16.84292221069336 - val_accuracy: 0.7207207083702087
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 15/15 [==============================] - 20s 1s/step - loss: 15.9970 - accuracy: 0.9771
# Epoch 111/120 - Time: 21.03s - Memory Usage: 5140.90MB - val_loss: 16.812938690185547 - val_accuracy: 0.6756756901741028
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 15/15 [==============================] - 19s 1s/step - loss: 15.9668 - accuracy: 0.9833
# Epoch 112/120 - Time: 19.77s - Memory Usage: 5158.86MB - val_loss: 16.808841705322266 - val_accuracy: 0.7747747898101807
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 15/15 [==============================] - 20s 1s/step - loss: 15.9541 - accuracy: 0.9750
# Epoch 113/120 - Time: 20.82s - Memory Usage: 5243.89MB - val_loss: 16.80848503112793 - val_accuracy: 0.7747747898101807
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 15/15 [==============================] - 19s 1s/step - loss: 15.9257 - accuracy: 0.9781
# Epoch 114/120 - Time: 21.43s - Memory Usage: 5006.97MB - val_loss: 16.798784255981445 - val_accuracy: 0.8018018007278442
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 15/15 [==============================] - 19s 1s/step - loss: 15.9300 - accuracy: 0.9667
# Epoch 115/120 - Time: 21.40s - Memory Usage: 5076.47MB - val_loss: 16.74223518371582 - val_accuracy: 0.7837837934494019
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 15/15 [==============================] - 20s 1s/step - loss: 15.8852 - accuracy: 0.9781
# Epoch 116/120 - Time: 21.58s - Memory Usage: 5207.32MB - val_loss: 16.91466522216797 - val_accuracy: 0.7027027010917664
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 15/15 [==============================] - 19s 1s/step - loss: 15.8443 - accuracy: 0.9844
# Epoch 117/120 - Time: 21.38s - Memory Usage: 5311.47MB - val_loss: 16.970884323120117 - val_accuracy: 0.6576576828956604
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 15/15 [==============================] - 20s 1s/step - loss: 15.8209 - accuracy: 0.9854
# Epoch 118/120 - Time: 21.44s - Memory Usage: 4997.39MB - val_loss: 16.67377281188965 - val_accuracy: 0.7387387156486511
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 15/15 [==============================] - 20s 1s/step - loss: 15.8173 - accuracy: 0.9792
# Epoch 119/120 - Time: 21.11s - Memory Usage: 5089.09MB - val_loss: 16.798006057739258 - val_accuracy: 0.6396396160125732
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 15/15 [==============================] - 19s 1s/step - loss: 15.7971 - accuracy: 0.9760
# Epoch 120/120 - Time: 21.40s - Memory Usage: 5212.96MB - val_loss: 16.691869735717773 - val_accuracy: 0.6666666865348816
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*

# %% [markdown]
# ###Metrics Evaluation###

# %%
predictedLabels = model.predict(testImages)
predictedClasses = np.argmax(predictedLabels, axis = 1)

report = classification_report(testLabels.argmax(axis = 1), predictedClasses)
print(report)
# Out:
# 4/4 [==============================] - 1s 83ms/step
#               precision    recall  f1-score   support
#
#            0       0.35      0.56      0.43        25
#            1       0.85      0.70      0.76        86
#
#     accuracy                           0.67       111
#    macro avg       0.60      0.63      0.60       111
# weighted avg       0.73      0.67      0.69       111

# %%
plt.figure(figsize=(8, 5))
plt.plot(range(1, num_epochs + 1), testAccuracy, color='b')
plt.xlabel('Epoch')
plt.ylabel('Test Accuracy')
plt.title('Test Accuracy over Epochs')
plt.ylim([0, 1])  # Set y-axis limit between 0 and 1
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(10, 5))

plt.subplot(1, 2, 1)
plt.plot(range(1, num_epochs + 1), training_times)
plt.xlabel('Epoch')
plt.ylabel('Time (s)')
plt.title('Training Speed per Epoch')

plt.subplot(1, 2, 2)
plt.plot(range(1, num_epochs + 1), memory_usage, color='orange')
plt.xlabel('Epoch')
plt.ylabel('Memory Usage (GB)')
plt.title('Memory Usage per Epoch')

plt.tight_layout()
plt.show()
