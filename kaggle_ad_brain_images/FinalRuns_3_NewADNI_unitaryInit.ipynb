# %% [markdown]
# ###Start###

# %% [markdown]
# This version is the most normal version of all versions. In this version unitary initialization used but BN and L2 have been removed from architecture of the model.

# %%
import tensorflow as tf
import numpy as np
import os, random
import matplotlib.pyplot as plt
from keras import layers
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras import regularizers
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras.models import load_model
from tensorflow.keras.optimizers.schedules import ExponentialDecay
from tensorflow.keras.optimizers import Adam
from imblearn.over_sampling import RandomOverSampler
from sklearn.metrics import classification_report
import time
import psutil

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
path = '/content/drive/MyDrive/Kag-adni-unBalance/Preprocessed/'
trainImages = np.load(path + 'trainImages.npy')
trainLabels = np.load(path + 'trainLabels.npy')
testImages  = np.load(path + 'testImages.npy')
testLabels  = np.load(path + 'testLabels.npy')

# %%
augmented = ImageDataGenerator(rotation_range=12,
                               width_shift_range = 0.1,
                               height_shift_range= 0.1,
                               zoom_range=0.1,
                               horizontal_flip= True)
augmented.fit(trainImages)
augmented.fit(testImages)

# %% [markdown]
# ###Data Check

# %%
#Data Loading Check
plt.imshow(trainImages[254])
print(trainImages.shape, " ", trainImages.dtype)
print(trainLabels.shape)
print(testImages.shape)
print(testLabels.shape)
# Out:
# (960, 256, 256, 3)   float32
# (960, 2)
# (111, 256, 256, 3)
# (111, 2)

# %%
\
classes = ['AD', 'CN']

figure, axes = plt.subplots(4, 5, figsize= (12,12))
for i in range(len(trainImages)):
  if trainLabels[i][0] == 1 :
    titleIndex = 0
  else :
    titleIndex = 1
  ax_row = i // 5
  ax_col = i % 5
  if ax_row ==4 or ax_col==5:
    break
  ax = axes[ax_row][ax_col]
  ax.imshow(trainImages[i])
  ax.set_title(classes[titleIndex])
  ax.axis('off')

plt.tight_layout()
plt.show()

# %% [markdown]
# ###Unitary Regularizer###

# %%
# used version 1.2
import tensorflow.keras.backend as K
class UnitaryRegularizer(tf.keras.regularizers.Regularizer):
    def __init__(self, lambd):
        self.lambd = lambd

    def __call__(self, weights):
        # Get the number of output neurons
        num_output_neurons = weights.shape[-1]

        # Reshape the weight matrix to be a 2D matrix (flatten filters)
        flattened_weights = tf.reshape(weights, (-1, num_output_neurons))

        # Calculate the matrix product and the identity matrix
        product = tf.matmul(flattened_weights, tf.transpose(flattened_weights))
        identity_matrix = tf.eye(product.shape[0])

        # Calculate the Frobenius norm for each filter separately
        filter_norms = tf.norm(product - identity_matrix, axis=[-2, -1])
        #print(filter_norms)

        # Calculate the regularization term as the sum of squared Frobenius norms
        regularization = 0.5 * self.lambd * tf.reduce_sum(tf.square(filter_norms))
        #tf.print(regularization)
        return regularization

    def get_config(self):
        return {'lambd': self.lambd}

# %% [markdown]
# ###MODEL

# %%
my_resnet = tf.keras.applications.ResNet50(input_shape=(256, 256, 3), include_top=False)
my_resnet.trainable = False
custom_lambd = 0.01
model = tf.keras.Sequential([
    tf.keras.layers.Input((256, 256, 3)),
    #tf.keras.layers.BatchNormalization(),
    my_resnet,
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.Conv2D(filters = 256, kernel_size = (3, 3),
                             activation = tf.nn.
                           relu , name='conv1', padding='same'),
    #tf.keras.layers.BatchNormalization(),
    tf.keras.layers.MaxPool2D(pool_size=(2, 2), name='pool1'),
    tf.keras.layers.Conv2D(filters = 128, kernel_size = (3, 3),
                             activation = tf.nn.relu, padding='same',
                            name='conv2'),
                           #kernel_regularizer= UnitaryRegularizer(lambd=custom_lambd) ),
    tf.keras.layers.Conv2D(filters = 64, kernel_size = (3, 3),
                             activation = tf.nn.relu, name='conv3',
                            padding='same'),
    tf.keras.layers.MaxPool2D(pool_size=(2, 2), name='pool3'),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.Conv2D(filters = 32, kernel_size = (3, 3),
                           activation= tf.nn.relu, padding='same',
                           name='conv4'),
                           #kernel_regularizer= UnitaryRegularizer(lambd=custom_lambd) ),
    tf.keras.layers.Conv2D(filters = 32, kernel_size = (3, 3),
                           activation= tf.nn.relu, padding='same',
                           name='conv5'),
                           #kernel_regularizer= UnitaryRegularizer(lambd=custom_lambd) ),
    #tf.keras.layers.BatchNormalization(),
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(128, activation = tf.nn.relu),
    tf.keras.layers.Dense(64, activation = tf.nn.relu),
                          #kernel_regularizer=regularizers.l2(0.01)),
    tf.keras.layers.Dense(2, activation = 'sigmoid')
])

# %% [markdown]
# ###Unitary Initialization###

# %%
# this function below is utilizing CPU because of using NUMPY
def unitarizer(weightArr):
  unitaryMatrices = np.empty_like(weightArr)
  print("1")
  weightArr_tr = np.transpose(weightArr, (3, 2, 0, 1))
  print("2 tr: ", weightArr_tr.shape)
  U, SIGMA, V_trans = np.linalg.svd(weightArr_tr)
  print("3 ", V_trans.shape)
  W = V_trans.T
  print("4 ", W.shape)
  W = np.reshape(W, weightArr.shape)
  print("5")
  #unitaryMatrices[:,:,i,j] = unitarySingleKernel
  return W

# %%
trainableWeights = model.trainable_weights
print("the shape of trainable weights in first conv", trainableWeights[12].shape)
# Out:
# the shape of trainable weights in first conv (3, 3, 32, 32)

# %%
indecies = [4, 10, 12]

for idx in indecies:
  print("***********************  Convolution is unitarizing ", idx, " ************************")
  convWeights  = trainableWeights[idx]
  print(convWeights.shape)
  U_convWeights = unitarizer(convWeights)
  print(U_convWeights[0][0][16][16])
  print("*************************  Convolution unitarized ", idx, "  *************************")
  model.trainable_weights[idx].assign(U_convWeights)
  convtester = model.trainable_weights[idx]
  print("************************* Convolution unitaryCheck ", idx, " *************************")
  print(convtester[0][0][16][16])
# Out:
# ***********************  Convolution is unitarizing  4  ************************
# (3, 3, 256, 128)
# 1
# 2 tr:  (128, 256, 3, 3)
# 3  (128, 256, 3, 3)
# 4  (3, 3, 256, 128)
# 5
# -0.5094888
# *************************  Convolution unitarized  4   *************************
# ************************* Convolution unitaryCheck  4  *************************
# tf.Tensor(-0.5094888, shape=(), dtype=float32)
# ***********************  Convolution is unitarizing  10  ************************
# (3, 3, 64, 32)
# 1
# 2 tr:  (32, 64, 3, 3)
# 3  (32, 64, 3, 3)
# 4  (3, 3, 64, 32)
# 5
# 0.6532229
# *************************  Convolution unitarized  10   *************************
# ************************* Convolution unitaryCheck  10  *************************
# tf.Tensor(0.6532229, shape=(), dtype=float32)
# ***********************  Convolution is unitarizing  12  ************************
# (3, 3, 32, 32)
# 1
# 2 tr:  (32, 32, 3, 3)
# 3  (32, 32, 3, 3)
# 4  (3, 3, 32, 32)
# 5
# 0.5089695
# *************************  Convolution unitarized  12   *************************
# ************************* Convolution unitaryCheck  12  *************************
# tf.Tensor(0.5089695, shape=(), dtype=float32)

# %%
#not needed when we regularize it.
# model.layers[6].trainable=False
# model.layers[10].trainable=False
# model.layers[11].trainable=False

# %% [markdown]
# ###Model compile###

# %%
model.compile(optimizer='sgd', loss='binary_crossentropy', metrics=['accuracy'])

# %%
checkpointPath = "/content/drive/MyDrive/Kag-adni-unBalance/finalCheckPoints/FinalRuns3/"

checkPointCallBack = ModelCheckpoint(filepath = checkpointPath,
                                     monitor = 'val_accuracy',
                                     mode='max', save_best_only = True)

# %% [markdown]
# ###Model Check

# %%
tf.keras.utils.plot_model(model, show_shapes = True,
                          show_layer_activations=True, show_trainable= True)

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  resnet50 (Functional)       (None, 8, 8, 2048)        23587712
#
#  conv1 (Conv2D)              (None, 8, 8, 256)         4718848
#
#  pool1 (MaxPooling2D)        (None, 4, 4, 256)         0
#
#  conv2 (Conv2D)              (None, 4, 4, 128)         295040
#
#  conv3 (Conv2D)              (None, 4, 4, 64)          73792
#
#  pool3 (MaxPooling2D)        (None, 2, 2, 64)          0
#
#  conv4 (Conv2D)              (None, 2, 2, 32)          18464
#
#  conv5 (Conv2D)              (None, 2, 2, 32)          9248
#
#  flatten_1 (Flatten)         (None, 128)               0
#
#  dense_3 (Dense)             (None, 128)               16512
#
#  dense_4 (Dense)             (None, 64)                8256
#
#  dense_5 (Dense)             (None, 2)                 130
#
# =================================================================
# Total params: 28,728,002
# Trainable params: 5,140,290
# Non-trainable params: 23,587,712
# _________________________________________________________________

# %%
#early_stopping = EarlyStopping(patience=5, restore_best_weights=True)

# %% [markdown]
# ###RUN###

# %%
training_times = []
memory_usage = []
testAccuracy = []
num_epochs = 120
for epoch in range(num_epochs):
  startTime = time.time()
  history = model.fit(augmented.flow(trainImages, trainLabels, batch_size = 64),
                    epochs = 1)
          #validation_data=(testImages, testLabels))
                    #callbacks=[checkPointCallBack])#with version 1.2
  endTime = time.time()
  epochTime = endTime - startTime
  training_times.append(epochTime)
  memory_usage.append(psutil.virtual_memory().used/1024**2)
  testLoss , testAcc = model.evaluate(testImages, testLabels, verbose = 0)
  testAccuracy.append(testAcc)
  print(f"Epoch {epoch + 1}/{num_epochs} - Time: {epochTime:.2f}s - Memory Usage: {memory_usage[-1]:.2f}MB - val_loss: {testLoss} - val_accuracy: {testAcc}")
  print("*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*")
# Out:
# 15/15 [==============================] - 19s 950ms/step - loss: 4.2687 - accuracy: 0.5083
# Epoch 1/120 - Time: 24.79s - Memory Usage: 5095.46MB - val_loss: 51.76806640625 - val_accuracy: 0.22522522509098053
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 15/15 [==============================] - 15s 986ms/step - loss: 0.7019 - accuracy: 0.5698
# Epoch 2/120 - Time: 15.68s - Memory Usage: 5181.38MB - val_loss: 22.462778091430664 - val_accuracy: 0.22522522509098053
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 15/15 [==============================] - 15s 984ms/step - loss: 0.6962 - accuracy: 0.5688
# Epoch 3/120 - Time: 21.32s - Memory Usage: 5281.26MB - val_loss: 12.563230514526367 - val_accuracy: 0.22522522509098053
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 15/15 [==============================] - 15s 981ms/step - loss: 0.6821 - accuracy: 0.5698
# Epoch 4/120 - Time: 21.29s - Memory Usage: 5383.24MB - val_loss: 6.4310102462768555 - val_accuracy: 0.22522522509098053
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 15/15 [==============================] - 15s 986ms/step - loss: 0.6637 - accuracy: 0.5792
# Epoch 5/120 - Time: 15.66s - Memory Usage: 5420.37MB - val_loss: 3.2376630306243896 - val_accuracy: 0.22522522509098053
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 15/15 [==============================] - 15s 980ms/step - loss: 0.6613 - accuracy: 0.5854
# Epoch 6/120 - Time: 15.75s - Memory Usage: 5218.34MB - val_loss: 1.7993077039718628 - val_accuracy: 0.22522522509098053
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 15/15 [==============================] - 16s 1s/step - loss: 0.6641 - accuracy: 0.5802
# Epoch 7/120 - Time: 16.46s - Memory Usage: 5289.84MB - val_loss: 0.7859950065612793 - val_accuracy: 0.5495495200157166
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 15/15 [==============================] - 15s 980ms/step - loss: 0.6413 - accuracy: 0.5823
# Epoch 8/120 - Time: 15.63s - Memory Usage: 5391.39MB - val_loss: 0.6619046926498413 - val_accuracy: 0.684684693813324
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 15/15 [==============================] - 16s 1s/step - loss: 0.6422 - accuracy: 0.5802
# Epoch 9/120 - Time: 16.91s - Memory Usage: 5456.10MB - val_loss: 0.6614975333213806 - val_accuracy: 0.7297297120094299
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 15/15 [==============================] - 15s 1s/step - loss: 0.6420 - accuracy: 0.5698
# Epoch 10/120 - Time: 16.17s - Memory Usage: 5255.90MB - val_loss: 0.6365368962287903 - val_accuracy: 0.7657657861709595
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 15/15 [==============================] - 15s 992ms/step - loss: 0.6365 - accuracy: 0.5948
# Epoch 11/120 - Time: 16.47s - Memory Usage: 5342.28MB - val_loss: 0.630719006061554 - val_accuracy: 0.7477477192878723
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 15/15 [==============================] - 15s 996ms/step - loss: 0.6362 - accuracy: 0.5948
# Epoch 12/120 - Time: 15.85s - Memory Usage: 5427.91MB - val_loss: 0.6818305253982544 - val_accuracy: 0.5855855941772461
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 15/15 [==============================] - 15s 1s/step - loss: 0.6238 - accuracy: 0.6042
# Epoch 13/120 - Time: 15.92s - Memory Usage: 5511.28MB - val_loss: 0.6937587261199951 - val_accuracy: 0.5675675868988037
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 15/15 [==============================] - 16s 1s/step - loss: 0.6408 - accuracy: 0.6042
# Epoch 14/120 - Time: 21.50s - Memory Usage: 5269.30MB - val_loss: 0.7273879647254944 - val_accuracy: 0.4864864945411682
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 15/15 [==============================] - 16s 1s/step - loss: 0.6321 - accuracy: 0.6042
# Epoch 15/120 - Time: 21.30s - Memory Usage: 5350.05MB - val_loss: 0.70822674036026 - val_accuracy: 0.5315315127372742
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 15/15 [==============================] - 15s 1s/step - loss: 0.6383 - accuracy: 0.6073
# Epoch 16/120 - Time: 16.26s - Memory Usage: 5345.32MB - val_loss: 0.7562662959098816 - val_accuracy: 0.45045045018196106
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 15/15 [==============================] - 15s 1s/step - loss: 0.6359 - accuracy: 0.6073
# Epoch 17/120 - Time: 21.31s - Memory Usage: 5457.12MB - val_loss: 0.8115500211715698 - val_accuracy: 0.36936935782432556
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 15/15 [==============================] - 15s 993ms/step - loss: 0.6326 - accuracy: 0.5927
# Epoch 18/120 - Time: 79.14s - Memory Usage: 4846.20MB - val_loss: 0.7208201289176941 - val_accuracy: 0.477477490901947
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 15/15 [==============================] - 15s 1000ms/step - loss: 0.6292 - accuracy: 0.6083
# Epoch 19/120 - Time: 21.64s - Memory Usage: 4967.86MB - val_loss: 0.6994619965553284 - val_accuracy: 0.5585585832595825
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 15/15 [==============================] - 16s 1s/step - loss: 0.6203 - accuracy: 0.6187
# Epoch 20/120 - Time: 16.79s - Memory Usage: 5046.25MB - val_loss: 0.8996490836143494 - val_accuracy: 0.30630630254745483
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 15/15 [==============================] - 15s 996ms/step - loss: 0.6397 - accuracy: 0.5854
# Epoch 21/120 - Time: 15.86s - Memory Usage: 5197.28MB - val_loss: 0.7042286396026611 - val_accuracy: 0.522522509098053
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 15/15 [==============================] - 15s 995ms/step - loss: 0.6304 - accuracy: 0.6104
# Epoch 22/120 - Time: 21.34s - Memory Usage: 4987.08MB - val_loss: 0.7847429513931274 - val_accuracy: 0.36036035418510437
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 15/15 [==============================] - 15s 999ms/step - loss: 0.6162 - accuracy: 0.6062
# Epoch 23/120 - Time: 21.29s - Memory Usage: 4982.56MB - val_loss: 0.7792940735816956 - val_accuracy: 0.342342346906662
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 15/15 [==============================] - 16s 1s/step - loss: 0.6215 - accuracy: 0.6177
# Epoch 24/120 - Time: 16.98s - Memory Usage: 5042.40MB - val_loss: 0.762258768081665 - val_accuracy: 0.3963963985443115
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 15/15 [==============================] - 15s 990ms/step - loss: 0.6182 - accuracy: 0.5969
# Epoch 25/120 - Time: 21.30s - Memory Usage: 5034.23MB - val_loss: 0.697704017162323 - val_accuracy: 0.5135135054588318
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 15/15 [==============================] - 16s 994ms/step - loss: 0.6183 - accuracy: 0.6104
# Epoch 26/120 - Time: 17.27s - Memory Usage: 4876.91MB - val_loss: 0.6492927670478821 - val_accuracy: 0.630630612373352
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 15/15 [==============================] - 15s 995ms/step - loss: 0.6337 - accuracy: 0.6083
# Epoch 27/120 - Time: 15.82s - Memory Usage: 4865.07MB - val_loss: 0.7440866827964783 - val_accuracy: 0.44144144654273987
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 15/15 [==============================] - 16s 1s/step - loss: 0.6213 - accuracy: 0.6198
# Epoch 28/120 - Time: 17.10s - Memory Usage: 4899.55MB - val_loss: 0.701061487197876 - val_accuracy: 0.5045045018196106
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 15/15 [==============================] - 15s 1s/step - loss: 0.6196 - accuracy: 0.6115
# Epoch 29/120 - Time: 15.89s - Memory Usage: 5023.98MB - val_loss: 0.6239905953407288 - val_accuracy: 0.6666666865348816
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 15/15 [==============================] - 15s 1s/step - loss: 0.6415 - accuracy: 0.5854
# Epoch 30/120 - Time: 16.78s - Memory Usage: 4794.24MB - val_loss: 0.647676944732666 - val_accuracy: 0.630630612373352
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 15/15 [==============================] - 15s 1s/step - loss: 0.6207 - accuracy: 0.5917
# Epoch 31/120 - Time: 21.32s - Memory Usage: 4900.30MB - val_loss: 0.6205122470855713 - val_accuracy: 0.7387387156486511
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 15/15 [==============================] - 15s 1s/step - loss: 0.6217 - accuracy: 0.6260
# Epoch 32/120 - Time: 16.11s - Memory Usage: 4954.25MB - val_loss: 0.6421161890029907 - val_accuracy: 0.630630612373352
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 15/15 [==============================] - 15s 1s/step - loss: 0.6259 - accuracy: 0.5979
# Epoch 33/120 - Time: 21.30s - Memory Usage: 5015.69MB - val_loss: 0.614460825920105 - val_accuracy: 0.7567567825317383
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 15/15 [==============================] - 15s 1s/step - loss: 0.6147 - accuracy: 0.6000
# Epoch 34/120 - Time: 16.07s - Memory Usage: 4784.33MB - val_loss: 0.5910203456878662 - val_accuracy: 0.7657657861709595
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 15/15 [==============================] - 15s 1000ms/step - loss: 0.6312 - accuracy: 0.6010
# Epoch 35/120 - Time: 21.30s - Memory Usage: 4920.61MB - val_loss: 0.5781299471855164 - val_accuracy: 0.7837837934494019
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 15/15 [==============================] - 15s 1s/step - loss: 0.6181 - accuracy: 0.6115
# Epoch 36/120 - Time: 15.94s - Memory Usage: 5047.48MB - val_loss: 0.5867087841033936 - val_accuracy: 0.7657657861709595
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 15/15 [==============================] - 15s 996ms/step - loss: 0.6292 - accuracy: 0.5917
# Epoch 37/120 - Time: 21.30s - Memory Usage: 5165.87MB - val_loss: 0.5885984897613525 - val_accuracy: 0.8018018007278442
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 15/15 [==============================] - 15s 996ms/step - loss: 0.6230 - accuracy: 0.6000
# Epoch 38/120 - Time: 21.35s - Memory Usage: 4864.55MB - val_loss: 0.5666998028755188 - val_accuracy: 0.8018018007278442
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 15/15 [==============================] - 16s 1s/step - loss: 0.6218 - accuracy: 0.6021
# Epoch 39/120 - Time: 17.65s - Memory Usage: 4966.29MB - val_loss: 0.5975293517112732 - val_accuracy: 0.7477477192878723
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 15/15 [==============================] - 15s 981ms/step - loss: 0.6226 - accuracy: 0.6094
# Epoch 40/120 - Time: 21.32s - Memory Usage: 4997.34MB - val_loss: 0.6041007041931152 - val_accuracy: 0.7567567825317383
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 15/15 [==============================] - 15s 981ms/step - loss: 0.6130 - accuracy: 0.6146
# Epoch 41/120 - Time: 15.68s - Memory Usage: 5086.73MB - val_loss: 0.5640694499015808 - val_accuracy: 0.792792797088623
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 15/15 [==============================] - 15s 994ms/step - loss: 0.6054 - accuracy: 0.6417
# Epoch 42/120 - Time: 21.31s - Memory Usage: 4812.88MB - val_loss: 0.5945872664451599 - val_accuracy: 0.7207207083702087
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 15/15 [==============================] - 15s 983ms/step - loss: 0.6216 - accuracy: 0.6219
# Epoch 43/120 - Time: 21.32s - Memory Usage: 4915.38MB - val_loss: 0.6031986474990845 - val_accuracy: 0.7027027010917664
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 15/15 [==============================] - 15s 994ms/step - loss: 0.6188 - accuracy: 0.6250
# Epoch 44/120 - Time: 16.27s - Memory Usage: 5041.14MB - val_loss: 0.6108792424201965 - val_accuracy: 0.7657657861709595
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 15/15 [==============================] - 15s 1s/step - loss: 0.6153 - accuracy: 0.6083
# Epoch 45/120 - Time: 15.99s - Memory Usage: 5147.66MB - val_loss: 0.6147867441177368 - val_accuracy: 0.7207207083702087
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 15/15 [==============================] - 15s 999ms/step - loss: 0.6124 - accuracy: 0.6385
# Epoch 46/120 - Time: 15.92s - Memory Usage: 4889.84MB - val_loss: 0.5983632206916809 - val_accuracy: 0.7297297120094299
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 15/15 [==============================] - 16s 994ms/step - loss: 0.6212 - accuracy: 0.6302
# Epoch 47/120 - Time: 17.16s - Memory Usage: 4954.54MB - val_loss: 0.6229907870292664 - val_accuracy: 0.7387387156486511
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 15/15 [==============================] - 15s 988ms/step - loss: 0.6070 - accuracy: 0.6500
# Epoch 48/120 - Time: 21.31s - Memory Usage: 4988.38MB - val_loss: 0.6455060243606567 - val_accuracy: 0.6666666865348816
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 15/15 [==============================] - 15s 990ms/step - loss: 0.6178 - accuracy: 0.5990
# Epoch 49/120 - Time: 16.61s - Memory Usage: 5050.02MB - val_loss: 0.6260168552398682 - val_accuracy: 0.6666666865348816
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 15/15 [==============================] - 16s 1s/step - loss: 0.6184 - accuracy: 0.6198
# Epoch 50/120 - Time: 17.21s - Memory Usage: 4778.12MB - val_loss: 0.6469449996948242 - val_accuracy: 0.6756756901741028
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 15/15 [==============================] - 15s 998ms/step - loss: 0.6208 - accuracy: 0.6156
# Epoch 51/120 - Time: 15.87s - Memory Usage: 4853.18MB - val_loss: 0.6256966590881348 - val_accuracy: 0.7387387156486511
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 15/15 [==============================] - 16s 999ms/step - loss: 0.6154 - accuracy: 0.6198
# Epoch 52/120 - Time: 22.05s - Memory Usage: 4958.40MB - val_loss: 0.6317926645278931 - val_accuracy: 0.7207207083702087
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 15/15 [==============================] - 15s 994ms/step - loss: 0.6240 - accuracy: 0.6156
# Epoch 53/120 - Time: 21.32s - Memory Usage: 5112.03MB - val_loss: 0.6040398478507996 - val_accuracy: 0.7117117047309875
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 15/15 [==============================] - 15s 998ms/step - loss: 0.6152 - accuracy: 0.6354
# Epoch 54/120 - Time: 21.32s - Memory Usage: 4868.33MB - val_loss: 0.6328197717666626 - val_accuracy: 0.7117117047309875
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 15/15 [==============================] - 15s 1000ms/step - loss: 0.6007 - accuracy: 0.6250
# Epoch 55/120 - Time: 21.36s - Memory Usage: 4934.69MB - val_loss: 0.6717674136161804 - val_accuracy: 0.684684693813324
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 15/15 [==============================] - 15s 1s/step - loss: 0.6227 - accuracy: 0.6094
# Epoch 56/120 - Time: 22.02s - Memory Usage: 5061.12MB - val_loss: 0.576114296913147 - val_accuracy: 0.7747747898101807
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 15/15 [==============================] - 15s 993ms/step - loss: 0.6041 - accuracy: 0.6302
# Epoch 57/120 - Time: 21.35s - Memory Usage: 5173.49MB - val_loss: 0.6265113949775696 - val_accuracy: 0.7567567825317383
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 15/15 [==============================] - 15s 999ms/step - loss: 0.6216 - accuracy: 0.6042
# Epoch 58/120 - Time: 21.32s - Memory Usage: 4879.68MB - val_loss: 0.6500135660171509 - val_accuracy: 0.7027027010917664
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 15/15 [==============================] - 15s 1s/step - loss: 0.6106 - accuracy: 0.6323
# Epoch 59/120 - Time: 21.31s - Memory Usage: 5002.92MB - val_loss: 0.600245475769043 - val_accuracy: 0.7477477192878723
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 15/15 [==============================] - 17s 1s/step - loss: 0.6074 - accuracy: 0.6281
# Epoch 60/120 - Time: 18.47s - Memory Usage: 5082.16MB - val_loss: 0.6357045769691467 - val_accuracy: 0.7387387156486511
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 15/15 [==============================] - 15s 994ms/step - loss: 0.6158 - accuracy: 0.6292
# Epoch 61/120 - Time: 21.31s - Memory Usage: 5146.09MB - val_loss: 0.6236024498939514 - val_accuracy: 0.7027027010917664
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 15/15 [==============================] - 16s 1s/step - loss: 0.6112 - accuracy: 0.6062
# Epoch 62/120 - Time: 21.87s - Memory Usage: 4871.04MB - val_loss: 0.5938245058059692 - val_accuracy: 0.7387387156486511
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 15/15 [==============================] - 15s 1s/step - loss: 0.5987 - accuracy: 0.6771
# Epoch 63/120 - Time: 21.32s - Memory Usage: 4986.41MB - val_loss: 0.6781011819839478 - val_accuracy: 0.6216216087341309
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 15/15 [==============================] - 15s 989ms/step - loss: 0.6045 - accuracy: 0.6229
# Epoch 64/120 - Time: 21.29s - Memory Usage: 5075.00MB - val_loss: 0.6589003801345825 - val_accuracy: 0.6666666865348816
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 15/15 [==============================] - 15s 989ms/step - loss: 0.5993 - accuracy: 0.6281
# Epoch 65/120 - Time: 15.73s - Memory Usage: 5059.47MB - val_loss: 0.6256977915763855 - val_accuracy: 0.7477477192878723
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 15/15 [==============================] - 15s 999ms/step - loss: 0.6056 - accuracy: 0.6375
# Epoch 66/120 - Time: 21.34s - Memory Usage: 4781.05MB - val_loss: 0.7184137105941772 - val_accuracy: 0.5945945978164673
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 15/15 [==============================] - 15s 985ms/step - loss: 0.6082 - accuracy: 0.6177
# Epoch 67/120 - Time: 15.65s - Memory Usage: 4836.36MB - val_loss: 0.6601148247718811 - val_accuracy: 0.684684693813324
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 15/15 [==============================] - 15s 986ms/step - loss: 0.6220 - accuracy: 0.6229
# Epoch 68/120 - Time: 21.38s - Memory Usage: 4881.41MB - val_loss: 0.6797463893890381 - val_accuracy: 0.6036036014556885
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 15/15 [==============================] - 15s 1s/step - loss: 0.6074 - accuracy: 0.6229
# Epoch 69/120 - Time: 21.31s - Memory Usage: 5016.87MB - val_loss: 0.6201188564300537 - val_accuracy: 0.7207207083702087
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 15/15 [==============================] - 17s 1s/step - loss: 0.5998 - accuracy: 0.6531
# Epoch 70/120 - Time: 18.15s - Memory Usage: 4847.86MB - val_loss: 0.6746235489845276 - val_accuracy: 0.5945945978164673
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 15/15 [==============================] - 15s 993ms/step - loss: 0.6059 - accuracy: 0.6250
# Epoch 71/120 - Time: 15.85s - Memory Usage: 4935.73MB - val_loss: 0.6188201904296875 - val_accuracy: 0.7477477192878723
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 15/15 [==============================] - 15s 1s/step - loss: 0.6075 - accuracy: 0.6385
# Epoch 72/120 - Time: 15.90s - Memory Usage: 4975.17MB - val_loss: 0.6267906427383423 - val_accuracy: 0.7387387156486511
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 15/15 [==============================] - 15s 983ms/step - loss: 0.6077 - accuracy: 0.6344
# Epoch 73/120 - Time: 16.72s - Memory Usage: 5051.33MB - val_loss: 0.6580858826637268 - val_accuracy: 0.7117117047309875
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 15/15 [==============================] - 15s 995ms/step - loss: 0.5991 - accuracy: 0.6479
# Epoch 74/120 - Time: 21.32s - Memory Usage: 4808.82MB - val_loss: 0.6464144587516785 - val_accuracy: 0.6576576828956604
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 15/15 [==============================] - 15s 993ms/step - loss: 0.6033 - accuracy: 0.6323
# Epoch 75/120 - Time: 16.60s - Memory Usage: 4915.22MB - val_loss: 0.5733979344367981 - val_accuracy: 0.7657657861709595
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 15/15 [==============================] - 15s 991ms/step - loss: 0.6035 - accuracy: 0.6292
# Epoch 76/120 - Time: 21.32s - Memory Usage: 4984.10MB - val_loss: 0.6263278126716614 - val_accuracy: 0.6666666865348816
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 15/15 [==============================] - 15s 991ms/step - loss: 0.6072 - accuracy: 0.6448
# Epoch 77/120 - Time: 16.31s - Memory Usage: 5102.43MB - val_loss: 0.6363798975944519 - val_accuracy: 0.6756756901741028
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 15/15 [==============================] - 15s 987ms/step - loss: 0.5885 - accuracy: 0.6438
# Epoch 78/120 - Time: 15.81s - Memory Usage: 4831.80MB - val_loss: 0.6146712899208069 - val_accuracy: 0.7477477192878723
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 15/15 [==============================] - 15s 994ms/step - loss: 0.6095 - accuracy: 0.6208
# Epoch 79/120 - Time: 21.31s - Memory Usage: 4944.70MB - val_loss: 0.622267484664917 - val_accuracy: 0.7387387156486511
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 15/15 [==============================] - 15s 990ms/step - loss: 0.6086 - accuracy: 0.6542
# Epoch 80/120 - Time: 21.30s - Memory Usage: 4999.56MB - val_loss: 0.614309549331665 - val_accuracy: 0.6936936974525452
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 15/15 [==============================] - 16s 1s/step - loss: 0.5877 - accuracy: 0.6490
# Epoch 81/120 - Time: 21.30s - Memory Usage: 5067.52MB - val_loss: 0.6586399674415588 - val_accuracy: 0.6576576828956604
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 15/15 [==============================] - 16s 1s/step - loss: 0.6033 - accuracy: 0.6250
# Epoch 82/120 - Time: 16.90s - Memory Usage: 4798.14MB - val_loss: 0.671561598777771 - val_accuracy: 0.7207207083702087
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 15/15 [==============================] - 15s 991ms/step - loss: 0.6052 - accuracy: 0.6187
# Epoch 83/120 - Time: 15.80s - Memory Usage: 4876.73MB - val_loss: 0.6128796339035034 - val_accuracy: 0.7477477192878723
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 15/15 [==============================] - 15s 990ms/step - loss: 0.6120 - accuracy: 0.6479
# Epoch 84/120 - Time: 21.30s - Memory Usage: 4912.60MB - val_loss: 0.6172103881835938 - val_accuracy: 0.7207207083702087
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 15/15 [==============================] - 15s 992ms/step - loss: 0.5966 - accuracy: 0.6510
# Epoch 85/120 - Time: 21.30s - Memory Usage: 4970.91MB - val_loss: 0.577599823474884 - val_accuracy: 0.7657657861709595
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 15/15 [==============================] - 15s 991ms/step - loss: 0.6056 - accuracy: 0.6271
# Epoch 86/120 - Time: 22.03s - Memory Usage: 4788.69MB - val_loss: 0.6460610032081604 - val_accuracy: 0.7297297120094299
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 15/15 [==============================] - 15s 986ms/step - loss: 0.6029 - accuracy: 0.6479
# Epoch 87/120 - Time: 21.31s - Memory Usage: 4891.47MB - val_loss: 0.6484245657920837 - val_accuracy: 0.7387387156486511
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 15/15 [==============================] - 15s 990ms/step - loss: 0.5901 - accuracy: 0.6677
# Epoch 88/120 - Time: 21.31s - Memory Usage: 4978.77MB - val_loss: 0.6558806300163269 - val_accuracy: 0.7297297120094299
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 15/15 [==============================] - 15s 994ms/step - loss: 0.5950 - accuracy: 0.6406
# Epoch 89/120 - Time: 15.84s - Memory Usage: 5062.50MB - val_loss: 0.6462167501449585 - val_accuracy: 0.7477477192878723
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 15/15 [==============================] - 15s 998ms/step - loss: 0.5817 - accuracy: 0.6510
# Epoch 90/120 - Time: 15.87s - Memory Usage: 4839.13MB - val_loss: 0.662460446357727 - val_accuracy: 0.7117117047309875
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 15/15 [==============================] - 16s 1s/step - loss: 0.6092 - accuracy: 0.6365
# Epoch 91/120 - Time: 21.35s - Memory Usage: 4968.57MB - val_loss: 0.6215603351593018 - val_accuracy: 0.7567567825317383
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 15/15 [==============================] - 15s 995ms/step - loss: 0.5882 - accuracy: 0.6625
# Epoch 92/120 - Time: 21.29s - Memory Usage: 5035.45MB - val_loss: 0.6626144051551819 - val_accuracy: 0.6936936974525452
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 15/15 [==============================] - 15s 997ms/step - loss: 0.5971 - accuracy: 0.6510
# Epoch 93/120 - Time: 15.84s - Memory Usage: 5082.55MB - val_loss: 0.6195775866508484 - val_accuracy: 0.7207207083702087
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 15/15 [==============================] - 15s 998ms/step - loss: 0.6004 - accuracy: 0.6521
# Epoch 94/120 - Time: 15.94s - Memory Usage: 4811.12MB - val_loss: 0.6761656999588013 - val_accuracy: 0.7027027010917664
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 15/15 [==============================] - 16s 1s/step - loss: 0.5891 - accuracy: 0.6594
# Epoch 95/120 - Time: 17.15s - Memory Usage: 4903.50MB - val_loss: 0.5624517798423767 - val_accuracy: 0.7567567825317383
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 15/15 [==============================] - 15s 993ms/step - loss: 0.5960 - accuracy: 0.6438
# Epoch 96/120 - Time: 15.84s - Memory Usage: 5000.70MB - val_loss: 0.7087127566337585 - val_accuracy: 0.6216216087341309
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 15/15 [==============================] - 15s 999ms/step - loss: 0.6030 - accuracy: 0.6417
# Epoch 97/120 - Time: 15.89s - Memory Usage: 5093.96MB - val_loss: 0.6155731081962585 - val_accuracy: 0.7297297120094299
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 15/15 [==============================] - 15s 1s/step - loss: 0.5879 - accuracy: 0.6458
# Epoch 98/120 - Time: 21.31s - Memory Usage: 4853.70MB - val_loss: 0.6422528624534607 - val_accuracy: 0.7117117047309875
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 15/15 [==============================] - 15s 1000ms/step - loss: 0.5951 - accuracy: 0.6615
# Epoch 99/120 - Time: 15.87s - Memory Usage: 4917.73MB - val_loss: 0.6172464489936829 - val_accuracy: 0.7477477192878723
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 15/15 [==============================] - 15s 1s/step - loss: 0.6132 - accuracy: 0.6156
# Epoch 100/120 - Time: 16.29s - Memory Usage: 4952.62MB - val_loss: 0.6414439082145691 - val_accuracy: 0.6936936974525452
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 15/15 [==============================] - 15s 986ms/step - loss: 0.5896 - accuracy: 0.6406
# Epoch 101/120 - Time: 16.10s - Memory Usage: 4998.88MB - val_loss: 0.6614570021629333 - val_accuracy: 0.6756756901741028
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 15/15 [==============================] - 15s 991ms/step - loss: 0.5988 - accuracy: 0.6219
# Epoch 102/120 - Time: 15.82s - Memory Usage: 4800.93MB - val_loss: 0.6336249113082886 - val_accuracy: 0.7117117047309875
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 15/15 [==============================] - 15s 1s/step - loss: 0.5996 - accuracy: 0.6438
# Epoch 103/120 - Time: 16.24s - Memory Usage: 4861.43MB - val_loss: 0.6480421423912048 - val_accuracy: 0.6936936974525452
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 15/15 [==============================] - 16s 991ms/step - loss: 0.5926 - accuracy: 0.6448
# Epoch 104/120 - Time: 17.35s - Memory Usage: 4961.29MB - val_loss: 0.657152533531189 - val_accuracy: 0.7297297120094299
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 15/15 [==============================] - 15s 983ms/step - loss: 0.6005 - accuracy: 0.6625
# Epoch 105/120 - Time: 15.63s - Memory Usage: 5061.55MB - val_loss: 0.7181749939918518 - val_accuracy: 0.5945945978164673
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 15/15 [==============================] - 15s 983ms/step - loss: 0.5770 - accuracy: 0.6562
# Epoch 106/120 - Time: 21.34s - Memory Usage: 4892.32MB - val_loss: 0.6492375731468201 - val_accuracy: 0.7207207083702087
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 15/15 [==============================] - 15s 987ms/step - loss: 0.5891 - accuracy: 0.6656
# Epoch 107/120 - Time: 15.68s - Memory Usage: 4963.86MB - val_loss: 0.662548303604126 - val_accuracy: 0.6666666865348816
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 15/15 [==============================] - 15s 983ms/step - loss: 0.5917 - accuracy: 0.6406
# Epoch 108/120 - Time: 21.33s - Memory Usage: 5051.95MB - val_loss: 0.6187364459037781 - val_accuracy: 0.7567567825317383
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 15/15 [==============================] - 15s 987ms/step - loss: 0.5719 - accuracy: 0.6771
# Epoch 109/120 - Time: 15.69s - Memory Usage: 5097.04MB - val_loss: 0.6589156985282898 - val_accuracy: 0.7207207083702087
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 15/15 [==============================] - 15s 983ms/step - loss: 0.6015 - accuracy: 0.6219
# Epoch 110/120 - Time: 15.65s - Memory Usage: 4794.88MB - val_loss: 0.6803105473518372 - val_accuracy: 0.684684693813324
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 15/15 [==============================] - 15s 971ms/step - loss: 0.5946 - accuracy: 0.6469
# Epoch 111/120 - Time: 22.02s - Memory Usage: 4928.60MB - val_loss: 0.6657795906066895 - val_accuracy: 0.6756756901741028
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 15/15 [==============================] - 15s 992ms/step - loss: 0.6018 - accuracy: 0.6271
# Epoch 112/120 - Time: 21.31s - Memory Usage: 4973.54MB - val_loss: 0.6358312368392944 - val_accuracy: 0.7297297120094299
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 15/15 [==============================] - 15s 983ms/step - loss: 0.5873 - accuracy: 0.6687
# Epoch 113/120 - Time: 15.66s - Memory Usage: 5054.03MB - val_loss: 0.7037360668182373 - val_accuracy: 0.6486486196517944
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 15/15 [==============================] - 15s 992ms/step - loss: 0.5931 - accuracy: 0.6375
# Epoch 114/120 - Time: 21.34s - Memory Usage: 4846.34MB - val_loss: 0.7022966146469116 - val_accuracy: 0.6036036014556885
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 15/15 [==============================] - 15s 983ms/step - loss: 0.5839 - accuracy: 0.6615
# Epoch 115/120 - Time: 21.97s - Memory Usage: 4902.26MB - val_loss: 0.5930425524711609 - val_accuracy: 0.7387387156486511
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 15/15 [==============================] - 15s 995ms/step - loss: 0.5986 - accuracy: 0.6490
# Epoch 116/120 - Time: 15.81s - Memory Usage: 4943.64MB - val_loss: 0.6379384398460388 - val_accuracy: 0.7027027010917664
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 15/15 [==============================] - 15s 995ms/step - loss: 0.5741 - accuracy: 0.6615
# Epoch 117/120 - Time: 21.30s - Memory Usage: 5003.24MB - val_loss: 0.6907035708427429 - val_accuracy: 0.6756756901741028
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 15/15 [==============================] - 15s 989ms/step - loss: 0.5851 - accuracy: 0.6448
# Epoch 118/120 - Time: 21.31s - Memory Usage: 4746.25MB - val_loss: 0.5278456211090088 - val_accuracy: 0.7657657861709595
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 15/15 [==============================] - 15s 986ms/step - loss: 0.5895 - accuracy: 0.6396

# %% [markdown]
# ###Metrics Evaluation###

# %%
predictedLabels = model.predict(testImages)
predictedClasses = np.argmax(predictedLabels, axis = 1)

report = classification_report(testLabels.argmax(axis = 1), predictedClasses)
print(report)
# Out:
# 4/4 [==============================] - 1s 84ms/step
#               precision    recall  f1-score   support
#
#            0       0.38      0.48      0.42        25
#            1       0.84      0.77      0.80        86
#
#     accuracy                           0.70       111
#    macro avg       0.61      0.62      0.61       111
# weighted avg       0.73      0.70      0.71       111

# %%
plt.figure(figsize=(8, 5))
plt.plot(range(1, num_epochs + 1), testAccuracy, color='b')
plt.xlabel('Epoch')
plt.ylabel('Test Accuracy')
plt.title('Test Accuracy over Epochs')
plt.ylim([0, 1])  # Set y-axis limit between 0 and 1
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(10, 5))

plt.subplot(1, 2, 1)
plt.plot(range(1, num_epochs + 1), training_times)
plt.xlabel('Epoch')
plt.ylabel('Time (s)')
plt.title('Training Speed per Epoch')

plt.subplot(1, 2, 2)
plt.plot(range(1, num_epochs + 1), memory_usage, color='orange')
plt.xlabel('Epoch')
plt.ylabel('Memory Usage (GB)')
plt.title('Memory Usage per Epoch')

plt.tight_layout()
plt.show()
